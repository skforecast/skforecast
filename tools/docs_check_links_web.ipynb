# %% [markdown]
# # Search links in docs
#
# pip install nbformat

# %%
import os
import nbformat

def search_text_in_files(directory, search_text_base):
    notebooks_with_text = []
    markdown_files_with_text = []

    # Recorre todos los archivos de la carpeta
    for root, dirs, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            if file.endswith(".ipynb"):
                with open(file_path, 'r', encoding='utf-8') as f:
                    nb = nbformat.read(f, as_version=4)
                    
                    # Recorre todas las celdas del notebook
                    for cell in nb.cells:
                        if cell.cell_type == 'markdown':
                            if search_text_base in cell.source:
                                notebooks_with_text.append(file_path)
                                break
            elif file.endswith(".md"):
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                    if search_text_base in content:
                        markdown_files_with_text.append(file_path)

    return notebooks_with_text, markdown_files_with_text

# Especifica la carpeta que contiene los notebooks y el texto a buscar
directory_path = '../docs/'
search_texts = [
    "https://skforecast.org/latest/introduction-forecasting/forecaster-parameters",
    "https://skforecast.org/latest/introduction-forecasting/forecaster-attributes",
    "https://skforecast.org/latest/user_guides/quick-start-skforecast",
    "https://skforecast.org/latest/user_guides/input-data",
    "https://skforecast.org/0.",
    "https://skforecast.org/0.12.1/user_guides/plot-forecaster-residuals",
    "https://skforecast.org/latest/user_guides/plot-forecaster-residuals"
]
search_texts = [
    "py72-classification-forecasting#Probability_calibration"
]

for search_text_base in search_texts:

    print(search_text_base)
    print("=" * len(search_text_base))

    # Llama a la función y obtén los notebooks que contienen el texto buscado
    notebooks, markdown_files = search_text_in_files(directory_path, search_text_base)

    # Imprime la lista de notebooks que contienen el texto
    if notebooks:
        print("The following notebooks contain the specified text:")
        for notebook in notebooks:
            print(notebook)
    else:
        print("No notebooks contain the specified text.")

    if markdown_files:
        print("\nThe following markdown files contain the specified text:")
        for markdown_file in markdown_files:
            print(markdown_file)
    else:
        print("No markdown files contain the specified text.")

    print("=" * len(search_text_base))
    print("\n")
# Out:
# py72-classification-forecasting#Probability_calibration
# =======================================================
# c:\Users\jaesc2\Miniconda3\envs\skforecast_py12\Lib\site-packages\nbformat\__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# The following notebooks contain the specified text:
# ../docs/user_guides\autoregressive-classification-forecasting.ipynb
# No markdown files contain the specified text.
# =======================================================

# %% [markdown]
# # Test links docs

# %%
base_url = "https://skforecast.org/0.20.0/"
# base_url = "https://dev.skforecast.org/0.17.0/"

# Lista de rutas extraídas del archivo mkdocs.yml
paths_general = [
    "",

    "examples/examples_english.md",
    "examples/examples_spanish.md",
    "examples/examples_chinese.md",

    "api/ForecasterRecursive.md",
    "api/ForecasterRecursiveClassifier.md",
    "api/ForecasterDirect.md",
    "api/ForecasterRecursiveMultiSeries.md",
    "api/ForecasterDirectMultiVariate.md",
    "api/ForecasterRnn.md",
    "api/ForecasterStats.md",
    "api/ForecasterEquivalentDate.md",
    "api/stats.md",
    "api/model_selection.md",
    "api/feature_selection.md",
    "api/preprocessing.md",
    "api/drift_detection.md",
    "api/metrics.md",
    "api/plot.md",
    "api/utils.md",
    "api/experimental.md",
    "api/datasets.md",
    "api/exceptions.md",

    "releases/releases.md",

    "more/about-skforecast.md",
    "more/consulting.md",
    "more/funding.md",
]

paths_user_guides = [
    "introduction-forecasting/introduction-forecasting.md",

    "user_guides/migration-guide.ipynb",
    
    "quick-start/quick-start-skforecast.ipynb",
    "quick-start/forecaster-parameters.md",
    "quick-start/forecaster-attributes.ipynb",
    "quick-start/how-to-install.md",
    
    "user_guides/table-of-contents.md",
    "user_guides/migration-guide.html",

    # Single series Forecasters
    "user_guides/input-data.ipynb",
    "user_guides/autoregressive-forecaster.ipynb",
    "user_guides/direct-multi-step-forecasting.ipynb",
    "user_guides/forecasting-baseline.ipynb",
    "user_guides/autoregressive-classification-forecasting.ipynb",

    # Global Forecasters (multiple series)
    "user_guides/independent-multi-time-series-forecasting.ipynb",
    "user_guides/multi-series-with-different-length-and-different_exog.ipynb",
    "user_guides/dependent-multi-series-multivariate-forecasting.ipynb",
    "user_guides/forecasting-with-deep-learning-rnn-lstm.ipynb",

    # Statistical Models
    "user_guides/forecasting-statistical-models.ipynb",
    "user_guides/forecasting-sarimax-arima.ipynb",
    "user_guides/forecasting-arar.ipynb",
    "user_guides/forecasting-ets.ipynb",

    # Feature Engineering
    "user_guides/exogenous-variables.ipynb",
    "user_guides/window-features-and-custom-features.ipynb",
    "user_guides/categorical-features.ipynb",
    "user_guides/calendar-features.ipynb",
    "user_guides/sklearn-transformers-and-pipeline.ipynb",
    "user_guides/time-series-differentiation.ipynb",
    "user_guides/feature-selection.ipynb",
    "user_guides/sktime-pipelines.ipynb",

    # Model Evaluation and Tuning
    "user_guides/metrics.ipynb",
    "user_guides/backtesting.ipynb",
    "user_guides/hyperparameter-tuning-and-lags-selection.ipynb",
    "user_guides/feature-selection.ipynb",

    # Probabilistic forecasting
    "user_guides/probabilistic-forecasting-overview.ipynb",
    "user_guides/probabilistic-forecasting-bootstrapped-residuals.ipynb",
    "user_guides/probabilistic-forecasting-conformal-prediction.ipynb",
    "user_guides/probabilistic-forecasting-conformal-calibration.ipynb",
    "user_guides/probabilistic-forecasting-quantile-regression.ipynb",
    "user_guides/probabilistic-forecasting-global-models.ipynb",
    "user_guides/probabilistic-forecasting-metrics.ipynb",
    "faq/probabilistic-forecasting-crps-score.ipynb",

    # Model Explainability
    "user_guides/explainability.ipynb",

    # Drift Detection
    "user_guides/drift-detection.ipynb",

    # Model deployment
    "user_guides/save-load-forecaster.ipynb",
    "user_guides/forecaster-in-production.ipynb",

    # Plotting
    "user_guides/plotting.ipynb",

    # Datasets
    "user_guides/datasets.ipynb",

    # Additional Resources
    "user_guides/training-and-prediction-matrices.ipynb",
    "user_guides/weighted-time-series-forecasting.ipynb",
    "user_guides/stacking-ensemble-models-forecasting.ipynb",
    "user_guides/forecasting-xgboost-lightgbm.ipynb",
    "user_guides/skforecast-in-GPU.ipynb",

    # FAQ and Tips
    "faq/table-of-contents.md",
    "faq/non-negative-predictions.ipynb",
    "faq/forecasting-time-series-with-missing-values.ipynb",
    "faq/forecasting-with-delayed-historical-data.ipynb",
    "faq/parameters-search-backtesting-vs-one-step-ahead.ipynb",
    "faq/probabilistic-forecasting-crps-score.ipynb",
    "faq/probabilistic-forecasting-calibrate-intervals.ipynb",
    "faq/cyclical-features-time-series.ipynb",
    "faq/time-series-aggregation.ipynb",
    "faq/skforecast-benchmark.ipynb",
    "faq/parallelization-skforecast.ipynb",
    "faq/profiling-skforecast.ipynb",
]

# base_url = "https://dev.skforecast.org/0.19.0/"
# paths_general = [
#     "",
#     "introduction-forecasting/introduction-forecasting.md",
#     "user_guides/table-of-contents.md",
#     "faq/table-of-contents.md",
#     "quick-start/forecaster-parameters.md",
#     "releases/releases.md",
# ]


# Función para cambiar la extensión a .html
def change_extension_to_html(path):
    if path.endswith(".md") or path.endswith(".ipynb"):
        return path.rsplit(".", 1)[0] + ".html"
    return path


# Generar enlaces completos con extensión .html
links_general = [
    base_url + change_extension_to_html(path) for path in paths_general
]
links_user_guides = [
    base_url + change_extension_to_html(path) for path in paths_user_guides
]

# %%
from colorama import Fore, Style

print("Esto es un texto normal")
print(Fore.RED + "Este texto es rojo" + Style.RESET_ALL)
print(Fore.GREEN + "Este texto es verde" + Style.RESET_ALL)
print(Fore.BLUE + "Este texto es azul" + Style.RESET_ALL)
print(Style.BRIGHT + Fore.RED + "Este texto es rojo en negrita" + Style.RESET_ALL)
print("Esto es un texto normal")
# Out:
# Esto es un texto normal
# Este texto es rojo
# Este texto es verde
# Este texto es azul
# Este texto es rojo en negrita
# Esto es un texto normal

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from colorama import Fore, Style


def check_links_ignoring_nav_links(url):
    # 1. Usar Session para mantener conexiones abiertas (reutiliza el handshake SSL)
    session = requests.Session()
    # User-Agent para parecer un navegador real
    session.headers.update({'User-Agent': 'Mozilla/5.0 (Link Checker)'})

    try:
        response = session.get(url, timeout=10)
        response.raise_for_status()
        print(f"[OK] Página accesible: {url}")
    except requests.exceptions.RequestException as e:
        print(Style.BRIGHT + Fore.RED + f"[ERROR] No se pudo acceder a {url}: {e}" + Style.RESET_ALL)
        return [(url, url, str(e))]  # (source_url, broken_link, error)

    # Parsear el contenido HTML
    soup = BeautifulSoup(response.content, "html.parser")
    links = soup.find_all("a", href=True)

    classes_no_to_visit = [
        'md-header__button', 'md-logo', "md-nav__link", "md-tabs__link",
        'md-source', 'md-social__link', 'autorefs-external'
    ]

    # Primera pasada: Solo recolectar URLs válidas
    links_to_check = []
    for link in links:
        class_link = link.get("class", [])
        
        # Filtros de clases
        if any(c in class_link for c in classes_no_to_visit):
            continue

        href = link['href']
        
        # Ignorar anclas internas, mailto, etc.
        if href.startswith(("#", "mailto:", "tel:", "javascript:")):
            continue

        full_url = urljoin(url, href)
        links_to_check.append(full_url)

    print(f"Comprobando {len(links_to_check)} enlaces...")
    
    broken_links = []

    # Segunda pasada: Comprobar enlaces uno a uno
    for link_url in links_to_check:
        try:
            # 2. Intentamos HEAD primero (mucho más rápido, no descarga el cuerpo)
            # allow_redirects=True es importante para seguir redirecciones
            r = session.head(link_url, timeout=5, allow_redirects=True)
            
            # Algunos servidores devuelven 405 o 404 a HEAD pero funcionan con GET
            # Si el status es de error (>=400), probamos con GET por si acaso
            if r.status_code >= 400:
                r = session.get(link_url, timeout=5, stream=True) 
                # stream=True descarga solo headers inicialmente, ahorrando ancho de banda

            if r.status_code >= 400:
                raise requests.exceptions.RequestException(f"Status {r.status_code}")

            print(f"  [OK] {link_url}")

        except requests.exceptions.RequestException as e:
            print(
                Style.BRIGHT + Fore.RED + 
                f"  [ERROR] Roto: {link_url} ({e})" 
                + Style.RESET_ALL
            )
            broken_links.append((url, link_url, str(e)))  # (source_url, broken_link, error)

    return broken_links

# Ejemplo de uso
# url = "https://skforecast.org/0.14.0/user_guides/table-of-contents.html"
# check_links_ignoring_nav_links(url)

# %%
# Check all links in user guides list
# ==============================================================================
from collections import defaultdict

broken_links_user_guides = []
for link in links_user_guides:
    broken_links = check_links_ignoring_nav_links(link)
    broken_links_user_guides.extend(broken_links)

print("")

# Resumen de enlaces rotos
# ==============================================================================
print(Style.BRIGHT + Fore.RED + "\n" + "=" * 80)
print("RESUMEN DE ENLACES ROTOS")
print("=" * 80)

grouped = defaultdict(list)
for source_url, broken_link, error in broken_links_user_guides:
    grouped[source_url].append((broken_link, error))

for source_url, links in grouped.items():
    print(f"\n[Origen] {source_url}")
    for link, error in links:
        print(f"   [{error}] {link}")

print("\n" + "=" * 80 + Style.RESET_ALL)
# Out:
# [OK] Página accesible: https://skforecast.org/0.20.0/introduction-forecasting/introduction-forecasting.html
# Comprobando 23 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/0.20.0/user_guides/direct-multi-step-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-classification-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-statistical-models
#   [OK] https://skforecast.org/0.20.0/introduction-forecasting/introduction-forecasting#recursive-multi-step-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/0.20.0/user_guides/direct-multi-step-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-classification-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-baseline
#   [OK] https://skforecast.org/0.20.0/quick-start/forecaster-parameters
#   [OK] https://skforecast.org/0.20.0/quick-start/forecaster-attributes
#   [OK] https://skforecast.org/0.20.0/user_guides/exogenous-variables
#   [OK] https://www.cienciadedatos.net/documentos/py29-forecasting-electricity-power-demand-python.html
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/migration-guide.html
# Comprobando 7 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/releases/releases
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/user_guides/window-features-and-custom-features
#   [OK] https://skforecast.org/0.20.0/user_guides/window-features-and-custom-features
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/quick-start/quick-start-skforecast.html
# Comprobando 12 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/user_guides/table-of-contents
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/0.20.0/quick-start/forecaster-parameters
#   [OK] https://skforecast.org/0.20.0/quick-start/forecaster-attributes
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://skforecast.org/0.20.0/user_guides/hyperparameter-tuning-and-lags-selection
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/quick-start/forecaster-parameters.html
# Comprobando 21 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.HistGradientBoostingRegressor.html
#   [OK] https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMRegressor.html
#   [OK] https://xgboost.readthedocs.io/en/stable/python/python_api.html#module-xgboost.sklearn
#   [OK] https://catboost.ai/en/docs/concepts/python-reference_catboostregressor
#   [OK] https://skforecast.org/0.20.0/introduction-forecasting/introduction-forecasting#machine-learning-for-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/window-features-and-custom-features
#   [OK] https://skforecast.org/0.20.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] https://skforecast.org/0.20.0/user_guides/weighted-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/time-series-differentiation
#   [OK] https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMRegressor.html#lightgbm.LGBMRegressor.fit
#   [OK] https://skforecast.org/0.20.0/user_guides/categorical-features#native-implementation-for-categorical-features
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.QuantileBinner
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.KBinsDiscretizer.html
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-bootstrapped-residuals#intervals-conditioned-on-predicted-values-binned-residuals
#   [OK] https://skforecast.org/0.20.0/introduction-forecasting/introduction-forecasting#direct-multi-step-forecasting
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirect
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.20.0/faq/parallelization-skforecast
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/quick-start/forecaster-attributes.html
# Comprobando 32 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=n_estimators,-int%2C%20default%3D100
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=criterion,-%7B%22squared_error%22%2C%20%22absolute_error%22%2C%20%22friedman_mse%22%2C%20%22poisson%22%7D%2C%20%20%20%20%20%20%20%20%20%20%20%20%20default%3D%22squared_error%22
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=max_depth,-int%2C%20default%3DNone
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=min_samples_split,-int%20or%20float%2C%20default%3D2
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=min_samples_leaf,-int%20or%20float%2C%20default%3D1
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=min_weight_fraction_leaf,-float%2C%20default%3D0.0
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=max_features,-%7B%22sqrt%22%2C%20%22log2%22%2C%20None%7D%2C%20int%20or%20float%2C%20default%3D1.0
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=max_leaf_nodes,-int%2C%20default%3DNone
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=min_impurity_decrease,-float%2C%20default%3D0.0
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=bootstrap,-bool%2C%20default%3DTrue
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=oob_score,-bool%20or%20callable%2C%20default%3DFalse
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=n_jobs,-int%2C%20default%3DNone
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=random_state,-int%2C%20RandomState%20instance%20or%20None%2C%20default%3DNone
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=verbose,-int%2C%20default%3D0
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=warm_start,-bool%2C%20default%3DFalse
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=ccp_alpha,-non-negative%20float%2C%20default%3D0.0
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=max_samples,-int%20or%20float%2C%20default%3DNone
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.ensemble.RandomForestRegressor.html#:~:text=monotonic_cst,-array-like%20of%20int%20of%20shape%20%28n_features%29%2C%20default%3DNone
#   [OK] https://skforecast.org/0.20.0/user_guides/direct-multi-step-forecasting
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirect
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.20.0/user_guides/forecaster-in-production
#   [OK] https://skforecast.org/0.20.0/user_guides/direct-multi-step-forecasting
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirect
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/quick-start/how-to-install.html
# Comprobando 4 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://pypi.org/project/skforecast/
#   [OK] https://anaconda.org/conda-forge/skforecast
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/table-of-contents.html
# Comprobando 58 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/user_guides/input-data
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/0.20.0/user_guides/direct-multi-step-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-baseline
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-classification-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] https://skforecast.org/0.20.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-statistical-models
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-arar
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-ets
#   [OK] https://skforecast.org/0.20.0/user_guides/exogenous-variables
#   [OK] https://skforecast.org/0.20.0/user_guides/window-features-and-custom-features
#   [OK] https://skforecast.org/0.20.0/user_guides/categorical-features
#   [OK] https://skforecast.org/0.20.0/user_guides/calendar-features
#   [OK] https://skforecast.org/0.20.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] https://skforecast.org/0.20.0/user_guides/time-series-differentiation
#   [OK] https://skforecast.org/0.20.0/user_guides/feature-selection
#   [OK] https://skforecast.org/0.20.0/user_guides/sktime-pipelines
#   [OK] https://skforecast.org/0.20.0/user_guides/metrics
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://skforecast.org/0.20.0/user_guides/hyperparameter-tuning-and-lags-selection
#   [OK] https://skforecast.org/0.20.0/user_guides/feature-selection
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-overview
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-bootstrapped-residuals
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-conformal-prediction
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-conformal-calibration
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-quantile-regression
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-global-models
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-metrics
#   [OK] https://skforecast.org/0.20.0/faq/probabilistic-forecasting-crps-score
#   [OK] https://skforecast.org/0.20.0/user_guides/explainability
#   [OK] https://skforecast.org/0.20.0/user_guides/drift-detection
#   [OK] https://skforecast.org/0.20.0/user_guides/save-load-forecaster
#   [OK] https://skforecast.org/0.20.0/user_guides/forecaster-in-production
#   [OK] https://skforecast.org/0.20.0/user_guides/plotting
#   [OK] https://skforecast.org/0.20.0/user_guides/datasets
#   [OK] https://skforecast.org/0.20.0/user_guides/migration-guide
#   [OK] https://skforecast.org/0.20.0/user_guides/training-and-prediction-matrices
#   [OK] https://skforecast.org/0.20.0/user_guides/weighted-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/stacking-ensemble-models-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-xgboost-lightgbm
#   [OK] https://skforecast.org/0.20.0/user_guides/skforecast-in-gpu
#   [OK] https://skforecast.org/0.20.0/faq/non-negative-predictions
#   [OK] https://skforecast.org/0.20.0/faq/forecasting-time-series-with-missing-values
#   [OK] https://skforecast.org/0.20.0/faq/forecasting-with-delayed-historical-data
#   [OK] https://skforecast.org/0.20.0/faq/parameters-search-backtesting-vs-one-step-ahead
#   [OK] https://skforecast.org/0.20.0/faq/cyclical-features-time-series
#   [OK] https://skforecast.org/0.20.0/faq/time-series-aggregation
#   [OK] https://skforecast.org/0.20.0/faq/skforecast-benchmark
#   [OK] https://skforecast.org/0.20.0/faq/benchmark-statistical-models
#   [OK] https://skforecast.org/0.20.0/faq/parallelization-skforecast
#   [OK] https://skforecast.org/0.20.0/faq/profiling-skforecast
#   [OK] https://skforecast.org/0.20.0/faq/table-of-contents
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/migration-guide.html
# Comprobando 7 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/releases/releases
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/user_guides/window-features-and-custom-features
#   [OK] https://skforecast.org/0.20.0/user_guides/window-features-and-custom-features
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/input-data.html
# Comprobando 10 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/0.20.0/user_guides/direct-multi-step-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-classification-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-baseline
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster.html
# Comprobando 9 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-overview
#   [OK] https://skforecast.org/0.20.0/user_guides/training-and-prediction-matrices
#   [OK] https://www.cienciadedatos.net/documentos/py49-modelling-time-series-trend-with-tree-based-models.html
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/direct-multi-step-forecasting.html
# Comprobando 6 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/faq/parallelization-skforecast
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirect
#   [OK] https://skforecast.org/0.20.0/user_guides/direct-multi-step-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/training-and-prediction-matrices
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/forecasting-baseline.html
# Comprobando 6 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://pandas.pydata.org/docs/reference/offset_frequency.html
#   [OK] https://skforecast.org/0.20.0/api/forecasterequivalentdate
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-baseline
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-conformal-prediction
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/autoregressive-classification-forecasting.html
# Comprobando 18 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursiveclassifier
#   [OK] https://skforecast.org/latest/api/forecasterrecursive#forecasterrecursiveclassifier
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.RollingFeaturesClassification
#   [OK] https://skforecast.org/0.20.0/user_guides/window-features-and-custom-features
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursiveclassifier
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-classification-forecasting
#   [OK] https://cienciadedatos.net/documentos/py72-classification-forecasting-categorical-series.html#Probability_calibration
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting#backtesting-with-custom-metric
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html
#   [OK] https://skforecast.org/0.20.0/user_guides/hyperparameter-tuning-and-lags-selection
#   [OK] https://scikit-learn.org/stable/modules/calibration.html#calibration-curves
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursiveclassifier
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting.html
# Comprobando 43 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/introduction-forecasting/introduction-forecasting
#   [OK] https://skforecast.org/0.20.0/introduction-forecasting/introduction-forecasting#recursive-multi-step-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] https://skforecast.org/0.20.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] https://www.cienciadedatos.net/documentos/py44-multi-series-forecasting-skforecast.html
#   [OK] https://www.cienciadedatos.net/documentos/py59-scalable-forecasting-models.html
#   [OK] https://cienciadedatos.net/documentos/py53-global-forecasting-models
#   [OK] https://cienciadedatos.net/documentos/py54-forecasting-with-deep-learning
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.reshape_series_wide_to_long
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.reshape_series_long_to_dict
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.reshape_series_long_to_dict
#   [OK] https://skforecast.org/0.20.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] https://skforecast.org/0.20.0/user_guides/exogenous-variables
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://skforecast.org/0.20.0/user_guides/hyperparameter-tuning-and-lags-selection#one-step-ahead-validation
#   [OK] https://skforecast.org/0.20.0/user_guides/metrics
#   [OK] https://skforecast.org/0.20.0/user_guides/hyperparameter-tuning-and-lags-selection#bayesian-search
#   [OK] https://optuna.readthedocs.io/en/stable/reference/generated/optuna.study.Study.html#optuna.study.Study
#   [OK] https://skforecast.org/0.20.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] https://skforecast.org/0.20.0/user_guides/exogenous-variables
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-bootstrapped-residuals#out-sample-residuals-non-conditioned-on-predicted-values
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://www.cienciadedatos.net/documentos/py49-modelling-time-series-trend-with-tree-based-models.html
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-global-models
#   [OK] https://scikit-learn.org/stable/modules/feature_selection.html
#   [OK] https://skforecast.org/0.20.0/user_guides/feature-selection#global-forecasting-models-feature-selection
#   [OK] https://skforecast.org/0.20.0/user_guides/metrics
#   [OK] https://skforecast.org/0.20.0/user_guides/training-and-prediction-matrices
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/multi-series-with-different-length-and-different_exog.html
# Comprobando 13 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.reshape_series_long_to_dict
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.reshape_exog_long_to_dict
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://skforecast.org/0.20.0/user_guides/hyperparameter-tuning-and-lags-selection#one-step-ahead-validation
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/dependent-multi-series-multivariate-forecasting.html
# Comprobando 28 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/introduction-forecasting/introduction-forecasting
#   [OK] https://skforecast.org/0.20.0/introduction-forecasting/introduction-forecasting#direct-multi-step-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] https://www.cienciadedatos.net/documentos/py44-multi-series-forecasting-skforecast.html
#   [OK] https://www.cienciadedatos.net/documentos/py59-scalable-forecasting-models.html
#   [OK] https://cienciadedatos.net/documentos/py53-global-forecasting-models
#   [OK] https://cienciadedatos.net/documentos/py54-forecasting-with-deep-learning
#   [OK] https://skforecast.org/0.20.0/faq/parallelization-skforecast
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.20.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-overview
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://skforecast.org/0.20.0/user_guides/hyperparameter-tuning-and-lags-selection#one-step-ahead-validation
#   [OK] https://skforecast.org/0.20.0/user_guides/hyperparameter-tuning-and-lags-selection#bayesian-search
#   [OK] https://optuna.readthedocs.io/en/stable/reference/generated/optuna.study.Study.html#optuna.study.Study
#   [OK] https://skforecast.org/0.20.0/user_guides/exogenous-variables
#   [OK] https://skforecast.org/0.20.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.20.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/weighted-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/metrics
#   [OK] https://skforecast.org/0.20.0/user_guides/training-and-prediction-matrices
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/forecasting-with-deep-learning-rnn-lstm.html
# Comprobando 20 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://www.cienciadedatos.net/documentos/py54-forecasting-with-deep-learning.html
#   [OK] https://keras.io/api/layers/recurrent_layers/lstm/
#   [OK] https://keras.io/api/layers/recurrent_layers/gru/
#   [OK] https://keras.io/api/layers/recurrent_layers/simple_rnn/
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-with-deep-learning-rnn-lstm#understanding-create-and-compile-model-in-depth
#   [OK] https://skforecast.org/0.20.0/api/forecasterrnn
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://skforecast.org/0.20.0/user_guides/exogenous-variables
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-conformal-prediction
#   [OK] https://keras.io/api/layers/recurrent_layers/lstm/
#   [OK] https://keras.io/api/layers/recurrent_layers/gru/
#   [OK] https://keras.io/api/layers/recurrent_layers/simple_rnn/
#   [OK] https://skforecast.org/0.20.0/api/forecasterrnn#skforecast.deep_learning.utils.create_and_compile_model
#   [OK] https://pytorch.org/get-started/locally/
#   [OK] https://skforecast.org/0.20.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] https://skforecast.org/0.20.0/api/forecasterrnn
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/forecasting-statistical-models.html
# Comprobando 32 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-ets
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._arima.Arima
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._ets.Ets
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._arar.Arar
#   [OK] https://skforecast.org/0.20.0/api/forecasterstats
#   [OK] https://www.cienciadedatos.net/documentos/py51-arima-sarimax-models-python.html
#   [OK] https://cienciadedatos.net/documentos/py73-arar-forecasting-models-python.html
#   [ERROR] Roto: https://cienciadedatos.net/documentos/py76-exponential-smoothing-models.html (Status 404)
#   [OK] https://skforecast.org/0.20.0/faq/benchmark-statistical-models
#   [OK] https://skforecast.org/0.20.0/api/forecasterstats
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._arima.Arima
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._ets.Ets
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._arar.Arar
#   [OK] https://www.sktime.net/en/stable/api_reference/auto_generated/sktime.forecasting.arima.ARIMA.html
#   [OK] https://www.aeon-toolkit.org/en/stable/api_reference/auto_generated/aeon.forecasting.stats.ARIMA.html#arima
#   [OK] https://skforecast.org/0.20.0/api/forecasterstats
#   [OK] https://skforecast.org/0.20.0/api/forecasterstats
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://skforecast.org/0.20.0/introduction-forecasting/introduction-forecasting#backtesting-forecasting-models
#   [OK] https://skforecast.org/0.20.0/user_guides/hyperparameter-tuning-and-lags-selection
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-ets
#   [OK] https://robjhyndman.com/hyndsight/aic/
#   [OK] https://sites.warnercnr.colostate.edu/kenburnham/wp-content/uploads/sites/25/2016/08/AIC-Myths-and-Misunderstandings.pdf
#   [OK] https://skforecast.org/0.20.0/api/forecasterstats
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://skforecast.org/0.20.0/api/forecasterstats
#   [OK] https://skforecast.org/0.20.0/user_guides/exogenous-variables
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima.html
# Comprobando 13 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._sarimax.Sarimax
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._arima.Arima
#   [OK] https://skforecast.org/0.20.0/user_guides/hyperparameter-tuning-and-lags-selection
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://robjhyndman.com/hyndsight/aic/
#   [OK] https://sites.warnercnr.colostate.edu/kenburnham/wp-content/uploads/sites/25/2016/08/AIC-Myths-and-Misunderstandings.pdf
#   [OK] https://skforecast.org/0.20.0/user_guides/exogenous-variables
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-statistical-models
#   [OK] https://skforecast.org/0.20.0/api/forecasterstats
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/forecasting-arar.html
# Comprobando 10 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://taf-society.github.io/Durbyn.jl/dev/
#   [OK] https://cienciadedatos.net/documentos/py73-arar-forecasting-models-python
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._arar.Arar
#   [OK] https://skforecast.org/0.20.0/user_guides/exogenous-variables
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-statistical-models
#   [OK] https://skforecast.org/0.20.0/api/forecasterstats
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/forecasting-ets.html
# Comprobando 10 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://taf-society.github.io/Durbyn.jl/dev/
#   [ERROR] Roto: https://cienciadedatos.net/documentos/py76-exponential-smoothing-models.html (Status 404)
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._ets.Ets
#   [OK] https://skforecast.org/0.20.0/user_guides/exogenous-variables
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-statistical-models
#   [OK] https://skforecast.org/0.20.0/api/forecasterstats
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/exogenous-variables.html
# Comprobando 14 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/user_guides/categorical-features
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/0.20.0/user_guides/window-features-and-custom-features
#   [OK] https://feature-engine.trainindata.com/en/latest/user_guide/timeseries/forecasting/LagFeatures.html#lagfeatures
#   [OK] https://feature-engine.trainindata.com/en/latest/api_doc/timeseries/forecasting/WindowFeatures.html
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.pipeline.Pipeline.html
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.pipeline.Pipeline.html#:~:text=steps,-list%20of%20tuples
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.pipeline.Pipeline.html#:~:text=transform_input,-list%20of%20str%2C%20default%3DNone
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.pipeline.Pipeline.html#:~:text=memory,-str%20or%20object%20with%20the%20joblib.Memory%20interface%2C%20default%3DNone
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.pipeline.Pipeline.html#:~:text=verbose,-bool%2C%20default%3DFalse
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting#backtesting-with-exogenous-variables
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/window-features-and-custom-features.html
# Comprobando 11 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/user_guides/exogenous-variables
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rolling.html
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.RollingFeatures
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/categorical-features.html
# Comprobando 31 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://www.cienciadedatos.net/documentos/py39-forecasting-time-series-with-skforecast-xgboost-lightgbm-catboost.html
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html#sklearn.preprocessing.OneHotEncoder
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.compose.ColumnTransformer.html
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.compose.ColumnTransformer.html
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.compose.ColumnTransformer.html#:~:text=transformers,-list%20of%20tuples
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.compose.ColumnTransformer.html#:~:text=remainder,-%7B%27drop%27%2C%20%27passthrough%27%7D%20or%20estimator%2C%20default%3D%27drop%27
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.compose.ColumnTransformer.html#:~:text=sparse_threshold,-float%2C%20default%3D0.3
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.compose.ColumnTransformer.html#:~:text=n_jobs,-int%2C%20default%3DNone
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.compose.ColumnTransformer.html#:~:text=transformer_weights,-dict%2C%20default%3DNone
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.compose.ColumnTransformer.html#:~:text=verbose,-bool%2C%20default%3DFalse
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.compose.ColumnTransformer.html#:~:text=verbose_feature_names_out,-bool%2C%20str%20or%20Callable%5B%5Bstr%2C%20str%5D%2C%20str%5D%2C%20default%3DTrue
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.compose.ColumnTransformer.html#:~:text=force_int_remainder_cols,-bool%2C%20default%3DFalse
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.preprocessing.OneHotEncoder.html
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.preprocessing.OneHotEncoder.html#:~:text=categories,-%27auto%27%20or%20a%20list%20of%20array-like%2C%20default%3D%27auto%27
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.preprocessing.OneHotEncoder.html#:~:text=drop,-%7B%27first%27%2C%20%27if_binary%27%7D%20or%20an%20array-like%20of%20shape%20%28n_features%2C%29%2C%20%20%20%20%20%20%20%20%20%20%20%20%20default%3DNone
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.preprocessing.OneHotEncoder.html#:~:text=sparse_output,-bool%2C%20default%3DTrue
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.preprocessing.OneHotEncoder.html#:~:text=dtype,-number%20type%2C%20default%3Dnp.float64
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.preprocessing.OneHotEncoder.html#:~:text=handle_unknown,-%7B%27error%27%2C%20%27ignore%27%2C%20%27infrequent_if_exist%27%2C%20%27warn%27%7D%2C%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20default%3D%27error%27
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.preprocessing.OneHotEncoder.html#:~:text=min_frequency,-int%20or%20float%2C%20default%3DNone
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.preprocessing.OneHotEncoder.html#:~:text=max_categories,-int%2C%20default%3DNone
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.preprocessing.OneHotEncoder.html#:~:text=feature_name_combiner,-%22concat%22%20or%20callable%2C%20default%3D%22concat%22
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OrdinalEncoder.html
#   [OK] https://feature-engine.trainindata.com/en/latest/user_guide/encoding/OrdinalEncoder.html
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://scikit-learn.org/dev/modules/generated/sklearn.preprocessing.TargetEncoder.html
#   [OK] https://scikit-learn.org/stable/modules/preprocessing.html#target-encoder
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/calendar-features.html
# Comprobando 6 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/user_guides/exogenous-variables
#   [OK] https://pandas.pydata.org/docs/user_guide/timeseries.html
#   [OK] https://feature-engine.trainindata.com/en/latest/user_guide/datetime/DatetimeFeatures.html#datetime-features
#   [OK] https://skforecast.org/0.20.0/faq/cyclical-features-time-series
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/sklearn-transformers-and-pipeline.html
# Comprobando 37 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/0.20.0/user_guides/training-and-prediction-matrices
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.FunctionTransformer.html
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.FunctionTransformer.html
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.FunctionTransformer.html
#   [OK] https://scikit-learn.org/stable/whats_new/v1.2.html#version-1-2-1
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.pipeline.Pipeline.html
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.pipeline.Pipeline.html#:~:text=steps,-list%20of%20tuples
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.pipeline.Pipeline.html#:~:text=transform_input,-list%20of%20str%2C%20default%3DNone
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.pipeline.Pipeline.html#:~:text=memory,-str%20or%20object%20with%20the%20joblib.Memory%20interface%2C%20default%3DNone
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.pipeline.Pipeline.html#:~:text=verbose,-bool%2C%20default%3DFalse
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.preprocessing.StandardScaler.html
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.preprocessing.StandardScaler.html#:~:text=copy,-bool%2C%20default%3DTrue
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.preprocessing.StandardScaler.html#:~:text=with_mean,-bool%2C%20default%3DTrue
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.preprocessing.StandardScaler.html#:~:text=with_std,-bool%2C%20default%3DTrue
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.linear_model.Ridge.html
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.linear_model.Ridge.html#:~:text=alpha,-%7Bfloat%2C%20ndarray%20of%20shape%20%28n_targets%2C%29%7D%2C%20default%3D1.0
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.linear_model.Ridge.html#:~:text=fit_intercept,-bool%2C%20default%3DTrue
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.linear_model.Ridge.html#:~:text=copy_X,-bool%2C%20default%3DTrue
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.linear_model.Ridge.html#:~:text=max_iter,-int%2C%20default%3DNone
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.linear_model.Ridge.html#:~:text=tol,-float%2C%20default%3D1e-4
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.linear_model.Ridge.html#:~:text=solver,-%7B%27auto%27%2C%20%27svd%27%2C%20%27cholesky%27%2C%20%27lsqr%27%2C%20%27sparse_cg%27%2C%20%20%20%20%20%20%20%20%20%20%20%20%20%27sag%27%2C%20%27saga%27%2C%20%27lbfgs%27%7D%2C%20default%3D%27auto%27
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.linear_model.Ridge.html#:~:text=positive,-bool%2C%20default%3DFalse
#   [OK] https://scikit-learn.org/1.8/modules/generated/sklearn.linear_model.Ridge.html#:~:text=random_state,-int%2C%20RandomState%20instance%2C%20default%3DNone
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting#scikit-learn-transformers-in-multi-series
#   [OK] https://skforecast.org/0.20.0/user_guides/dependent-multi-series-multivariate-forecasting#scikit-learn-transformers-in-multivariate
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/time-series-differentiation.html
# Comprobando 6 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.TimeSeriesDifferentiator
#   [OK] https://www.cienciadedatos.net/documentos/py49-modelling-time-series-trend-with-tree-based-models.html
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.TimeSeriesDifferentiator
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/feature-selection.html
# Comprobando 13 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://scikit-learn.org/stable/modules/feature_selection.html
#   [OK] https://feature-engine.trainindata.com/en/latest/api_doc/selection/index.html
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFE.html
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFECV.html#sklearn.feature_selection.RFECV
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SequentialFeatureSelector.html
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SequentialFeatureSelector.html
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectFromModel.html
#   [OK] https://feature-engine.trainindata.com/en/latest/user_guide/selection/MRMR.html
#   [OK] https://feature-engine.trainindata.com/en/latest/index.html
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/sktime-pipelines.html
# Comprobando 6 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://www.sktime.net/en/stable/
#   [OK] https://www.sktime.net/en/latest/api_reference/auto_generated/sktime.forecasting.compose.TransformedTargetForecaster.html#transformedtargetforecaster
#   [OK] https://www.sktime.net/en/latest/api_reference/auto_generated/sktime.forecasting.compose.ForecastingPipeline.html
#   [OK] https://skforecast.org/0.20.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/metrics.html
# Comprobando 21 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_absolute_error.html
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_absolute_percentage_error.html
#   [OK] https://en.wikipedia.org/wiki/Symmetric_mean_absolute_percentage_error
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_log_error.html
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.metrics.median_absolute_error.html
#   [OK] https://en.wikipedia.org/wiki/Mean_absolute_scaled_error#:~:text=In%20statistics%2C%20the%20mean%20absolute,2005%20by%20statistician%20Rob%20J.
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.metrics.balanced_accuracy_score.html
# ...
#   [OK] https://nannyml.readthedocs.io/en/stable/tutorials/detecting_data_drift/univariate_drift_detection.html
#   [OK] https://nannyml.readthedocs.io/en/stable/
#   [OK] https://skforecast.org/0.20.0/api/drift_detection#skforecast.drift_detection._population_drift.PopulationDriftDetector
#   [OK] https://skforecast.org/0.20.0/api/drift_detection#skforecast.drift_detection._population_drift.PopulationDriftDetector
#   [OK] https://skforecast.org/0.20.0/user_guides/drift-detection
#   [OK] https://skforecast.org/0.20.0/api/drift_detection#skforecast.drift_detection._population_drift.PopulationDriftDetector
#   [OK] https://skforecast.org/0.20.0/user_guides/drift-detection
#   [OK] https://skforecast.org/0.20.0/api/drift_detection#skforecast.drift_detection._range_drift.RangeDriftDetector
#   [OK] https://skforecast.org/0.20.0/api/drift_detection#skforecast.drift_detection._range_drift.RangeDriftDetector
#   [OK] https://skforecast.org/0.20.0/api/drift_detection#skforecast.drift_detection._range_drift.RangeDriftDetector
#   [OK] https://skforecast.org/0.20.0/user_guides/drift-detection
#   [OK] https://skforecast.org/0.20.0/api/drift_detection#skforecast.drift_detection._range_drift.RangeDriftDetector
#   [OK] https://skforecast.org/0.20.0/user_guides/drift-detection
#   [OK] https://skforecast.org/0.20.0/user_guides/forecaster-in-production
#   [OK] https://skforecast.org/0.20.0/user_guides/forecaster-in-production
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/save-load-forecaster.html
# Comprobando 7 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/user_guides/forecaster-in-production
#   [OK] https://skforecast.org/0.20.0/user_guides/window-features-and-custom-features#create-your-custom-window-features
#   [OK] https://skforecast.org/0.20.0/user_guides/weighted-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/forecaster-in-production.html
# Comprobando 4 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/user_guides/drift-detection
#   [OK] https://skforecast.org/0.20.0/user_guides/save-load-forecaster
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/plotting.html
# Comprobando 3 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/datasets.html
# Comprobando 3 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://github.com/skforecast/skforecast-datasets
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/training-and-prediction-matrices.html
# Comprobando 25 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] https://skforecast.org/0.20.0/user_guides/time-series-differentiation
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/0.20.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] https://skforecast.org/0.20.0/user_guides/time-series-differentiation
#   [OK] https://skforecast.org/0.20.0/user_guides/time-series-differentiation
#   [OK] https://skforecast.org/0.20.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] https://skforecast.org/0.20.0/api/utils#skforecast.utils.utils.transform_numpy
#   [OK] https://skforecast.org/0.20.0/api/utils#skforecast.utils.utils.transform_series
#   [OK] https://skforecast.org/0.20.0/api/utils#skforecast.utils.utils.transform_dataframe
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting#series-encoding-in-multi-series
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.20.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] https://skforecast.org/0.20.0/user_guides/time-series-differentiation
#   [OK] https://skforecast.org/0.20.0/user_guides/time-series-differentiation
#   [OK] https://skforecast.org/0.20.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] https://skforecast.org/0.20.0/api/utils#skforecast.utils.utils.transform_numpy
#   [OK] https://skforecast.org/0.20.0/api/utils#skforecast.utils.utils.transform_series
#   [OK] https://skforecast.org/0.20.0/api/utils#skforecast.utils.utils.transform_dataframe
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/weighted-time-series-forecasting.html
# Comprobando 4 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://github.com/microsoft/LightGBM/issues/5553
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/stacking-ensemble-models-forecasting.html
# Comprobando 8 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.StackingRegressor.html#sklearn.ensemble.StackingRegressor
#   [OK] https://cienciadedatos.net/documentos/py52-stacking-ensemble-models-forecasting.html
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.StackingRegressor.html#sklearn.ensemble.StackingRegressor
#   [OK] https://scikit-learn.org/1.6/modules/generated/sklearn.ensemble.StackingRegressor.html
#   [OK] https://scikit-learn.org/1.6/modules/generated/sklearn.linear_model.Ridge.html
#   [OK] https://scikit-learn.org/1.6/modules/generated/sklearn.linear_model.Ridge.html
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/forecasting-xgboost-lightgbm.html
# Comprobando 16 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://xgboost.readthedocs.io/en/stable/index.html
#   [OK] https://lightgbm.readthedocs.io/en/latest/
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.HistGradientBoostingRegressor.html#sklearn.ensemble.HistGradientBoostingRegressor
#   [OK] https://catboost.ai/
#   [OK] https://skforecast.org/0.20.0/user_guides/categorical-features#native-implementation-for-categorical-features
#   [OK] https://cienciadedatos.net/documentos/py39-forecasting-time-series-with-skforecast-xgboost-lightgbm-catboost
#   [OK] https://www.cienciadedatos.net/documentos/py56-forecasting-time-series-with-xgboost.html
#   [OK] https://cienciadedatos.net/documentos/py29-forecasting-electricity-power-demand-python
#   [OK] https://skforecast.org/latest/user_guides/skforecast-in-gpu
#   [OK] https://www.cienciadedatos.net/documentos/py49-modelling-time-series-trend-with-tree-based-models.html
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/user_guides/skforecast-in-GPU.html
# Comprobando 8 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://colab.research.google.com/drive/10PYQFQN9oNkAHh0X7wwyBLQ3JQ_Cm7pP?usp=sharing
#   [OK] https://colab.research.google.com/drive/17Csc70AY-GQA-tvZjq9TYCbmnrNOzslh?usp=sharing
#   [OK] https://colab.research.google.com/drive/1Z-n0kKEnQvY02e9-HxKbkTdLc10RNd_-?usp=sharing
#   [OK] https://colab.research.google.com/drive/1RlHrd7QQ0z4WaA93hrn9zCnHCVC7wbWU?usp=sharing
#   [OK] https://docs.rapids.ai/api/cuml/stable
#   [OK] https://rapids.ai/start.html
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/faq/table-of-contents.html
# Comprobando 18 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://github.com/skforecast/skforecast/issues
#   [OK] https://skforecast.org/0.20.0/faq/non-negative-predictions
#   [OK] https://skforecast.org/0.20.0/faq/forecasting-time-series-with-missing-values
#   [OK] https://skforecast.org/0.20.0/user_guides/time-series-differentiation
#   [OK] https://cienciadedatos.net/documentos/py49-modelling-time-series-trend-with-tree-based-models.html
#   [OK] https://skforecast.org/0.20.0/faq/forecasting-with-delayed-historical-data
#   [OK] https://skforecast.org/0.20.0/faq/parameters-search-backtesting-vs-one-step-ahead
#   [OK] https://skforecast.org/0.20.0/faq/probabilistic-forecasting-crps-score
#   [OK] https://skforecast.org/0.20.0/faq/probabilistic-forecasting-calibrate-intervals
#   [OK] https://cienciadedatos.net/documentos/py63-data-leakage-pre-trained-forecasting-models.html
#   [OK] https://skforecast.org/0.20.0/faq/cyclical-features-time-series
#   [OK] https://skforecast.org/0.20.0/faq/time-series-aggregation
#   [OK] https://skforecast.org/0.20.0/faq/skforecast-benchmark
#   [OK] https://skforecast.org/0.20.0/faq/benchmark-statistical-models
#   [OK] https://skforecast.org/0.20.0/faq/parallelization-skforecast
#   [OK] https://skforecast.org/0.20.0/faq/profiling-skforecast
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/faq/non-negative-predictions.html
# Comprobando 4 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://florianwilhelm.info/2020/05/honey_i_shrunk_the_target_variable/
#   [OK] https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.FunctionTransformer.html
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/faq/forecasting-time-series-with-missing-values.html
# Comprobando 3 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/user_guides/weighted-time-series-forecasting
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/faq/forecasting-with-delayed-historical-data.html
# Comprobando 5 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://skforecast.org/0.20.0/user_guides/forecaster-in-production
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/faq/parameters-search-backtesting-vs-one-step-ahead.html
# Comprobando 3 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/faq/probabilistic-forecasting-crps-score.html
# Comprobando 5 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://cienciadedatos.net/documentos/py42-probabilistic-forecasting
#   [OK] https://cienciadedatos.net/documentos/py60-probabilistic-forecasting-prediction-intervals-multi-step-forecasting
#   [OK] https://skforecast.org/0.20.0/faq/probabilistic-forecasting-crps-score
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/faq/probabilistic-forecasting-calibrate-intervals.html
# Comprobando 4 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://leanpub.com/conformal-prediction
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.ConformalIntervalCalibrator
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/faq/cyclical-features-time-series.html
# Comprobando 5 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://scikit-learn.org/stable/auto_examples/applications/plot_cyclical_feature_engineering.html#sphx-glr-auto-examples-applications-plot-cyclical-feature-engineering-py
#   [OK] https://scikit-lego.netlify.app/preprocessing.html#Repeating-Basis-Function-Transformer
#   [OK] https://developer.nvidia.com/blog/three-approaches-to-encoding-time-information-as-features-for-ml-models/
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/faq/time-series-aggregation.html
# Comprobando 2 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/faq/skforecast-benchmark.html
# Comprobando 14 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/latest/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/latest/user_guides/backtesting
#   [OK] https://skforecast.org/latest/user_guides/direct-multi-step-forecasting
#   [OK] https://skforecast.org/latest/user_guides/backtesting
#   [OK] https://skforecast.org/latest/user_guides/autoregressive-classification-forecasting
#   [OK] https://skforecast.org/latest/user_guides/backtesting
#   [OK] https://skforecast.org/latest/user_guides/forecasting-sarimax-arima
#   [OK] https://skforecast.org/latest/user_guides/backtesting
#   [OK] https://skforecast.org/latest/user_guides/independent-multi-time-series-forecasting
#   [OK] https://skforecast.org/latest/user_guides/backtesting
#   [OK] https://skforecast.org/latest/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] https://skforecast.org/latest/user_guides/backtesting
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/faq/benchmark-statistical-models.html
# Comprobando 6 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/api/forecasterstats
#   [ERROR] Roto: https://skforecast.org/0.20.0/api/stats.md#skforecast.stats._sarimax.Sarimax (Status 404)
#   [ERROR] Roto: https://skforecast.org/0.20.0/api/stats.md#skforecast.stats._arar.Arar (Status 404)
#   [ERROR] Roto: https://skforecast.org/latest/api/recursive#forecasterrecursive.ForecasterRecursive (Status 404)
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/faq/parallelization-skforecast.html
# Comprobando 4 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._utils.select_n_jobs_backtesting
#   [OK] https://skforecast.org/0.20.0/api/utils#skforecast.utils.utils.select_n_jobs_fit_forecaster
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/faq/profiling-skforecast.html
# Comprobando 2 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://squidfunk.github.io/mkdocs-material/
#
#
#
# ================================================================================
# RESUMEN DE ENLACES ROTOS
# ================================================================================
#
# [Origen] https://skforecast.org/0.20.0/user_guides/forecasting-statistical-models.html
#    [Status 404] https://cienciadedatos.net/documentos/py76-exponential-smoothing-models.html
#
# [Origen] https://skforecast.org/0.20.0/user_guides/forecasting-ets.html
#    [Status 404] https://cienciadedatos.net/documentos/py76-exponential-smoothing-models.html
#
# [Origen] https://skforecast.org/0.20.0/faq/benchmark-statistical-models.html
#    [Status 404] https://skforecast.org/0.20.0/api/stats.md#skforecast.stats._sarimax.Sarimax
#    [Status 404] https://skforecast.org/0.20.0/api/stats.md#skforecast.stats._arar.Arar
#    [Status 404] https://skforecast.org/latest/api/recursive#forecasterrecursive.ForecasterRecursive
#
# ================================================================================

# %%
# Check all links in general list
# ==============================================================================
from collections import defaultdict

broken_links_general = []
for link in links_general:
    broken_links = check_links_ignoring_nav_links(link)
    broken_links_general.extend(broken_links)

print("")

# Resumen de enlaces rotos
# ==============================================================================
print(Style.BRIGHT + Fore.RED + "\n" + "=" * 80)
print("RESUMEN DE ENLACES ROTOS")
print("=" * 80)

grouped = defaultdict(list)
for source_url, broken_link, error in broken_links_general:
    grouped[source_url].append((broken_link, error))

for source_url, links in grouped.items():
    print(f"\n[Origen] {source_url}")
    for link, error in links:
        print(f"   [{error}] {link}")

print("\n" + "=" * 80 + Style.RESET_ALL)
# Out:
# [OK] Página accesible: https://skforecast.org/0.20.0/
# Comprobando 53 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://pypi.org/project/skforecast/
#   [OK] https://anaconda.org/conda-forge/skforecast
#   [OK] https://codecov.io/gh/skforecast/skforecast
#   [OK] https://github.com/skforecast/skforecast/actions/workflows/unit-tests.yml
#   [OK] https://www.repostatus.org/#active
#   [OK] https://github.com/skforecast/skforecast/graphs/commit-activity
#   [OK] https://pepy.tech/project/skforecast
#   [OK] https://pypistats.org/packages/skforecast
#   [OK] https://github.com/skforecast/skforecast/blob/master/LICENSE
#   [OK] https://zenodo.org/doi/10.5281/zenodo.8382787
#   [OK] https://www.paypal.com/donate/?hosted_button_id=D2JZSWRLTZDL6
#   [OK] https://www.buymeacoffee.com/skforecast
#   [OK] https://www.linkedin.com/company/skforecast/
#   [OK] https://discord.gg/3V52qpNkuj
#   [OK] https://cienciadedatos.net/en/forecasting-python
#   [OK] https://numfocus.org/sponsored-projects/affiliated-projects
#   [OK] https://gc-os-ai.github.io/
#   [OK] https://github.com/skforecast/skforecast/issues
#   [OK] https://github.com/skforecast/skforecast/blob/master/CONTRIBUTING.md
#   [OK] https://github.com/skforecast/skforecast/blob/master/CONTRIBUTING.md
#   [OK] https://skforecast.org/0.20.0/quick-start/how-to-install
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-forecaster
#   [OK] https://skforecast.org/0.20.0/user_guides/direct-multi-step-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-classification-forecasting
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-baseline
#   [OK] https://skforecast.org/0.20.0/user_guides/table-of-contents
#   [OK] https://skforecast.org/0.20.0/examples/examples_english
#   [OK] https://github.com/skforecast/skforecast/issues
#   [OK] https://skforecast.org/0.20.0/examples/examples_english
#   [OK] https://docs.pytest.org/en/latest/
#   [OK] https://github.com/skforecast/skforecast/blob/master/CONTRIBUTING.md
#   [OK] https://skforecast.org/0.20.0/more/about-skforecast
#   [OK] https://doi.org/10.1109/SusTech60925.2024.10553570
#   [OK] https://doi.org/10.1016/j.jaridenv.2024.105160
#   [OK] https://doi.org/10.1109/AMPS59207.2023.10297192
#   [ERROR] Roto: https://doi.org/10.37431/conectividad.v5i2.126 (HTTPSConnectionPool(host='www.revista.ister.edu.ec', port=443): Max retries exceeded with url: /ojs/index.php/ISTER/article/view/126 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.revista.ister.edu.ec'. (_ssl.c:1010)"))))
#   [OK] https://doi.org/10.19139/soic-2310-5070-1822
#   [ERROR] Roto: https://doi.org/10.3390/en16031495 (Status 403)
#   [ERROR] Roto: https://doi.org/10.3390/en16186726 (Status 403)
#   [ERROR] Roto: https://doi.org/10.3390/en16186731 (Status 403)
#   [OK] https://doi.org/10.1007/978-3-031-22200-9_32
#   [OK] https://www.buymeacoffee.com/skforecast
#   [OK] https://github.com/sponsors/JoaquinAmatRodrigo
#   [OK] https://github.com/sponsors/JavierEscobarOrtiz
#   [OK] https://www.paypal.com/donate/?hosted_button_id=D2JZSWRLTZDL6
#   [OK] https://github.com/skforecast/skforecast/blob/master/LICENSE
#   [OK] https://creativecommons.org/licenses/by-nc-sa/4.0/
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/examples/examples_english.html
# Comprobando 34 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://cienciadedatos.net/en/forecasting-python
#   [OK] https://www.cienciadedatos.net/documentos/py27-time-series-forecasting-python-scikitlearn.html
#   [OK] https://www.cienciadedatos.net/documentos/py51-arima-sarimax-models-python.html
#   [OK] https://cienciadedatos.net/documentos/py73-arar-forecasting-models-python.html
#   [OK] https://www.cienciadedatos.net/documentos/py39-forecasting-time-series-with-skforecast-xgboost-lightgbm-catboost.html
#   [OK] https://cienciadedatos.net/documentos/py72-classification-forecasting-categorical-series.html
#   [OK] https://www.cienciadedatos.net/documentos/py56-forecasting-time-series-with-xgboost.html
#   [OK] https://www.cienciadedatos.net/documentos/py58-forecasting-time-series-with-lightgbm.html
#   [OK] https://www.cienciadedatos.net/documentos/py44-multi-series-forecasting-skforecast.html
#   [OK] https://www.cienciadedatos.net/documentos/py53-global-forecasting-models.html
#   [OK] https://www.cienciadedatos.net/documentos/py59-scalable-forecasting-models.html
#   [OK] https://cienciadedatos.net/documentos/py66-forecasting-sticker-sales-kaggle.html
#   [OK] https://www.cienciadedatos.net/documentos/py61-m5-forecasting-competition.html
#   [OK] https://cienciadedatos.net/documentos/py54-forecasting-with-deep-learning
#   [OK] https://cienciadedatos.net/documentos/py68-forecasting-at-scale-with-deep-learning.html
#   [OK] https://cienciadedatos.net/documentos/py64-clustering-time-series-forecasting.html
#   [OK] https://www.cienciadedatos.net/documentos/py42-probabilistic-forecasting.html
#   [OK] https://cienciadedatos.net/documentos/py60-probabilistic-forecasting-prediction-intervals-multi-step-forecasting.html
#   [OK] https://www.cienciadedatos.net/documentos/py57-interpretable-forecasting-models.html
#   [OK] https://cienciadedatos.net/documentos/py70-drift-detection-forecasting-model.html
#   [OK] https://www.cienciadedatos.net/documentos/py49-modelling-time-series-trend-with-tree-based-models.html
#   [OK] https://www.cienciadedatos.net/documentos/py46-forecasting-time-series-missing-values.html
#   [OK] https://cienciadedatos.net/documentos/py52-stacking-ensemble-models-forecasting.html
#   [OK] https://cienciadedatos.net/documentos/py62-time-series-anomaly-detection.html
#   [OK] https://cienciadedatos.net/documentos/py63-data-leakage-pre-trained-forecasting-models.html
#   [OK] https://cienciadedatos.net/documentos/py65-accelerate-forecasting-models-gpu.html
#   [OK] https://cienciadedatos.net/documentos/py75-accelerate-forecasting-with-scikit-learn-intelex.html
#   [OK] https://www.cienciadedatos.net/documentos/py29-forecasting-electricity-power-demand-python.html
#   [OK] https://www.cienciadedatos.net/documentos/py37-forecasting-web-traffic-machine-learning.html
#   [OK] https://www.cienciadedatos.net/documentos/py48-intermittent-demand-forecasting.html
#   [OK] https://www.cienciadedatos.net/documentos/py45-weighted-time-series-forecasting.html
#   [OK] https://www.cienciadedatos.net/documentos/py41-forecasting-cryptocurrency-bitcoin-machine-learning-python.html
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/examples/examples_spanish.html
# Comprobando 28 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://cienciadedatos.net/forecasting-python
#   [OK] https://www.cienciadedatos.net/documentos/py27-forecasting-series-temporales-python-scikitlearn.html
#   [OK] https://cienciadedatos.net/documentos/py51-modelos-arima-sarimax-python.html
#   [OK] https://www.cienciadedatos.net/documentos/py39-forecasting-series-temporales-con-skforecast-xgboost-lightgbm-catboost.html
#   [OK] https://www.cienciadedatos.net/documentos/py56-forecasting-series-temporales-con-xgboost.html
#   [OK] https://www.cienciadedatos.net/documentos/py58-forecasting-series-temporales-con-lightgbm.html
#   [OK] https://youtu.be/MlktVhReO0E
#   [OK] https://www.cienciadedatos.net/documentos/py44-multi-series-forecasting-skforecast-español.html
#   [OK] https://www.cienciadedatos.net/documentos/py53-modelos-forecasting-globales.html
#   [OK] https://www.cienciadedatos.net/documentos/py59-modelos-forecasting-escalables.html
#   [OK] https://cienciadedatos.net/documentos/py66-forecasting-sticker-sales-kaggle-es.html
#   [OK] https://cienciadedatos.net/documentos/py54-forecasting-con-deep-learning
#   [OK] https://cienciadedatos.net/documentos/py64-clustering-series-temporales-forecasting.html
#   [OK] https://cienciadedatos.net/documentos/py42-forecasting-probabilistico.html
#   [OK] https://cienciadedatos.net/documentos/py60-forecasting-probabilistico-intervalos-prediccion-forecasting-multi-step.html
#   [OK] https://cienciadedatos.net/documentos/py49-modelar-tendencia-en-series-temporales-modelos-de-arboles.html
#   [OK] https://www.cienciadedatos.net/documentos/py46-forecasting-series-temporales-incompletas.html
#   [OK] https://www.cienciadedatos.net/documentos/py57-modelos-forecasting-interpretables.html
#   [OK] https://cienciadedatos.net/documentos/py52-stacking-ensemble-modelos-forecasting.html
#   [OK] https://cienciadedatos.net/documentos/py62-deteccion-anomalias-series-temporales.html
#   [OK] https://cienciadedatos.net/documentos/py63-data-leakage-modelos-forecasting-preentrenados.html
#   [OK] https://www.cienciadedatos.net/documentos/py29-forecasting-demanda-energia-electrica-python.html
#   [OK] https://www.cienciadedatos.net/documentos/py37-forecasting-visitas-web-machine-learning.html
#   [OK] https://www.cienciadedatos.net/documentos/py48-forecasting-demanda-intermitente.html
#   [OK] https://cienciadedatos.net/documentos/py45-weighted-time-series-forecasting-es
#   [OK] https://www.cienciadedatos.net/documentos/py41-forecasting-criptomoneda-bitcoin-machine-learning-python.html
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/examples/examples_chinese.html
# Comprobando 6 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://cienciadedatos.net/cn/forecasting-python
#   [OK] https://cienciadedatos.net/documentos/py27-time-series-forecasting-python-scikitlearn-cn.html
#   [OK] https://www.cienciadedatos.net/documentos/py51-arima-sarimax-models-python-cn.html
#   [OK] https://www.cienciadedatos.net/documentos/py39-forecasting-time-series-with-skforecast-xgboost-lightgbm-catboost-cn.html
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/ForecasterRecursive.html
# Comprobando 10 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.TimeSeriesDifferentiator
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.QuantileBinner
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://mapie.readthedocs.io/en/stable/theoretical_description_regression.html#the-split-method
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://mapie.readthedocs.io/en/stable/theoretical_description_regression.html#the-split-method
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/ForecasterRecursiveClassifier.html
# Comprobando 2 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/ForecasterDirect.html
# Comprobando 10 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.TimeSeriesDifferentiator
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.QuantileBinner
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://mapie.readthedocs.io/en/stable/theoretical_description_regression.html#the-split-method
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://mapie.readthedocs.io/en/stable/theoretical_description_regression.html#the-split-method
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/ForecasterRecursiveMultiSeries.html
# Comprobando 9 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.TimeSeriesDifferentiator
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://mapie.readthedocs.io/en/stable/theoretical_description_regression.html#the-split-method
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://mapie.readthedocs.io/en/stable/theoretical_description_regression.html#the-split-method
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/ForecasterDirectMultiVariate.html
# Comprobando 9 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.TimeSeriesDifferentiator
#   [OK] https://mapie.readthedocs.io/en/stable/theoretical_description_regression.html#the-split-method
#   [OK] https://mapie.readthedocs.io/en/stable/theoretical_description_regression.html#the-split-method
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://mapie.readthedocs.io/en/stable/theoretical_description_regression.html#the-split-method
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/ForecasterRnn.html
# Comprobando 9 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://keras.io/api/layers/recurrent_layers/lstm/
#   [OK] https://keras.io/api/layers/recurrent_layers/gru/
#   [OK] https://keras.io/api/layers/recurrent_layers/simple_rnn/
#   [OK] https://keras.io/api/layers/core_layers/dense/
#   [OK] https://keras.io/api/models/model_training_apis/
#   [OK] https://mapie.readthedocs.io/en/stable/theoretical_description_regression.html#the-split-method
#   [OK] https://mapie.readthedocs.io/en/stable/theoretical_description_regression.html#the-split-method
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/ForecasterStats.html
# Comprobando 3 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.sarimax.SARIMAXResults.info_criteria.html
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/ForecasterEquivalentDate.html
# Comprobando 6 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://pandas.pydata.org/docs/reference/offset_frequency.html
#   [OK] https://pandas.pydata.org/docs/reference/offset_frequency.html
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.QuantileBinner
#   [OK] https://mapie.readthedocs.io/en/stable/theoretical_description_regression.html#the-split-method
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/stats.html
# Comprobando 8 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://www.statsmodels.org/stable/generated/statsmodels.tsa.statespace.sarimax.SARIMAX.html
#   [OK] https://www.statsmodels.org/stable/generated/statsmodels.tsa.statespace.sarimax.SARIMAXResults.html
#   [OK] https://www.statsmodels.org/stable/generated/statsmodels.tsa.statespace.mlemodel.MLEResults.append.html#statsmodels.tsa.statespace.mlemodel.MLEResults.append
#   [OK] https://www.statsmodels.org/stable/generated/statsmodels.tsa.statespace.mlemodel.MLEResults.apply.html#statsmodels.tsa.statespace.mlemodel.MLEResults.apply
#   [OK] https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.mlemodel.MLEResults.extend.html#statsmodels.tsa.statespace.mlemodel.MLEResults.extend
#   [OK] https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.sarimax.SARIMAXResults.info_criteria.html
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/model_selection.html
# Comprobando 6 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://mapie.readthedocs.io/en/stable/theoretical_description_regression.html#the-split-method
#   [OK] https://otexts.com/fpp3/prediction-intervals.html
#   [OK] https://mapie.readthedocs.io/en/stable/theoretical_description_regression.html#the-split-method
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/feature_selection.html
# Comprobando 2 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/preprocessing.html
# Comprobando 2 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/drift_detection.html
# Comprobando 5 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/latest/user_guides/drift-detection#deep-dive-into-temporal-drift-detection-in-time-series
#   [OK] https://nannyml.readthedocs.io/en/stable/
#   [OK] https://nannyml.readthedocs.io/en/stable/tutorials/detecting_data_drift/univariate_drift_detection.html
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/metrics.html
# Comprobando 2 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/plot.html
# Comprobando 5 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://www.statsmodels.org/stable/generated/statsmodels.tsa.stattools.acf.html
#   [OK] https://www.statsmodels.org/stable/generated/statsmodels.tsa.stattools.pacf.html
#   [OK] https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/utils.html
# Comprobando 2 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/experimental.html
# Comprobando 2 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/datasets.html
# Comprobando 2 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/api/exceptions.html
# Comprobando 2 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/releases/releases.html
# Comprobando 361 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._arima.Arima
#   [OK] https://skforecast.org/0.20.0/api/stats
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://skforecast.org/0.20.0/api/forecasterstats
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._sarimax.Sarimax
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._arima.Arima
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._arar.Arar
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._ets.Ets
#   [OK] https://skforecast.org/0.20.0/api/drift_detection#skforecast.drift_detection._population_drift.PopulationDriftDetector
#   [OK] https://skforecast.org/0.20.0/user_guides/drift-detection
#   [OK] https://skforecast.org/0.19.0/api/forecastersarimax
#   [OK] https://skforecast.org/0.20.0/api/forecasterstats
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._arima.Arima
#   [OK] https://skforecast.org/0.20.0/api/stats
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://skforecast.org/0.20.0/api/forecasterstats
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._sarimax.Sarimax
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._arima.Arima
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._arar.Arar
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._ets.Ets
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_stats
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.RollingFeatures
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirect
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirect
#   [OK] https://skforecast.org/0.20.0/api/drift_detection#skforecast.drift_detection._population_drift.PopulationDriftDetector
#   [OK] https://skforecast.org/0.19.0/api/forecastersarimax
#   [OK] https://skforecast.org/0.20.0/api/forecasterstats
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_stats
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.QuantileBinner
#   [OK] https://skforecast.org/0.20.0/api/drift_detection#skforecast.drift_detection._population_drift.PopulationDriftDetector
#   [OK] https://github.com/skforecast/skforecast/issues/1080
#   [OK] https://skforecast.org/0.20.0/api/utils#skforecast.utils.utils.load_forecaster
#   [OK] https://github.com/skforecast/skforecast/issues/1079
#   [OK] https://skforecast.org/0.20.0/api/drift_detection#skforecast.drift_detection._population_drift.PopulationDriftDetector
#   [OK] https://github.com/skforecast/skforecast/issues/1080
#   [OK] https://skforecast.org/0.20.0/api/utils#skforecast.utils.utils.save_forecaster
#   [OK] https://skforecast.org/0.20.0/api/utils#skforecast.utils.utils.load_forecaster
#   [OK] https://skforecast.org/0.20.0/api/utils#skforecast.utils.utils.load_forecaster
#   [OK] https://github.com/skforecast/skforecast/issues/1079
#   [OK] https://skforecast.org/0.20.0/user_guides/migration-guide
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursiveclassifier
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/autoregressive-classification-forecasting
#   [OK] https://skforecast.org/0.20.0/api/drift_detection#skforecast.drift_detection._population_drift.PopulationDriftDetector
#   [OK] https://skforecast.org/0.20.0/api/drift_detection
#   [OK] https://skforecast.org/0.20.0/user_guides/drift-detection
#   [OK] https://skforecast.org/0.20.0/api/stats
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-sarimax-arima
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._arar.Arar
#   [OK] https://skforecast.org/0.20.0/api/stats
#   [OK] https://skforecast.org/0.20.0/user_guides/forecasting-arar
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._sarimax.Sarimax
#   [OK] https://skforecast.org/0.20.0/api/stats
#   [OK] https://skforecast.org/0.20.0/user_guides/migration-guide
#   [OK] https://skforecast.org/0.19.0/api/forecastersarimax
#   [OK] https://skforecast.org/0.20.0/api/forecasterstats
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/migration-guide
#   [OK] https://github.com/skforecast/skforecast/issues/1051
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursiveclassifier
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/api/drift_detection#skforecast.drift_detection._population_drift.PopulationDriftDetector
#   [OK] https://skforecast.org/0.20.0/api/drift_detection
#   [OK] https://skforecast.org/0.20.0/api/stats
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._arar.Arar
#   [OK] https://skforecast.org/0.20.0/api/stats
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.reshape_series_exog_dict_to_long
#   [OK] https://skforecast.org/0.20.0/api/preprocessing
#   [OK] https://skforecast.org/0.20.0/api/datasets
#   [OK] https://skforecast.org/0.20.0/user_guides/migration-guide
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._sarimax.Sarimax
#   [OK] https://skforecast.org/0.20.0/api/stats
#   [OK] https://skforecast.org/0.20.0/user_guides/migration-guide
#   [OK] https://skforecast.org/0.19.0/api/forecastersarimax
#   [OK] https://skforecast.org/0.20.0/api/forecasterstats
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/user_guides/migration-guide
#   [OK] https://github.com/skforecast/skforecast/issues/1051
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.TimeSeriesFold
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting#backtesting-with-fold-stride
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [ERROR] Roto: https://skforecast.org/0.19.0/api/model_selection.md#skforecast.model_selection._validation.backtesting_sarimax (Status 404)
#   [OK] https://github.com/skforecast/skforecast/issues/764
#   [OK] https://skforecast.org/0.20.0/api/drift_detection
#   [OK] https://skforecast.org/0.20.0/api/drift_detection#skforecast.drift_detection._range_drift.RangeDriftDetector
#   [OK] https://skforecast.org/0.20.0/user_guides/drift-detection
#   [OK] https://skforecast.org/0.20.0/api/plot#skforecast.plot.plot.backtesting_gif_creator
#   [OK] https://skforecast.org/0.20.0/api/plot
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting#create-your-own-backtesting-gif
#   [OK] https://skforecast.org/0.20.0/api/datasets#skforecast.datasets.show_datasets_info
#   [OK] https://skforecast.org/0.20.0/user_guides/datasets
#   [OK] https://skforecast.org/0.20.0/quick-start/forecaster-attributes#skforecast-tags
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] https://github.com/skforecast/skforecast/issues/1028
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://github.com/skforecast/skforecast/issues/1039
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.TimeSeriesFold
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting#backtesting-with-fold-stride
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [ERROR] Roto: https://skforecast.org/0.19.0/api/model_selection.md#skforecast.model_selection._validation.backtesting_sarimax (Status 404)
#   [OK] https://github.com/skforecast/skforecast/issues/764
#   [OK] https://skforecast.org/0.20.0/api/drift_detection
#   [OK] https://skforecast.org/0.20.0/api/drift_detection#skforecast.drift_detection._range_drift.RangeDriftDetector
#   [OK] https://skforecast.org/0.20.0/user_guides/drift-detection
#   [OK] https://skforecast.org/0.20.0/api/plot#skforecast.plot.plot.backtesting_gif_creator
#   [OK] https://skforecast.org/0.20.0/api/plot
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting#create-your-own-backtesting-gif
#   [OK] https://skforecast.org/0.20.0/api/datasets#skforecast.datasets.show_datasets_info
#   [OK] https://skforecast.org/0.20.0/user_guides/datasets
#   [OK] https://skforecast.org/0.20.0/quick-start/forecaster-attributes#skforecast-tags
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] https://github.com/skforecast/skforecast/issues/1028
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://github.com/skforecast/skforecast/issues/1039
#   [OK] https://skforecast.org/0.20.0/api/forecasterequivalentdate
#   [OK] https://skforecast.org/0.20.0/api/experimental
#   [OK] https://skforecast.org/0.20.0/api/forecasterrnn
#   [OK] https://skforecast.org/0.20.0/api/forecasterrnn#skforecast.deep_learning.utils.create_and_compile_model
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.reshape_series_long_to_dict
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.reshape_exog_long_to_dict
#   [OK] https://skforecast.org/0.20.0/api/preprocessing
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.OneStepAheadFold
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.OneStepAheadFold
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.reshape_series_wide_to_long
#   [OK] https://skforecast.org/0.20.0/api/preprocessing
#   [OK] https://skforecast.org/0.20.0/api/metrics#skforecast.metrics.symmetric_mean_absolute_percentage_error
#   [OK] https://skforecast.org/0.20.0/api/metrics
#   [OK] https://skforecast.org/0.20.0/api/forecasterequivalentdate
#   [OK] https://skforecast.org/0.20.0/api/experimental
#   [OK] https://skforecast.org/0.20.0/api/experimental#skforecast.experimental._experimental.calculate_distance_from_holiday
#   [OK] https://skforecast.org/0.20.0/api/experimental
#   [OK] https://skforecast.org/0.20.0/api/forecasterrnn
#   [OK] https://skforecast.org/0.20.0/api/forecasterrnn#skforecast.deep_learning.utils.create_and_compile_model
#   [OK] https://skforecast.org/0.20.0/api/forecasterrnn
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.reshape_series_long_to_dict
#   [OK] https://skforecast.org/0.20.0/api/preprocessing
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.reshape_exog_long_to_dict
#   [OK] https://skforecast.org/0.20.0/api/preprocessing
#   [OK] https://skforecast.org/0.20.0/api/forecasterrnn#skforecast.deep_learning.utils.create_and_compile_model
#   [OK] https://skforecast.org/0.20.0/api/forecasterrnn
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.OneStepAheadFold
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.OneStepAheadFold
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-conformal-prediction
#   [OK] https://mapie.readthedocs.io/en/stable/theoretical_description_regression.html#the-split-method
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-bootstrapped-residuals#intervals-conditioned-on-predicted-values-binned-residuals
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirect
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.ConformalIntervalCalibrator
#   [OK] https://skforecast.org/0.20.0/user_guides/probabilistic-forecasting-conformal-calibration
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.ConformalIntervalCalibrator
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirect
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting#differentiation
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.RollingFeatures
#   [OK] https://skforecast.org/0.19.0/api/forecastersarimax
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.TimeSeriesFold
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.OneStepAheadFold
#   [OK] https://skforecast.org/0.16.0/api/preprocessing#skforecast.preprocessing.preprocessing.exog_long_to_dict
#   [OK] https://skforecast.org/0.20.0/api/plot#skforecast.plot.plot.calculate_lag_autocorrelation
#   [OK] https://skforecast.org/0.20.0/api/plot
#   [OK] https://skforecast.org/0.20.0/api/datasets
#   [OK] https://skforecast.org/0.20.0/api/metrics
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.OneStepAheadFold
#   [OK] https://skforecast.org/0.20.0/api/model_selection
#   [OK] https://skforecast.org/0.20.0/api/exceptions
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.13.0/api/forecasterautoregcustom
#   [OK] https://skforecast.org/0.13.0/api/forecastermultiseriescustom
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirect
#   [OK] https://skforecast.org/0.20.0/api/forecasterdirectmultivariate
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.16.0/api/preprocessing#skforecast.preprocessing.preprocessing.exog_long_to_dict
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.TimeSeriesFold
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.OneStepAheadFold
#   [OK] https://github.com/g-rubio
#   [OK] https://github.com/skforecast/skforecast/pull/898
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/user_guides/migration-guide
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.RollingFeatures
#   [OK] https://skforecast.org/0.20.0/user_guides/window-features-and-custom-features
#   [OK] https://skforecast.org/0.20.0/api/model_selection
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.TimeSeriesFold
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.OneStepAheadFold
#   [OK] https://skforecast.org/0.20.0/user_guides/hyperparameter-tuning-and-lags-selection#one-step-ahead-validation
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.OneStepAheadFold
#   [OK] https://skforecast.org/0.20.0/api/model_selection
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/user_guides/exogenous-variables#handling-missing-exogenous-data-in-initial-training-periods
#   [OK] https://skforecast.org/0.20.0/user_guides/migration-guide
#   [OK] https://skforecast.org/0.13.0/api/forecasterautoregcustom
#   [OK] https://skforecast.org/0.20.0/user_guides/window-features-and-custom-features
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.19.0/api/forecastersarimax
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._sarimax.Sarimax
#   [OK] https://skforecast.org/0.20.0/api/preprocessing#skforecast.preprocessing.preprocessing.RollingFeatures
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.OneStepAheadFold
#   [OK] https://skforecast.org/0.20.0/api/model_selection
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/api/model_selection
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://github.com/imMoya
#   [OK] https://github.com/skforecast/skforecast/pull/811
#   [OK] https://skforecast.org/0.20.0/api/forecasterrnn#skforecast.deep_learning.utils.create_and_compile_model
#   [OK] https://github.com/pablorodriper
#   [OK] https://github.com/skforecast/skforecast/pull/824
#   [OK] https://skforecast.org/0.13.0/api/forecasterautoregcustom
#   [OK] https://skforecast.org/0.13.0/api/forecastermultiseriescustom
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursive
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/forecasterrecursivemultiseries
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._search.bayesian_search_forecaster
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._search.bayesian_search_forecaster_multiseries
#   [OK] https://skforecast.org/0.19.0/api/forecastersarimax
#   [OK] https://skforecast.org/0.20.0/api/stats#skforecast.stats._sarimax.Sarimax
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/model_selection
#   [OK] https://skforecast.org/0.20.0/api/model_selection
#   [OK] https://skforecast.org/0.20.0/api/model_selection
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.TimeSeriesFold
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._split.OneStepAheadFold
#   [OK] https://skforecast.org/0.20.0/api/feature_selection
#   [OK] https://skforecast.org/0.20.0/api/feature_selection#skforecast.feature_selection.feature_selection.select_features
#   [OK] https://skforecast.org/0.20.0/api/feature_selection#skforecast.feature_selection.feature_selection.select_features_multiseries
#   [OK] https://skforecast.org/0.20.0/api/feature_selection#skforecast.feature_selection.feature_selection.select_features
#   [OK] https://skforecast.org/0.20.0/api/feature_selection#skforecast.feature_selection.feature_selection.select_features_multiseries
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.13.0/api/forecastermultiseries
#   [OK] https://skforecast.org/0.13.0/api/forecastermultiseriescustom
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting#forecasting-unknown-series
#   [OK] https://skforecast.org/0.13.0/api/forecastermultiseries
#   [OK] https://skforecast.org/0.13.0/api/forecastermultiseriescustom
#   [OK] https://skforecast.org/0.20.0/user_guides/independent-multi-time-series-forecasting#series-encoding-in-multi-series
#   [OK] https://skforecast.org/0.20.0/api/metrics
#   [OK] https://skforecast.org/0.20.0/api/metrics#skforecast.metrics.mean_absolute_scaled_error
#   [OK] https://skforecast.org/0.20.0/api/metrics#skforecast.metrics.root_mean_squared_scaled_error
#   [OK] https://skforecast.org/0.20.0/user_guides/metrics
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] https://skforecast.org/0.20.0/api/model_selection
#   [OK] https://skforecast.org/0.13.0/api/model_selection_multiseries
#   [OK] https://skforecast.org/0.20.0/user_guides/backtesting#backtesting-with-skip-folds
#   [OK] https://skforecast.org/0.13.0/api/forecastermultiseries
#   [OK] https://skforecast.org/0.13.0/api/forecastermultiseriescustom
#   [OK] https://skforecast.org/0.20.0/api/forecasterrnn
#   [OK] https://skforecast.org/0.20.0/api/forecasterrnn
#   [OK] https://skforecast.org/0.20.0/api/plot#skforecast.plot.plot.plot_prediction_intervals
#   [OK] https://skforecast.org/0.20.0/api/plot
#   [OK] https://skforecast.org/0.20.0/api/metrics
#   [OK] https://skforecast.org/0.20.0/api/model_selection
#   [OK] https://skforecast.org/0.13.0/api/model_selection_multiseries
#   [OK] https://skforecast.org/0.20.0/api/plot#skforecast.plot.plot.plot_prediction_intervals
#   [OK] https://skforecast.org/0.20.0/api/plot
#   [OK] https://skforecast.org/0.13.0/api/forecastermultiseries
#   [OK] https://skforecast.org/0.13.0/api/forecastermultiseriescustom
#   [OK] https://skforecast.org/0.13.0/api/forecastermultiseries
#   [OK] https://skforecast.org/0.13.0/api/forecastermultiseriescustom
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._search.grid_search_forecaster_multiseries
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._search.random_search_forecaster_multiseries
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._search.bayesian_search_forecaster_multiseries
#   [OK] https://skforecast.org/0.13.0/api/preprocessing#skforecast.preprocessing.DateTimeFeatureTransformer
#   [OK] https://skforecast.org/0.13.0/api/preprocessing#skforecast.preprocessing.create_datetime_features
#   [OK] https://skforecast.org/0.20.0/api/preprocessing
#   [OK] https://skforecast.org/0.20.0/quick-start/how-to-install
#   [OK] https://skforecast.org/0.13.0/api/forecasterautoreg
#   [OK] https://skforecast.org/0.13.0/api/forecastermultiseries
#   [OK] https://skforecast.org/0.13.0/api/forecastermultiseriescustom
#   [OK] https://skforecast.org/0.20.0/api/model_selection
#   [OK] https://skforecast.org/0.20.0/api/metrics
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] https://skforecast.org/0.20.0/api/utils
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster
#   [ERROR] Roto: https://skforecast.org/0.19.0/api/model_selection.md#skforecast.model_selection._validation.backtesting_sarimax (Status 404)
#   [OK] https://skforecast.org/0.20.0/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] https://skforecast.org/0.13.0/api/forecastermultiseries
#   [OK] https://skforecast.org/0.13.0/api/forecastermultiseriescustom
#   [OK] https://skforecast.org/latest/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] https://skforecast.org/latest/user_guides/feature-selection
#   [OK] https://skforecast.org/latest/api/model_selection#skforecast.model_selection.model_selection.select_features
#   [OK] https://skforecast.org/0.12.0/api/model_selection_multiseries#skforecast.model_selection_multiseries.model_selection_multiseries.select_features_multiseries
#   [OK] https://skforecast.org/latest/api/forecasterrnn
#   [OK] https://skforecast.org/latest/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] https://skforecast.org/0.12.0/user_guides/probabilistic-forecasting#intervals-conditioned-on-predicted-values-binned-residuals
#   [OK] https://skforecast.org/0.12.0/api/forecasterautoreg
#   [OK] https://skforecast.org/latest/user_guides/independent-multi-time-series-forecasting#hyperparameter-tuning-and-lags-selection-multi-series
#   [OK] https://skforecast.org/latest/user_guides/time-series-differentiation
#   [OK] https://skforecast.org/0.12.0/api/forecastermultiseries
#   [OK] https://skforecast.org/0.12.0/api/forecastermultiseriescustom
#   [OK] https://skforecast.org/0.12.0/api/forecastermultivariate
#   [OK] https://github.com/Metaming
#   [OK] http://alkaline-ml.com/pmdarima/modules/generated/pmdarima.arima.ARIMA.html#pmdarima.arima.ARIMA
#   [OK] https://github.com/Pablo-Davila
#   [OK] https://github.com/Bennett561
#   [OK] https://github.com/tkaraouzene
#   [OK] https://github.com/Pablo-Davila
#   [OK] https://skforecast.org
#   [OK] https://github.com/skforecast/skforecast#introduction
#   [OK] https://github.com/skforecast/skforecast#introduction
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/more/about-skforecast.html
# Comprobando 33 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://github.com/skforecast/skforecast
#   [OK] https://www.linkedin.com/company/skforecast/
#   [OK] https://discord.gg/3V52qpNkuj
#   [OK] https://cienciadedatos.net/en/forecasting-python
#   [OK] https://github.com/skforecast/skforecast
#   [OK] https://github.com/JoaquinAmatRodrigo
#   [ERROR] Roto: https://www.linkedin.com/in/joaquin-amat-rodrigo (Status 999)
#   [OK] https://github.com/JavierEscobarOrtiz
#   [ERROR] Roto: https://www.linkedin.com/in/javier-escobar-ortiz (Status 999)
#   [OK] https://github.com/FernandoCarazoMelo
#   [OK] https://github.com/Akai01
#   [OK] https://github.com/skforecast/skforecast/graphs/contributors
#   [OK] https://github.com/skforecast/skforecast/issues
#   [OK] https://github.com/skforecast/skforecast/blob/master/CONTRIBUTING.md
#   [OK] https://github.com/josh-wong
#   [OK] https://github.com/edgBR
#   [OK] https://github.com/syndct
#   [OK] https://github.com/KishManani
#   [OK] https://github.com/Sergio-Quijano-Stratesys
#   [OK] https://github.com/schoulten
#   [OK] https://github.com/tyg3rr
#   [OK] https://github.com/IvanLiuTW
#   [OK] https://github.com/imMoya
#   [OK] https://github.com/pablorodriper
#   [OK] https://github.com/g-rubio
#   [OK] https://github.com/GinesMeca
#   [OK] https://zenodo.org/doi/10.5281/zenodo.8382787
#   [OK] https://github.com/skforecast/skforecast/blob/master/CITATION.cff
#   [OK] https://github.com/skforecast/skforecast/blob/master/LICENSE
#   [OK] https://github.com/skforecast/skforecast/blob/master/LICENSE
#   [OK] https://creativecommons.org/licenses/by-nc-sa/4.0/
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/more/consulting.html
# Comprobando 7 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://www.linkedin.com/company/skforecast/
#   [OK] https://discord.gg/3V52qpNkuj
#   [OK] https://cienciadedatos.net/en/forecasting-python
#   [ERROR] Roto: https://www.linkedin.com/in/joaquin-amat-rodrigo (Status 999)
#   [ERROR] Roto: https://www.linkedin.com/in/javier-escobar-ortiz (Status 999)
#   [OK] https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.20.0/more/funding.html
# Comprobando 11 enlaces...
#   [OK] https://skforecast.org/
#   [OK] https://www.buymeacoffee.com/skforecast
#   [OK] https://github.com/sponsors/JoaquinAmatRodrigo
#   [OK] https://github.com/sponsors/JavierEscobarOrtiz
#   [OK] https://www.paypal.com/donate/?hosted_button_id=D2JZSWRLTZDL6
#   [OK] https://www.linkedin.com/company/skforecast/
#   [OK] https://discord.gg/3V52qpNkuj
#   [OK] https://cienciadedatos.net/en/forecasting-python
#   [ERROR] Roto: https://www.linkedin.com/in/joaquin-amat-rodrigo (Status 999)
#   [ERROR] Roto: https://www.linkedin.com/in/javier-escobar-ortiz (Status 999)
#   [OK] https://squidfunk.github.io/mkdocs-material/
#
#
#
# ================================================================================
# RESUMEN DE ENLACES ROTOS
# ================================================================================
#
# [Origen] https://skforecast.org/0.20.0/
#    [HTTPSConnectionPool(host='www.revista.ister.edu.ec', port=443): Max retries exceeded with url: /ojs/index.php/ISTER/article/view/126 (Caused by SSLError(SSLCertVerificationError(1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'www.revista.ister.edu.ec'. (_ssl.c:1010)")))] https://doi.org/10.37431/conectividad.v5i2.126
#    [Status 403] https://doi.org/10.3390/en16031495
#    [Status 403] https://doi.org/10.3390/en16186726
#    [Status 403] https://doi.org/10.3390/en16186731
#
# [Origen] https://skforecast.org/0.20.0/releases/releases.html
#    [Status 404] https://skforecast.org/0.19.0/api/model_selection.md#skforecast.model_selection._validation.backtesting_sarimax
#    [Status 404] https://skforecast.org/0.19.0/api/model_selection.md#skforecast.model_selection._validation.backtesting_sarimax
#    [Status 404] https://skforecast.org/0.19.0/api/model_selection.md#skforecast.model_selection._validation.backtesting_sarimax
#
# [Origen] https://skforecast.org/0.20.0/more/about-skforecast.html
#    [Status 999] https://www.linkedin.com/in/joaquin-amat-rodrigo
#    [Status 999] https://www.linkedin.com/in/javier-escobar-ortiz
#
# [Origen] https://skforecast.org/0.20.0/more/consulting.html
#    [Status 999] https://www.linkedin.com/in/joaquin-amat-rodrigo
#    [Status 999] https://www.linkedin.com/in/javier-escobar-ortiz
#
# [Origen] https://skforecast.org/0.20.0/more/funding.html
#    [Status 999] https://www.linkedin.com/in/joaquin-amat-rodrigo
#    [Status 999] https://www.linkedin.com/in/javier-escobar-ortiz
#
# ================================================================================
