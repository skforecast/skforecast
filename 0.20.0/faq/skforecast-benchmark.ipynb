# %% [markdown]
# # Benchmarking skforecast
#
# Benchmarking is an essential part of the development process of **skforecast**. It provides a transparent view of how the **performance of the library** evolves across versions and helps users make informed decisions when choosing the right forecaster or configuration for their use case.
#
# In this section, we present benchmark results that measure the execution time of key methods (`fit`, `predict`, etc.) and their **performance evolution across versions**, allowing the detection of improvements or regressions.
#
# ## Methodology
#
# The benchmarking results presented here are generated using a **custom benchmarking script** located in the `benchmarks/` directory of the repository. This script executes a series of performance tests for the main forecasting classes and their methods, recording both execution time and variability across multiple runs.
#
# To ensure **consistency and reproducibility**, all benchmarks are automatically executed as part of the continuous integration (CI) pipeline using GitHub Actions. This guarantees that each new release of the library is tested under the **same environment and dependency configuration**, making performance results directly comparable across versions.
#
# Users who wish to reproduce the benchmarks locally can execute the same script by running:
#
# ```bash
# # From skforecast root directory
# python benchmarks/run_benchmarks.py
# ```
#
# Results are stored in a structured format in `benchmarks/benchmarks.joblib`.

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background: rgba(255,145,0,.1); padding-top: 0px; padding-bottom: 6px; border-radius: 8px; border-left: 8px solid #ff9100; border-color: #ff9100; padding-left: 10px; padding-right: 10px">
#
# <p class="title">
#     <i style="font-size: 18px; color:#ff9100; border-color: #ff1744;"></i>
#     <b style="color: #ff9100;"> <span style="color: #ff9100;">&#9888;</span> Warning</b>
# </p>
#
# The <code>plot_benchmark_results</code> function is located at the end of the notebook. <a href="#plot-function">Go to plot function</a>.
#
# </div>

# %%
# Libraries
# ==============================================================================
import platform
import psutil
import numpy as np
import pandas as pd
import joblib

import sklearn
import skforecast

# Display all columns in pandas
pd.set_option("display.max_columns", None)

# %%
# Environment information
# ==============================================================================
print(f"Python version           : {platform.python_version()}")
print(f"skforecast version       : {skforecast.__version__}")
print(f"numpy version            : {np.__version__}")
print(f"pandas version           : {pd.__version__}")
print(f"scikit-learn version     : {sklearn.__version__}")
print(f"Computer network name    : {platform.node()}")
print(f"Processor type           : {platform.processor()}")
print(f"Platform type            : {platform.platform()}")
print(f"Number of physical cores : {psutil.cpu_count(logical=False)}")
print(f"Number of logical cores  : {psutil.cpu_count(logical=True)}")
print(f"Memory total             : {round(psutil.virtual_memory().total / 1e9, 2)} GB")
# Out:
# Python version           : 3.13.11
# skforecast version       : 0.20.0
# numpy version            : 2.3.5
# pandas version           : 2.3.3
# scikit-learn version     : 1.8.0
# Computer network name    : ITES015-NB0029
# Processor type           : Intel64 Family 6 Model 141 Stepping 1, GenuineIntel
# Platform type            : Windows-11-10.0.26100-SP0
# Number of physical cores : 8
# Number of logical cores  : 16
# Memory total             : 34.07 GB

# %%
import warnings
warnings.filterwarnings(
    "ignore",
    category=FutureWarning,
    message="'force_all_finite' was renamed to 'ensure_all_finite'"
)

# %% [markdown]
# ## Global results

# %%
# Load benchmark results
# ==============================================================================
results_benchmark_all = joblib.load("../../benchmarks/benchmark.joblib")
print("Shape:", results_benchmark_all.shape)
results_benchmark_all.head(2)
# Out:
# Shape: (1951, 21)
#        forecaster_name  estimator_name                          function_name  \
# 0  ForecasterRecursive  DummyRegressor  ForecasterRecursive__create_train_X_y
# 1  ForecasterRecursive  DummyRegressor                ForecasterRecursive_fit
#
#                       function_hash        method_name  run_time_avg  \
# 0  59b823f1ff395872fac4f7578bd859fa  _create_train_X_y      0.004280
# 1  9d73eaf5faa980194d715362601eed68                fit      0.005956
#
#    run_time_median  run_time_p95  run_time_std  n_repeats  \
# 0         0.004191      0.004524      0.000344         30
# 1         0.005379      0.008166      0.001107         10
#
#                     datetime python_version skforecast_version numpy_version  \
# 0 2025-08-26 06:59:07.003048        3.12.11             0.17.0         2.1.3
# 1 2025-08-26 06:59:07.066656        3.12.11             0.17.0         2.1.3
#
#   pandas_version sklearn_version lightgbm_version  \
# 0          2.3.2           1.6.1            4.6.0
# 1          2.3.2           1.6.1            4.6.0
#
#                                         platform processor  cpu_count  \
# 0  Linux-6.11.0-1018-azure-x86_64-with-glibc2.39    x86_64          4
# 1  Linux-6.11.0-1018-azure-x86_64-with-glibc2.39    x86_64          4
#
#    memory_gb
# 0      16.77
# 1      16.77

# %% [markdown]
# ## ForecasterRecursive
#
# The [`ForecasterRecursive` class](https://skforecast.org/latest/user_guides/autoregressive-forecaster.html) is benchmarked under a fixed experimental setup to ensure fair comparison across library versions. Key conditions are:
#
# | Condition           | Value                                                                                |
# |:--------------------|:-------------------------------------------------------------------------------------|
# | Estimator           | `sklearn.dummy.DummyRegressor` (to isolate forecaster overhead)                      |
# | Dataset length      | 2000 synthetic observations (generated with `bench_forecaster_recursive._make_data`) |
# | Lags as predictors  | 50                                                                                   |
# | Exogenous features  | 3                                                                                    |
# | Data transformation | `StandardScaler()` for time series features and exogenous variables                  |
# | Prediction horizon  | 100 steps ahead                                                                      |
# | Backtesting split   | 1200 training, remaining for testing, step size = 50, no re-fitting (see [guide](https://skforecast.org/latest/user_guides/backtesting.html)) |
#
# **Note:** In versions `< 0.14.0`, `ForecasterRecursive` was named `ForecasterAutoreg`.

# %%
# Plot benchmark results
# ==============================================================================
plot_benchmark_results(
    results_benchmark_all,
    forecaster_names = ['ForecasterRecursive', 'ForecasterAutoreg'],
    estimators       = ['DummyRegressor', 'LinearRegression'],
    add_mean         = True,
    add_median       = True
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="f6175785-3216-443b-99e5-258150b3fbd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f6175785-3216-443b-99e5-258150b3fbd9")) {                    Plotly.newPlot(                        "f6175785-3216-443b-99e5-258150b3fbd9",                        [{"error_y":{"array":{"dtype":"f8","bdata":"soYjLinYND\u002fcaBeLQBA0P01wTlL8mjM\u002fPINNe9HcMj8="},"color":"#636EFA","thickness":1.5,"type":"data","visible":true,"width":5},"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#636EFA","line":{"color":"white","width":1},"opacity":0.85,"size":10},"mode":"markers","text":["Forecaster: ForecasterRecursive\u003cbr\u003eEstimator: DummyRegressor\u003cbr\u003eFunction: ForecasterRecursive__create_train_X_y\u003cbr\u003eFunction_hash: 59b823f1ff395872fac4f7578bd859fa\u003cbr\u003eMethod: _create_train_X_y\u003cbr\u003eDatetime: 2025-08-26 09:16:24.501701\u003cbr\u003ePython version: 3.12.11\u003cbr\u003eskforecast version: 0.15.1\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.2\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 0.004335 s\u003cbr\u003eRun time median: 0.004245 s\u003cbr\u003eRun time p95: 0.004673 s\u003cbr\u003eRun time std: 0.000318 s\u003cbr\u003eN\u00ba repeats: 30","Forecaster: ForecasterRecursive\u003cbr\u003eEstimator: DummyRegressor\u003cbr\u003eFunction: ForecasterRecursive__create_train_X_y\u003cbr\u003eFunction_hash: 59b823f1ff395872fac4f7578bd859fa\u003cbr\u003eMethod: _create_train_X_y\u003cbr\u003eDatetime: 2025-08-26 09:32:24.754428\u003cbr\u003ePython version: 3.12.11\u003cbr\u003eskforecast version: 0.15.1\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.2\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 0.004331 s\u003cbr\u003eRun time median: 0.004265 s\u003cbr\u003eRun time p95: 0.004510 s\u003cbr\u003eRun time std: 0.000306 s\u003cbr\u003eN\u00ba repeats: 30","Forecaster: ForecasterRecursive\u003cbr\u003eEstimator: DummyRegressor\u003cbr\u003eFunction: ForecasterRecursive__create_train_X_y\u003cbr\u003eFunction_hash: 59b823f1ff395872fac4f7578bd859fa\u003cbr\u003eMethod: _create_train_X_y\u003cbr\u003eDatetime: 2025-08-26 09:45:16.117787\u003cbr\u003ePython version: 3.12.11\u003cbr\u003eskforecast version: 0.15.1\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.2\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 0.004295 s\u003cbr\u003eRun time median: 0.004229 s\u003cbr\u003eRun time p95: 0.004443 s\u003cbr\u003eRun time std: 0.000299 s\u003cbr\u003eN\u00ba repeats: 30","Forecaster: ForecasterRecursive\u003cbr\u003eEstimator: DummyRegressor\u003cbr\u003eFunction: ForecasterRecursive__create_train_X_y\u003cbr\u003eFunction_hash: 59b823f1ff395872fac4f7578bd859fa\u003cbr\u003eMethod: _create_train_X_y\u003cbr\u003eDatetime: 2025-08-26 10:08:51.281682\u003cbr\u003ePython version: 3.12.11\u003cbr\u003eskforecast version: 0.15.1\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.2\u003cbr\u003esklearn version: 1.6.1\u003cbr ...

# %% [markdown]
# ## ForecasterDirect
#
# The [`ForecasterDirect` class](https://skforecast.org/latest/user_guides/direct-multi-step-forecasting.html) is benchmarked under a fixed experimental setup to ensure fair comparison across library versions. Key conditions are:
#
# | Condition           | Value                                                                                |
# |:--------------------|:-------------------------------------------------------------------------------------|
# | Estimator           | `sklearn.dummy.DummyRegressor` (to isolate forecaster overhead)                      |
# | Dataset length      | 2000 synthetic observations (generated with `bench_forecaster_direct._make_data`)    |
# | Lags as predictors  | 20                                                                                   |
# | Exogenous features  | 3                                                                                    |
# | Data transformation | `StandardScaler()` for time series features and exogenous variables                  |
# | Prediction horizon  | 10 steps ahead (10 estimators)                                                       |
# | Backtesting split   | 1200 training, remaining for testing, step size = 10, no re-fitting (see [guide](https://skforecast.org/latest/user_guides/backtesting.html)) |
#
# **Note:** In versions `< 0.14.0`, `ForecasterDirect` was named `ForecasterAutoregDirect`.

# %%
# Plot benchmark results
# ==============================================================================
plot_benchmark_results(
    results_benchmark_all,
    forecaster_names = ['ForecasterDirect', 'ForecasterAutoregDirect'],
    estimators       = ['DummyRegressor'],
    add_mean         = True,
    add_median       = True
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="b90d8ef5-627d-49d0-ad3f-6582a10d117e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b90d8ef5-627d-49d0-ad3f-6582a10d117e")) {                    Plotly.newPlot(                        "b90d8ef5-627d-49d0-ad3f-6582a10d117e",                        [{"error_y":{"array":{"dtype":"f8","bdata":"grFYcZRtGT8SROp1Bs40P52LZtDoDh0\u002f+5BOvH6oGT8="},"color":"#636EFA","thickness":1.5,"type":"data","visible":true,"width":5},"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#636EFA","line":{"color":"white","width":1},"opacity":0.85,"size":10},"mode":"markers","text":["Forecaster: ForecasterDirect\u003cbr\u003eEstimator: DummyRegressor\u003cbr\u003eFunction: ForecasterDirect__create_train_X_y\u003cbr\u003eFunction_hash: b27d0379b7b474b819c78e1534c516f2\u003cbr\u003eMethod: _create_train_X_y\u003cbr\u003eDatetime: 2025-08-26 09:26:38.097253\u003cbr\u003ePython version: 3.12.11\u003cbr\u003eskforecast version: 0.15.1\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.2\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 0.004872 s\u003cbr\u003eRun time median: 0.004844 s\u003cbr\u003eRun time p95: 0.004946 s\u003cbr\u003eRun time std: 0.000097 s\u003cbr\u003eN\u00ba repeats: 30","Forecaster: ForecasterDirect\u003cbr\u003eEstimator: DummyRegressor\u003cbr\u003eFunction: ForecasterDirect__create_train_X_y\u003cbr\u003eFunction_hash: b27d0379b7b474b819c78e1534c516f2\u003cbr\u003eMethod: _create_train_X_y\u003cbr\u003eDatetime: 2025-08-26 09:42:57.366018\u003cbr\u003ePython version: 3.12.11\u003cbr\u003eskforecast version: 0.15.1\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.2\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 0.005200 s\u003cbr\u003eRun time median: 0.005055 s\u003cbr\u003eRun time p95: 0.005882 s\u003cbr\u003eRun time std: 0.000317 s\u003cbr\u003eN\u00ba repeats: 30","Forecaster: ForecasterDirect\u003cbr\u003eEstimator: DummyRegressor\u003cbr\u003eFunction: ForecasterDirect__create_train_X_y\u003cbr\u003eFunction_hash: b27d0379b7b474b819c78e1534c516f2\u003cbr\u003eMethod: _create_train_X_y\u003cbr\u003eDatetime: 2025-08-26 09:55:38.254694\u003cbr\u003ePython version: 3.12.11\u003cbr\u003eskforecast version: 0.15.1\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.2\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 0.004863 s\u003cbr\u003eRun time median: 0.004834 s\u003cbr\u003eRun time p95: 0.004952 s\u003cbr\u003eRun time std: 0.000111 s\u003cbr\u003eN\u00ba repeats: 30","Forecaster: ForecasterDirect\u003cbr\u003eEstimator: DummyRegressor\u003cbr\u003eFunction: ForecasterDirect__create_train_X_y\u003cbr\u003eFunction_hash: b27d0379b7b474b819c78e1534c516f2\u003cbr\u003eMethod: _create_train_X_y\u003cbr\u003eDatetime: 2025-08-26 10:19:08.700698\u003cbr\u003ePython version: 3.12.11\u003cbr\u003eskforecast version: 0.15.1\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.2\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0 ...

# %% [markdown]
# ## ForecasterRecursiveClassifier
#
# The [`ForecasterRecursiveClassifier` class](https://skforecast.org/latest/user_guides/autoregressive-classification-forecasting.html) is benchmarked under a fixed experimental setup to ensure fair comparison across library versions. Key conditions are:
#
# | Condition           | Value                                                                                           |
# |:--------------------|:------------------------------------------------------------------------------------------------|
# | Estimator           | `sklearn.dummy.DummyClassifier` (to isolate forecaster overhead)                                |
# | Dataset length      | 2000 synthetic observations (generated with `bench_forecaster_recursive_classifier._make_data`) |
# | Lags as predictors  | 50                                                                                              |
# | Exogenous features  | 3                                                                                               |
# | Data transformation | `StandardScaler()` for exogenous variables                                                      |
# | Prediction horizon  | 100 steps ahead                                                                                 |
# | Backtesting split   | 1200 training, remaining for testing, step size = 50, no re-fitting (see [guide](https://skforecast.org/latest/user_guides/backtesting.html)) |

# %%
# Plot benchmark results
# ==============================================================================
plot_benchmark_results(
    results_benchmark_all,
    forecaster_names = ['ForecasterRecursiveClassifier'],
    estimators       = ['DummyClassifier'],
    add_mean         = True,
    add_median       = True
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="cf8b73ca-604c-4c68-8553-5ccf11bc594f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("cf8b73ca-604c-4c68-8553-5ccf11bc594f")) {                    Plotly.newPlot(                        "cf8b73ca-604c-4c68-8553-5ccf11bc594f",                        [{"error_y":{"array":{"dtype":"f8","bdata":"CO1IVSqw5z7ydrgPJzLtPtxIZgFqgPQ+jwpDmT\u002f08D6FHnakJ4XrPg=="},"color":"#636EFA","thickness":1.5,"type":"data","visible":true,"width":5},"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#636EFA","line":{"color":"white","width":1},"opacity":0.85,"size":10},"mode":"markers","text":["Forecaster: ForecasterRecursiveClassifier\u003cbr\u003eEstimator: DummyClassifier\u003cbr\u003eFunction: ForecasterRecursiveClassifier__create_lags\u003cbr\u003eFunction_hash: e480650afd0f0c4bf90a8d9084fcf6ec\u003cbr\u003eMethod: _create_lags\u003cbr\u003eDatetime: 2025-11-27 13:26:59.098012\u003cbr\u003ePython version: 3.12.12\u003cbr\u003eskforecast version: 0.19.0\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.3\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 0.000213 s\u003cbr\u003eRun time median: 0.000210 s\u003cbr\u003eRun time p95: 0.000233 s\u003cbr\u003eRun time std: 0.000011 s\u003cbr\u003eN\u00ba repeats: 30","Forecaster: ForecasterRecursiveClassifier\u003cbr\u003eEstimator: DummyClassifier\u003cbr\u003eFunction: ForecasterRecursiveClassifier__create_lags\u003cbr\u003eFunction_hash: e480650afd0f0c4bf90a8d9084fcf6ec\u003cbr\u003eMethod: _create_lags\u003cbr\u003eDatetime: 2025-11-27 14:00:05.435947\u003cbr\u003ePython version: 3.12.12\u003cbr\u003eskforecast version: 0.19.0\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.3\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 0.000207 s\u003cbr\u003eRun time median: 0.000201 s\u003cbr\u003eRun time p95: 0.000232 s\u003cbr\u003eRun time std: 0.000014 s\u003cbr\u003eN\u00ba repeats: 30","Forecaster: ForecasterRecursiveClassifier\u003cbr\u003eEstimator: DummyClassifier\u003cbr\u003eFunction: ForecasterRecursiveClassifier__create_lags\u003cbr\u003eFunction_hash: e480650afd0f0c4bf90a8d9084fcf6ec\u003cbr\u003eMethod: _create_lags\u003cbr\u003eDatetime: 2025-11-27 14:39:29.283992\u003cbr\u003ePython version: 3.12.12\u003cbr\u003eskforecast version: 0.19.0\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.3\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 0.000212 s\u003cbr\u003eRun time median: 0.000204 s\u003cbr\u003eRun time p95: 0.000251 s\u003cbr\u003eRun time std: 0.000020 s\u003cbr\u003eN\u00ba repeats: 30","Forecaster: ForecasterRecursiveClassifier\u003cbr\u003eEstimator: DummyClassifier\u003cbr\u003eFunction: ForecasterRecursiveClassifier__create_lags\u003cbr\u003eFunction_hash: e480650afd0f0c4bf90a8d9084fcf6ec\u003cbr\u003eMethod: _create_lags\u003cbr\u003eDatetime: 2025-11-27 15:00:55.169814\u003cbr\u003ePython version: 3.12.12\u003cbr\u003eskforecast version: 0.19.0\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version ...

# %% [markdown]
# ## ForecasterStats
#
# The [`ForecasterStats` class](https://skforecast.org/latest/user_guides/forecasting-sarimax-arima.html) is benchmarked under a fixed experimental setup to ensure fair comparison across library versions. Key conditions are:
#
# | Condition           | Value                                                                           |
# |:--------------------|:--------------------------------------------------------------------------------|
# | Estimator           | `skforecast.stats.Arima`                                                        |
# | Dataset length      | 500 synthetic observations (generated with `bench_forecaster_stats._make_data`) |
# | Exogenous features  | 3                                                                               |
# | Data transformation | `StandardScaler()` for time series features and exogenous variables             |
# | Prediction horizon  | 24 steps ahead                                                                  |
# | Backtesting split   | 300 training, remaining for testing, step size = 24 with re-fitting (see [guide](https://skforecast.org/latest/user_guides/backtesting.html)) |

# %%
# Plot benchmark results
# ==============================================================================
plot_benchmark_results(
    results_benchmark_all,
    forecaster_names = ['ForecasterStats'],
    estimators       = ['skforecast.Arima'],
    add_mean         = True,
    add_median       = True
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="df8cb88e-c3cd-422a-ac95-8b1d1a050966" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("df8cb88e-c3cd-422a-ac95-8b1d1a050966")) {                    Plotly.newPlot(                        "df8cb88e-c3cd-422a-ac95-8b1d1a050966",                        [{"error_y":{"array":{"dtype":"f8","bdata":"QUfeRzM8RD+3KJobVooxP+FX97\u002f7kDk\u002fIVXsPZghLj\u002fyJ87yv1U5P0XXHmg\u002f+z0\u002fFAtFOCBVHj8="},"color":"#636EFA","thickness":1.5,"type":"data","visible":true,"width":5},"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#636EFA","line":{"color":"white","width":1},"opacity":0.85,"size":10},"mode":"markers","text":["Forecaster: ForecasterStats\u003cbr\u003eEstimator: skforecast.Arima\u003cbr\u003eFunction: ForecasterStats_fit\u003cbr\u003eFunction_hash: d372f75e83b0ad0cf205e7faf6c19833\u003cbr\u003eMethod: fit\u003cbr\u003eDatetime: 2026-01-29 12:03:24.937536\u003cbr\u003ePython version: 3.12.12\u003cbr\u003eskforecast version: 0.20.0\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.3\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 0.045420 s\u003cbr\u003eRun time median: 0.045254 s\u003cbr\u003eRun time p95: 0.046306 s\u003cbr\u003eRun time std: 0.000618 s\u003cbr\u003eN\u00ba repeats: 15","Forecaster: ForecasterStats\u003cbr\u003eEstimator: skforecast.Arima\u003cbr\u003eFunction: ForecasterStats_fit\u003cbr\u003eFunction_hash: d372f75e83b0ad0cf205e7faf6c19833\u003cbr\u003eMethod: fit\u003cbr\u003eDatetime: 2026-01-29 12:30:51.666195\u003cbr\u003ePython version: 3.12.12\u003cbr\u003eskforecast version: 0.20.0\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.3\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 0.044714 s\u003cbr\u003eRun time median: 0.044692 s\u003cbr\u003eRun time p95: 0.045192 s\u003cbr\u003eRun time std: 0.000268 s\u003cbr\u003eN\u00ba repeats: 15","Forecaster: ForecasterStats\u003cbr\u003eEstimator: skforecast.Arima\u003cbr\u003eFunction: ForecasterStats_fit\u003cbr\u003eFunction_hash: d372f75e83b0ad0cf205e7faf6c19833\u003cbr\u003eMethod: fit\u003cbr\u003eDatetime: 2026-01-29 15:24:43.781901\u003cbr\u003ePython version: 3.12.12\u003cbr\u003eskforecast version: 0.20.0\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.3\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 0.044796 s\u003cbr\u003eRun time median: 0.044660 s\u003cbr\u003eRun time p95: 0.045555 s\u003cbr\u003eRun time std: 0.000390 s\u003cbr\u003eN\u00ba repeats: 15","Forecaster: ForecasterStats\u003cbr\u003eEstimator: skforecast.Arima\u003cbr\u003eFunction: ForecasterStats_fit\u003cbr\u003eFunction_hash: d372f75e83b0ad0cf205e7faf6c19833\u003cbr\u003eMethod: fit\u003cbr\u003eDatetime: 2026-01-29 17:22:05.865520\u003cbr\u003ePython version: 3.12.12\u003cbr\u003eskforecast version: 0.20.0\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.3\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with- ...

# %% [markdown]
# ## ForecasterRecursiveMultiSeries
#
# The [`ForecasterRecursiveMultiSeries` class](https://skforecast.org/latest/user_guides/independent-multi-time-series-forecasting.html) is benchmarked under a fixed experimental setup to ensure fair comparison across library versions. Key conditions are:
#
# | Condition           | Value                                                                                                       |
# |:--------------------|:------------------------------------------------------------------------------------------------------------|
# | Estimator           | `sklearn.dummy.DummyRegressor` (to isolate forecaster overhead)                                             |
# | Number of series    | 600 time series                                                                                             |
# | Dataset length      | 2000 synthetic observations per series (generated with `bench_forecaster_recursive_multiseries._make_data`) |
# | Lags as predictors  | 50                                                                                                          |
# | Exogenous features  | 3                                                                                                           |
# | Data transformation | `StandardScaler()` for time series features and exogenous variables                                         |
# | Prediction horizon  | 100 steps ahead                                                                                             |
# | Backtesting split   | 1200 training, remaining for testing, step size = 50, no re-fitting (see [guide](https://skforecast.org/latest/user_guides/backtesting.html)) |
#
# **Note:** In versions `< 0.14.0`, `ForecasterRecursiveMultiSeries` was named `ForecasterAutoregMultiSeries`.

# %%
# Plot benchmark results
# ==============================================================================
plot_benchmark_results(
    results_benchmark_all,
    forecaster_names = ['ForecasterRecursiveMultiSeries', 'ForecasterAutoregMultiSeries'],
    estimators       = ['DummyRegressor', 'LinearRegression'],
    add_mean         = True,
    add_median       = True
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="2bf5aaa1-b025-4e44-bd15-f3cccb705e51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2bf5aaa1-b025-4e44-bd15-f3cccb705e51")) {                    Plotly.newPlot(                        "2bf5aaa1-b025-4e44-bd15-f3cccb705e51",                        [{"error_y":{"array":{"dtype":"f8","bdata":"E4+5x5usqz\u002f2j3o1DzSsP+6fIew+x6Q\u002fey2P44PQpD8="},"color":"#636EFA","thickness":1.5,"type":"data","visible":true,"width":5},"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#636EFA","line":{"color":"white","width":1},"opacity":0.85,"size":10},"mode":"markers","text":["Forecaster: ForecasterRecursiveMultiSeries\u003cbr\u003eEstimator: DummyRegressor\u003cbr\u003eFunction: ForecasterRecursiveMultiSeries__create_train_X_y_series_is_dict_no_exog\u003cbr\u003eFunction_hash: 884eb9ee19bb306145a0fd967253bbfc\u003cbr\u003eMethod: _create_train_X_y_series_is_dict_no_exog\u003cbr\u003eDatetime: 2025-08-26 09:16:44.855557\u003cbr\u003ePython version: 3.12.11\u003cbr\u003eskforecast version: 0.15.1\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.2\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 1.817318 s\u003cbr\u003eRun time median: 1.812321 s\u003cbr\u003eRun time p95: 1.910855 s\u003cbr\u003eRun time std: 0.054051 s\u003cbr\u003eN\u00ba repeats: 10","Forecaster: ForecasterRecursiveMultiSeries\u003cbr\u003eEstimator: DummyRegressor\u003cbr\u003eFunction: ForecasterRecursiveMultiSeries__create_train_X_y_series_is_dict_no_exog\u003cbr\u003eFunction_hash: 884eb9ee19bb306145a0fd967253bbfc\u003cbr\u003eMethod: _create_train_X_y_series_is_dict_no_exog\u003cbr\u003eDatetime: 2025-08-26 09:32:45.343465\u003cbr\u003ePython version: 3.12.11\u003cbr\u003eskforecast version: 0.15.1\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.2\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 1.831855 s\u003cbr\u003eRun time median: 1.839436 s\u003cbr\u003eRun time p95: 1.906595 s\u003cbr\u003eRun time std: 0.055085 s\u003cbr\u003eN\u00ba repeats: 10","Forecaster: ForecasterRecursiveMultiSeries\u003cbr\u003eEstimator: DummyRegressor\u003cbr\u003eFunction: ForecasterRecursiveMultiSeries__create_train_X_y_series_is_dict_no_exog\u003cbr\u003eFunction_hash: 884eb9ee19bb306145a0fd967253bbfc\u003cbr\u003eMethod: _create_train_X_y_series_is_dict_no_exog\u003cbr\u003eDatetime: 2025-08-26 09:45:36.411819\u003cbr\u003ePython version: 3.12.11\u003cbr\u003eskforecast version: 0.15.1\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.2\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 1.810209 s\u003cbr\u003eRun time median: 1.813572 s\u003cbr\u003eRun time p95: 1.867506 s\u003cbr\u003eRun time std: 0.040583 s\u003cbr\u003eN\u00ba repeats: 10","Forecaster: ForecasterRecursiveMultiSeries\u003cbr\u003eEstimator: DummyRegressor\u003cbr\u003eFunction: ForecasterRecursiveMultiSeries__create_train_X_y_series_is_dict_no_exog\u003cbr\u003eFunction_hash: 884eb9ee19bb306145a0fd967253bbfc\u003cbr\u003eMethod: _create_ ...

# %% [markdown]
# ## ForecasterDirectMultiVariate
#
# The [`ForecasterDirectMultiVariate` class](https://skforecast.org/latest/user_guides/dependent-multi-series-multivariate-forecasting.html) is benchmarked under a fixed experimental setup to ensure fair comparison across library versions. Key conditions are:
#
# | Condition           | Value                                                                                          |
# |:--------------------|:-----------------------------------------------------------------------------------------------|
# | Estimator           | `sklearn.dummy.DummyRegressor` (to isolate forecaster overhead)                                |
# | Number of series    | 13 time series                                                                                 |
# | Dataset length      | 1000 synthetic observations (generated with `bench_forecaster_direct_multivariate._make_data`) |
# | Lags as predictors  | 20                                                                                             |
# | Exogenous features  | 3                                                                                              |
# | Data transformation | `StandardScaler()` for time series features and exogenous variables                            |
# | Prediction horizon  | 10 steps ahead (10 estimators)                                                                 |
# | Backtesting split   | 900 training, remaining for testing, step size = 10, no re-fitting (see [guide](https://skforecast.org/latest/user_guides/backtesting.html)) |
#
# **Note:** In versions `< 0.14.0`, `ForecasterDirectMultiVariate` was named `ForecasterAutoregMultiVariate`.

# %%
# Plot benchmark results
# ==============================================================================
plot_benchmark_results(
    results_benchmark_all,
    forecaster_names = ['ForecasterDirectMultiVariate', 'ForecasterAutoregMultiVariate'],
    estimators       = ['DummyRegressor'],
    add_mean         = True,
    add_median       = True
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="658eb43b-483a-4075-96d3-7096b0588e95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("658eb43b-483a-4075-96d3-7096b0588e95")) {                    Plotly.newPlot(                        "658eb43b-483a-4075-96d3-7096b0588e95",                        [{"error_y":{"array":{"dtype":"f8","bdata":"BHx0jJFKJT\u002f6lxpFBQFDPxtg7GyVLjI\u002fXpxPyly4Mj8="},"color":"#636EFA","thickness":1.5,"type":"data","visible":true,"width":5},"hovertemplate":"%{text}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":"#636EFA","line":{"color":"white","width":1},"opacity":0.85,"size":10},"mode":"markers","text":["Forecaster: ForecasterDirectMultiVariate\u003cbr\u003eEstimator: DummyRegressor\u003cbr\u003eFunction: ForecasterDirectMultiVariate__create_train_X_y\u003cbr\u003eFunction_hash: 376309f7138e749dc0a50d758cde50bb\u003cbr\u003eMethod: _create_train_X_y\u003cbr\u003eDatetime: 2025-08-26 09:26:41.839716\u003cbr\u003ePython version: 3.12.11\u003cbr\u003eskforecast version: 0.15.1\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.2\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 0.026547 s\u003cbr\u003eRun time median: 0.026550 s\u003cbr\u003eRun time p95: 0.026786 s\u003cbr\u003eRun time std: 0.000162 s\u003cbr\u003eN\u00ba repeats: 10","Forecaster: ForecasterDirectMultiVariate\u003cbr\u003eEstimator: DummyRegressor\u003cbr\u003eFunction: ForecasterDirectMultiVariate__create_train_X_y\u003cbr\u003eFunction_hash: 376309f7138e749dc0a50d758cde50bb\u003cbr\u003eMethod: _create_train_X_y\u003cbr\u003eDatetime: 2025-08-26 09:43:01.191103\u003cbr\u003ePython version: 3.12.11\u003cbr\u003eskforecast version: 0.15.1\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.2\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 0.027182 s\u003cbr\u003eRun time median: 0.027153 s\u003cbr\u003eRun time p95: 0.028190 s\u003cbr\u003eRun time std: 0.000580 s\u003cbr\u003eN\u00ba repeats: 10","Forecaster: ForecasterDirectMultiVariate\u003cbr\u003eEstimator: DummyRegressor\u003cbr\u003eFunction: ForecasterDirectMultiVariate__create_train_X_y\u003cbr\u003eFunction_hash: 376309f7138e749dc0a50d758cde50bb\u003cbr\u003eMethod: _create_train_X_y\u003cbr\u003eDatetime: 2025-08-26 09:55:41.982980\u003cbr\u003ePython version: 3.12.11\u003cbr\u003eskforecast version: 0.15.1\u003cbr\u003enumpy version: 2.1.3\u003cbr\u003epandas version: 2.3.2\u003cbr\u003esklearn version: 1.6.1\u003cbr\u003elightgbm version: 4.6.0\u003cbr\u003ePlatform: Linux-6.11.0-1018-azure-x86_64-with-glibc2.39\u003cbr\u003eProcessor: x86_64\u003cbr\u003eCPU count: 4\u003cbr\u003eMemory (GB): 16.77\u003cbr\u003eRun time avg: 0.026615 s\u003cbr\u003eRun time median: 0.026531 s\u003cbr\u003eRun time p95: 0.027122 s\u003cbr\u003eRun time std: 0.000277 s\u003cbr\u003eN\u00ba repeats: 10","Forecaster: ForecasterDirectMultiVariate\u003cbr\u003eEstimator: DummyRegressor\u003cbr\u003eFunction: ForecasterDirectMultiVariate__create_train_X_y\u003cbr\u003eFunction_hash: 376309f7138e749dc0a50d758cde50bb\u003cbr\u003eMethod: _create_train_X_y\u003cbr\u003eDatetime: 2025-08-26 10:19:12.403473\u003cbr\u003ePython version: 3.12.11\u003cbr\u003eskforecast version: 0.15.1\u003cbr\u003enumpy version: 2.1.3\u003cb ...

# %% [markdown]
# ## Plot function

# %%
#  Plot function
# ==============================================================================
from __future__ import annotations
import numpy as np
import pandas as pd
import plotly.io as pio
import plotly.graph_objects as go
from plotly.express.colors import qualitative
from packaging.version import Version, InvalidVersion
pio.renderers.default = "notebook_connected"


def plot_benchmark_results(
    df: pd.DataFrame, 
    forecaster_names: str | list[str], 
    estimators: str | list[str] | None = None, 
    add_median: bool = True, 
    add_mean: bool = True
) -> None:
    """
    Plot interactive benchmark results by method and package version.

    This function renders an interactive Plotly chart that visualizes execution
    times for multiple methods across `skforecast` versions. Each data point
    represents a run (or an aggregated run) for a given `(method, version)` and is
    jittered horizontally to avoid overlap. Points are **colored by version** and
    (optionally) per-version **median** and **mean** lines are overlaid for the
    selected method. A dropdown allows switching the visible method.

    Parameters
    ----------
    df : pandas DataFrame
        Input data to benchmark.
    forecaster_names : str, list 
        Forecaster(s) to filter in `df` (column `forecaster_name`).
    estimators : str, list, default None
        Estimator(s) to filter in `df` (column `estimator_name`). If `None`,
        no additional filtering by estimator is applied.
    add_median : bool, default True
        If `True`, draw one per-version **median** line for the selected method.
    add_mean : bool, default True
        If `True`, draw one per-version **mean** line for the selected method.
    
    Returns
    -------
    None
        Displays the plot inline.

    """

    if df.empty:
        print("No data found for the specified filters.")
        return

    if not isinstance(forecaster_names, list):
        forecaster_names = [forecaster_names]
    df = df.query("forecaster_name in @forecaster_names")

    if estimators is not None:
        if not isinstance(estimators, list):
            estimators = [estimators]
        df = df.query("estimator_name in @estimators")
        
    df = df.copy()

    def try_version(v):
        try: 
            return Version(str(v).lstrip('v'))
        except InvalidVersion: 
            return Version("0")  # fallback

    versions_sorted = sorted(df['skforecast_version'].unique(), key=try_version)
    version_to_num = {v: i for i, v in enumerate(versions_sorted)}
    df['skforecast_version'] = pd.Categorical(
        df['skforecast_version'], 
        categories=versions_sorted, 
        ordered=True
    )

    rng = np.random.default_rng(42)
    df['x_jittered'] = (
        df['skforecast_version'].map(version_to_num).astype(float) + 
        rng.uniform(-0.05, 0.05, size=len(df))
    )

    # --- paleta por versión ---
    version_colors = {
        v: qualitative.Plotly[i % len(qualitative.Plotly)] 
        for i, v in enumerate(versions_sorted)
    }

    methods = list(df['method_name'].unique())

    fig = go.Figure()

    # --- un trace por (método, métrica); colores por versión en los puntos ---
    method_to_traces = {m: [] for m in methods}
    for i, m in enumerate(methods):
        for version in versions_sorted:

            sub_df = df[
                (df['method_name'] == m) & 
                (df['skforecast_version'] == version)
            ]
            if sub_df.empty:
                continue

            marker = dict(
                size=10,
                color=version_colors[version],
                opacity=0.85,
                line=dict(color="white", width=1)
            )   

            error_y = dict(
                type='data', 
                array=sub_df['run_time_std'].to_numpy(), 
                visible=not sub_df['run_time_std'].isna().all(),
                color=version_colors[version],
                thickness=1.5,
                width=5
            )

            fig.add_trace(go.Scatter(
                x=sub_df['x_jittered'],
                y=sub_df['run_time_avg'],
                mode='markers',
                marker=marker,
                error_y=error_y,
                visible=(i == 0),
                # name=f"{methods[i]} — {label}",
                text = sub_df.apply(lambda row: (
                    f"Forecaster: {row['forecaster_name']}<br>"
                    f"Estimator: {row['estimator_name']}<br>"
                    f"Function: {row['function_name']}<br>"
                    f"Function_hash: {row['function_hash']}<br>"
                    f"Method: {row['method_name']}<br>"
                    f"Datetime: {row['datetime']}<br>"
                    f"Python version: {row['python_version']}<br>"
                    f"skforecast version: {row['skforecast_version']}<br>"
                    f"numpy version: {row['numpy_version']}<br>"
                    f"pandas version: {row['pandas_version']}<br>"
                    f"sklearn version: {row['sklearn_version']}<br>"
                    f"lightgbm version: {row['lightgbm_version']}<br>"
                    f"Platform: {row['platform']}<br>"
                    f"Processor: {row['processor']}<br>"
                    f"CPU count: {row['cpu_count']}<br>"
                    f"Memory (GB): {row['memory_gb']:.2f}<br>"
                    f"Run time avg: {row['run_time_avg']:.6f} s<br>"
                    f"Run time median: {row['run_time_median']:.6f} s<br>"
                    f"Run time p95: {row['run_time_p95']:.6f} s<br>"
                    f"Run time std: {row['run_time_std']:.6f} s<br>"
                    f"Nº repeats: {row['n_repeats']}"
                ), axis=1),
                hovertemplate = '%{text}<extra></extra>'
            ))
            method_to_traces[m].append(len(fig.data) - 1)

    median_trace_id = {}
    if add_median:
        for i, m in enumerate(methods):

            med_df = (
                df[df['method_name'] == m]
                .groupby('skforecast_version', observed=True)['run_time_avg']
                .median()
                .reset_index()
            )
            if med_df.empty:
                continue

            median_color = "#374151"
            med_df['x_center'] = med_df['skforecast_version'].map(version_to_num)
            fig.add_trace(go.Scatter(
                x=med_df['x_center'],
                y=med_df['run_time_avg'],
                mode='lines+markers',
                line=dict(color=median_color, width=2),
                marker=dict(size=8, color=median_color),
                name='Median (per version)',
                visible=(i == 0)
            ))
            median_trace_id[m] = len(fig.data) - 1

    mean_trace_id = {}
    if add_mean:
        for i, m in enumerate(methods):

            mean_df = (
                df[df['method_name'] == m]
                .groupby('skforecast_version', observed=True)['run_time_avg']
                .mean()
                .reset_index()
            )
            if mean_df.empty:
                continue

            mean_color = "#9CA3AF"
            mean_df['x_center'] = mean_df['skforecast_version'].map(version_to_num)
            fig.add_trace(go.Scatter(
                x=mean_df['x_center'],
                y=mean_df['run_time_avg'],
                mode='lines+markers',
                line=dict(color=mean_color, width=2, dash='dash'),
                marker=dict(size=8, color=mean_color),
                name='Mean (per version)',
                visible=(i == 0)
            ))
            mean_trace_id[m] = len(fig.data) - 1

    def visible_mask_for(method):
        n = len(fig.data)
        mask = [False] * n

        # puntos del método (todas sus versiones)
        for idx in method_to_traces.get(method, []):
            mask[idx] = True
        # su mediana y media (si existen)
        if add_median and method in median_trace_id:
            mask[median_trace_id[method]] = True
        if add_mean and method in mean_trace_id:
            mask[mean_trace_id[method]] = True

        return mask

    buttons_methods = []
    for i, m in enumerate(methods):
        buttons_methods.append(dict(
            label=m,
            method="update",
            args=[
                {"visible": visible_mask_for(m)}, 
                {"title": {"text": f"Execution time — method: `{m}`"}}
            ]
        ))

    fig.update_layout(
        title=dict(
            text=f"Execution time — method: `{methods[0]}`"
        ),
        xaxis=dict(
            tickmode="array",
            tickvals=list(version_to_num.values()),
            ticktext=list(version_to_num.keys()),
            title="skforecast version",
            tickangle=0,
            automargin=True,
        ),
        yaxis=dict(
            title="Execution time (s)", 
            automargin=True
        ),
        # template="plotly_white",
        margin=dict(l=70, r=20, t=100, b=60), 
        updatemenus=[
            dict(
                type="dropdown",
                buttons=buttons_methods,
                showactive=True,
                direction="down",
                x=1.00,
                y=1.03,
                xanchor="right",
                yanchor="bottom",
                pad={"r": 2, "t": 0},
            ),
        ],
        legend=dict(title=""),
        showlegend=False,
    )

    fig.show()
    
    # Show in web (other option)
    # from IPython.display import HTML
    # return HTML(fig.to_html(full_html=False, include_plotlyjs="cdn"))
