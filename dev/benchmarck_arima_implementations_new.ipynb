# %% [markdown]
# # Compare Arima results from Skforecast, pmdarima and statsforecast

# %%
# %load_ext autoreload
# %autoreload 2
import sys
from pathlib import Path
path = str(Path.cwd().parent)
print(path)
sys.path.insert(1, path)
import skforecast

print(skforecast.__version__)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/joaquin/Documents/GitHub/skforecast
# 0.21.0

# %%
# Libraries
# ==============================================================================
import numpy as np
import pandas as pd
from pmdarima import ARIMA as pmdarima_ARIMA
from skforecast.stats import Arima as skf_Arima
from statsforecast.models import ARIMA as statsforecast_Arima
import warnings
import timeit

# %%
# Datasets
# ==============================================================================
from fixtures_arima import datasets

# %%
# Benchmarking ARIMA implementations
# ==============================================================================
warnings.filterwarnings("ignore", message=".*force_all_finite.*")
warnings.filterwarnings("ignore", message=".*Non-stationary starting seasonal autoregressive.*")
warnings.filterwarnings("ignore", message=".*Too few observations to estimate starting parameters.*")
warnings.filterwarnings("ignore", message=".*Too few observations to estimate starting parameters for seasonal ARMA.*")

results = []
for key, value in datasets.items():
    data = value['data']
    m = value['seasonal_periods']
    order = value['order']
    seasonal_order = value['seasonal_order']
    steps_ahead = value['steps_ahead']
    name = key
    print(f"Dataset: {name}")

    # pmdarima
    try:
        print("    pmdarima...")
        start = timeit.default_timer()
        res = pmdarima_ARIMA(
            order=order,
            seasonal_order=seasonal_order + (m,),
            method = 'bfgs',
            maxiter = 500,
            suppress_warnings = False,
            trend = None,
            with_intercept = True,
        )
        res.fit(data)
        end = timeit.default_timer()
        elapsed_time_fit = end - start

        start = timeit.default_timer()
        predictions = res.predict(n_periods=steps_ahead).to_numpy()
        end = timeit.default_timer()
        elapsed_time_pred = end - start
        aic = res.aic()
    except Exception as e:
        warnings.warn(f"pmdarima ARIMA failed on dataset {name} with error: {e}")
        elapsed_time_fit = np.nan
        elapsed_time_pred = np.nan
        aic = np.nan
        predictions = [np.nan] * steps_ahead
    results.append([name, "pmdarima", elapsed_time_fit, elapsed_time_pred, aic, predictions])
    print(f"        time: {elapsed_time_fit + elapsed_time_pred:.2f} seconds")

    # skforecast
    print("    skforecast...")
    try:
        start = timeit.default_timer()
        res = skf_Arima(
            order=order,
            seasonal_order=seasonal_order,
            m=m,
            fit_intercept = True,
            enforce_stationarity = True,
            method = "CSS-ML",
            n_cond = None,
            optim_method = "BFGS",
            optim_kwargs = {"maxiter": 500},
        )
        res.fit(y=data, suppress_warnings=True)
        end = timeit.default_timer()
        elapsed_time_fit = end - start

        start = timeit.default_timer()
        predictions = res.predict(steps=steps_ahead)
        end = timeit.default_timer()
        elapsed_time_pred = end - start
        aic = res.aic_
    except Exception as e:
        warnings.warn(f"skforecast ARIMA failed on dataset {name} with error: {e}")
        elapsed_time_fit = np.nan
        elapsed_time_pred = np.nan
        aic = np.nan
        predictions = [np.nan] * steps_ahead
    results.append([name, "skforecast", elapsed_time_fit, elapsed_time_pred, aic, predictions])
    print(f"        time: {elapsed_time_fit + elapsed_time_pred:.2f} seconds")
    
    # statsforecast
    print("    statsforecast...")
    try:
        start = timeit.default_timer()
        res = statsforecast_Arima(
            order=order,
            seasonal_order=seasonal_order,
            season_length=m,
            include_mean = True,
            method = "CSS-ML",
        )
        res.fit(y=data)
        end = timeit.default_timer()
        elapsed_time_fit = end - start

        start = timeit.default_timer()
        predictions = res.predict(h=steps_ahead)['mean']
        end = timeit.default_timer()
        elapsed_time_pred = end - start
        aic = res.model_['aic']
    except Exception as e:
        warnings.warn(f"statsforecast ARIMA failed on dataset {name} with error: {e}")
        elapsed_time_fit = np.nan
        elapsed_time_pred = np.nan
        aic = np.nan
        predictions = [np.nan] * steps_ahead
    results.append([name, "statsforecast", elapsed_time_fit, elapsed_time_pred, aic, predictions])
    print(f"        time: {elapsed_time_fit + elapsed_time_pred:.2f} seconds")
# Out:
# Dataset: air_passengers
#     pmdarima...
#         time: 1.06 seconds
#     skforecast...
#         time: 0.22 seconds
#     statsforecast...
#         time: 0.06 seconds
# Dataset: monthly_data
#     pmdarima...
#         time: 2.32 seconds
#     skforecast...
#         time: 0.28 seconds
#     statsforecast...
#         time: 0.07 seconds
# Dataset: quarterly_data
#     pmdarima...
# /home/joaquin/miniconda3/envs/skforecast_21_py13/lib/python3.13/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#         time: 1.97 seconds
#     skforecast...
#         time: 0.18 seconds
#     statsforecast...
#         time: 0.12 seconds
# Dataset: daily_data
#     pmdarima...
# /home/joaquin/miniconda3/envs/skforecast_21_py13/lib/python3.13/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
#         time: 1.07 seconds
#     skforecast...
#         time: 0.28 seconds
#     statsforecast...
#         time: 0.04 seconds
# Dataset: hourly_data
#     pmdarima...
#         time: 8.72 seconds
#     skforecast...
#         time: 2.01 seconds
#     statsforecast...
#         time: 0.11 seconds
# Dataset: no_seasonal_data
#     pmdarima...
# /home/joaquin/miniconda3/envs/skforecast_21_py13/lib/python3.13/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/joaquin/miniconda3/envs/skforecast_21_py13/lib/python3.13/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#         time: 0.30 seconds
#     skforecast...
#         time: 0.24 seconds
#     statsforecast...
#         time: 0.13 seconds
# Dataset: strong_seasonal
#     pmdarima...
#         time: 2.75 seconds
#     skforecast...
#         time: 0.23 seconds
#     statsforecast...
#         time: 0.07 seconds
# Dataset: multi_seasonal
#     pmdarima...
# /home/joaquin/miniconda3/envs/skforecast_21_py13/lib/python3.13/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#         time: 12.75 seconds
#     skforecast...
#         time: 0.52 seconds
#     statsforecast...
#         time: 0.19 seconds
# Dataset: sunspots_data
#     pmdarima...
# /home/joaquin/miniconda3/envs/skforecast_21_py13/lib/python3.13/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/joaquin/miniconda3/envs/skforecast_21_py13/lib/python3.13/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#         time: 9.61 seconds
#     skforecast...
#         time: 1.19 seconds
#     statsforecast...
#         time: 0.33 seconds
# Dataset: co2_data
#     pmdarima...
#         time: 2.21 seconds
#     skforecast...
#         time: 0.52 seconds
#     statsforecast...
#         time: 0.12 seconds
# Dataset: macrodata_data
#     pmdarima...
#         time: 0.12 seconds
#     skforecast...
#         time: 0.04 seconds
#     statsforecast...
#         time: 0.10 seconds
# Dataset: nile_data
#     pmdarima...
#         time: 0.20 seconds
#     skforecast...
#         time: 0.05 seconds
#     statsforecast...
#         time: 0.03 seconds
# Dataset: fuel_consumption
#     pmdarima...
#         time: 1.86 seconds
#     skforecast...
#         time: 0.60 seconds
#     statsforecast...
#         time: 0.12 seconds
# Dataset: h2o_data
#     pmdarima...
# /home/joaquin/miniconda3/envs/skforecast_21_py13/lib/python3.13/site-packages/statsforecast/arima.py:1130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return np.all(x[0] == x)
# /home/joaquin/miniconda3/envs/skforecast_21_py13/lib/python3.13/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#         time: 1.39 seconds
#     skforecast...
#         time: 0.09 seconds
#     statsforecast...
#         time: 0.07 seconds
# /home/joaquin/miniconda3/envs/skforecast_21_py13/lib/python3.13/site-packages/statsforecast/arima.py:1130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return np.all(x[0] == x)

# %%
# Results
# ==============================================================================
results_df = pd.DataFrame(
    results,
    columns=["dataset", "library", "time_fit", "time_pred", "aic", "predictions"]
)
results_df = results_df.set_index(['dataset'])
results_df
# Out:
#                         library   time_fit  time_pred          aic  \
# dataset
# air_passengers         pmdarima   1.051136   0.011290  1022.904236
# air_passengers       skforecast   0.219730   0.000505  1021.837720
# air_passengers    statsforecast   0.056533   0.001342  1021.007365
# monthly_data           pmdarima   2.298715   0.017985   205.442889
# monthly_data         skforecast   0.279142   0.000425   205.010881
# monthly_data      statsforecast   0.064337   0.001823   206.141029
# quarterly_data         pmdarima   1.966056   0.007512   157.099510
# quarterly_data       skforecast   0.178887   0.000196   157.024240
# quarterly_data    statsforecast   0.120813   0.000657   178.361447
# daily_data             pmdarima   1.065044   0.008801   358.402921
# daily_data           skforecast   0.281878   0.000100   360.414217
# daily_data        statsforecast   0.042231   0.000550   360.311782
# hourly_data            pmdarima   8.704302   0.016020   566.867845
# hourly_data          skforecast   2.008143   0.001291   563.641251
# hourly_data       statsforecast   0.105368   0.002206   572.040744
# no_seasonal_data       pmdarima   0.294784   0.010021   178.699073
# no_seasonal_data     skforecast   0.236002   0.000095   173.262736
# no_seasonal_data  statsforecast   0.133099   0.000412   174.277971
# strong_seasonal        pmdarima   2.739440   0.009873  1431.493761
# strong_seasonal      skforecast   0.228191   0.000643  1430.894869
# strong_seasonal   statsforecast   0.070042   0.000822  1433.303050
# multi_seasonal         pmdarima  12.743374   0.010167  5483.603930
# multi_seasonal       skforecast   0.517526   0.000194  5482.835386
# multi_seasonal    statsforecast   0.187232   0.000778  5503.048151
# sunspots_data          pmdarima   9.598039   0.009419  2701.116084
# sunspots_data        skforecast   1.191058   0.000141  2502.460711
# sunspots_data     statsforecast   0.331914   0.000864  2493.849908
# co2_data               pmdarima   2.203411   0.010432   707.737601
# co2_data             skforecast   0.524523   0.000251   698.627776
# co2_data          statsforecast   0.118842   0.001158   706.383517
# macrodata_data         pmdarima   0.111283   0.006829 -1352.521260
# macrodata_data       skforecast   0.044579   0.000193 -1352.703944
# macrodata_data    statsforecast   0.099288   0.000375 -1352.521260
# nile_data              pmdarima   0.193403   0.004234  1267.623397
# nile_data            skforecast   0.052627   0.000073  1268.266770
# nile_data         statsforecast   0.034034   0.000899  1267.276297
# fuel_consumption       pmdarima   1.834682   0.023154  5473.324206
# fuel_consumption     skforecast   0.601491   0.000341  5385.895713
# fuel_consumption  statsforecast   0.123118   0.001292  5386.119024
# h2o_data               pmdarima   1.374148   0.017760  -482.228920
# h2o_data             skforecast   0.085835   0.000204  -483.262058
# h2o_data          statsforecast   0.065130   0.000715  -483.062157
#
#                                                         predictions
# dataset
# air_passengers    [447.39765478639623, 422.45058186250935, 454.3...
# air_passengers    [447.05566681373193, 421.8748893186421, 453.50...
# air_passengers    [447.0757711641652, 421.9400011324278, 453.760...
# monthly_data      [140.03388251253494, 212.59105111863394, 217.3...
# monthly_data      [141.3820524925975, 218.0933046845662, 222.638...
# monthly_data      [137.63461155341992, 207.64572518151454, 213.1...
# quarterly_data    [262.6032089172833, 116.12548510382481, -50.73...
# quarterly_data    [255.84457979667843, 110.04416815653951, -54.0...
# quarterly_data    [235.66379845188953, 107.19456849797109, -55.6...
# daily_data        [1980.5249016356397, 1392.7494986722031, 444.6...
# daily_data        [2048.123789780667, 1460.999151669073, 528.210...
# daily_data        [1996.108453437945, 1433.563793482589, 497.934...
# hourly_data       [77.70090800052402, 91.43504699577018, 96.1875...
# hourly_data       [78.24225411622369, 93.44220495872996, 99.9892...
# hourly_data       [80.36024065118063, 91.32887357870115, 99.0465...
# no_seasonal_data  [95.61398341002065, 97.81716045171024, 100.230...
# no_seasonal_data  [84.31590696680725, 83.59955461819882, 86.3408...
# no_seasonal_data  [96.65338895013126, 107.71687667745306, 110.98...
# strong_seasonal   [-102.42979230854561, -75.17915381414232, -3.2...
# strong_seasonal   [-101.30382697400469, -73.55175499548787, -1.9...
# strong_seasonal   [-101.8967877661544, -74.08675339094786, -2.86...
# multi_seasonal    [174.20504804907551, 172.05216748528488, 173.8...
# multi_seasonal    [173.51217383910995, 171.16566068194618, 173.2...
# multi_seasonal    [172.0837945627306, 171.57482826827865, 176.14...
# sunspots_data     [12.894108254258217, 45.90232942772544, 92.699...
# sunspots_data     [21.857667223148205, 44.41114153763212, 70.830...
# sunspots_data     [20.661208188341757, 42.24105822521206, 68.918...
# co2_data          [371.9639944403571, 372.84124485482965, 373.67...
# co2_data          [371.9589542677127, 372.8369721444161, 373.669...
# co2_data          [371.94849679596115, 372.84092870311144, 373.6...
# macrodata_data    [0.0055037404968847296, 0.006382660206328804, ...
# macrodata_data    [0.0055094818863460765, 0.006391220961016404, ...
# macrodata_data    [0.005503737857706841, 0.006382656150095653, 0...
# nile_data         [799.333890272331, 813.3616177861835, 815.0918...
# nile_data         [816.2248058142187, 835.6085641592193, 840.537...
# nile_data         [815.7400016514883, 833.8786564043955, 838.222...
# fuel_consumption  [578907.6297060002, 686610.1287335342, 658518....
# fuel_consumption  [583318.6975326823, 680433.7863077373, 668969....
# fuel_consumption  [583200.9306509467, 678493.602774687, 669593.6...
# h2o_data          [0.949355300434774, 1.0191965247389112, 1.0752...
# h2o_data          [0.9491399313969764, 1.018954708256356, 1.0748...
# h2o_data          [0.955975139211795, 1.0240528097812442, 1.0842...

# %%
# Diagnostics for a single dataset
# ==============================================================================
dataset_name = 'air_passengers'

data = datasets[dataset_name]['data']
m = datasets[dataset_name]['seasonal_periods']
order = datasets[dataset_name]['order']
seasonal_order = datasets[dataset_name]['seasonal_order']
steps_ahead = datasets[dataset_name]['steps_ahead']
name = dataset_name

res = skf_Arima(
    order=order,
    seasonal_order=seasonal_order,
    m=m,
    fit_intercept = True,
    enforce_stationarity = True,
    method = "CSS-ML",
    n_cond = None,
    optim_method = "BFGS",
    optim_kwargs = {"maxiter": 500},
)
res.fit(y=data, suppress_warnings=True)
predictions = res.predict(steps=steps_ahead)
predictions
# Out:
# array([447.05566681, 421.87488932, 453.50220277, 489.91210031,
#        502.18753895, 564.23332621, 649.81453009, 636.71568728,
#        538.92039472, 491.07141449, 422.81142454, 464.74123069,
#        479.573524  , 454.39274651, 486.02005996, 522.4299575 ,
#        534.70539614, 596.7511834 , 682.33238728, 669.23354447,
#        571.43825191, 523.58927168, 455.32928173, 497.25908788])

# %%
# Plot predictions
# ==============================================================================
import matplotlib.pyplot as plt
from skforecast.plot import set_dark_theme
set_dark_theme()

for dataset in results_df.index.unique():
    plt.figure(figsize=(7, 3))
    plt.title(f"Predictions for dataset: {dataset}")
    for _, row in results_df.loc[dataset].iterrows():
        plt.plot(
            range(len(row['predictions'])),
            row['predictions'],
            label=row['library']
        )
    plt.xlabel("Steps Ahead")
    plt.ylabel("Predicted Values")
    plt.legend()
    plt.show()

# %%
# Plot fitting times
# ==============================================================================
df_plot = results_df.pivot(columns="library", values="time_fit")
ax = df_plot.plot(kind="bar", figsize=(8,4))
plt.yscale("log") 
ax.set_ylabel("Time to fit (log scale)")
ax.set_xlabel("Dataset")
plt.title("Time to Fit per Library for Each Dataset (log scale)")
plt.xticks(rotation=45)
plt.legend(title="Library")
plt.tight_layout()
plt.show()

# Plot prediction times
# ==============================================================================
df_plot = results_df.pivot(columns="library", values="time_pred")
ax = df_plot.plot(kind="bar", figsize=(8,4))
plt.yscale("log") 
ax.set_ylabel("Time to predict (log scale)")
ax.set_xlabel("Dataset")
plt.title("Time to Predict per Library for Each Dataset (log scale)")
plt.xticks(rotation=45)
plt.legend(title="Library")
plt.tight_layout()
plt.show()
