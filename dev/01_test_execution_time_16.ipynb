# %%
import time
import platform
import psutil
import threadpoolctl
import sklearn
import numpy as np
import pandas as pd
import lightgbm
import skforecast
from packaging.version import parse as parse_version

from lightgbm import LGBMRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from skforecast.utils import check_predict_input
from skforecast.recursive import ForecasterRecursive
from skforecast.model_selection import TimeSeriesFold, backtesting_forecaster, backtesting_forecaster_multiseries

# %load_ext pyinstrument
# %load_ext line_profiler
# Out:
# The pyinstrument extension is already loaded. To reload it, use:
#   %reload_ext pyinstrument
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
# !pip install pyinstrument
# !pip install line_profiler
# !pip install lightgbm==4.6.0
# !pip install -U scikit-learn==1.6.1 lightgbm==4.6.0 pandas==2.2.3 numpy==2.1.3

# conda create -n skforecast_benchmark_3_12_9 python=3.12.9

# %%
print(f"Python version: {platform.python_version()}")
print(f"skforecast version: {skforecast.__version__}")
print(f"scikit-learn version: {sklearn.__version__}")
print(f"lightgbm version: {lightgbm.__version__}")
print(f"pandas version: {pd.__version__}")
print(f"numpy version: {np.__version__}")
print(f"Computer network name: {platform.node()}")
print(f"Processor type: {platform.processor()}")
print(f"Platform type: {platform.platform()}")
print(f"Operating system: {platform.system()}")
print(f"Operating system release: {platform.release()}")
print(f"Operating system version: {platform.version()}")
print(f"Number of physical cores: {psutil.cpu_count(logical=False)}")
print(f"Number of logical cores: {psutil.cpu_count(logical=True)}")
print("Threadpools:", threadpoolctl.threadpool_info())
# Info BLAS detallada (NumPy >=1.26)
try:
    import numpy.__config__ as c
    print(c.get_info('blas_opt_info'))
except Exception as e:
    print("No BLAS info:", e)
# Out:
# Python version: 3.12.9
# skforecast version: 0.16.0
# scikit-learn version: 1.7.1
# lightgbm version: 4.6.0
# pandas version: 2.3.1
# numpy version: 2.2.6
# Computer network name: joaquin-HP-ProBook-440-G6
# Processor type: x86_64
# Platform type: Linux-6.14.0-27-generic-x86_64-with-glibc2.39
# Operating system: Linux
# Operating system release: 6.14.0-27-generic
# Operating system version: #27~24.04.1-Ubuntu SMP PREEMPT_DYNAMIC Tue Jul 22 17:38:49 UTC 2
# Number of physical cores: 4
# Number of logical cores: 8
# Threadpools: [{'user_api': 'blas', 'internal_api': 'openblas', 'num_threads': 8, 'prefix': 'libscipy_openblas', 'filepath': '/home/joaquin/miniconda3/envs/skforecast_16_py12/lib/python3.12/site-packages/numpy.libs/libscipy_openblas64_-56d6093b.so', 'version': '0.3.29', 'threading_layer': 'pthreads', 'architecture': 'Haswell'}, {'user_api': 'blas', 'internal_api': 'openblas', 'num_threads': 8, 'prefix': 'libscipy_openblas', 'filepath': '/home/joaquin/miniconda3/envs/skforecast_16_py12/lib/python3.12/site-packages/scipy.libs/libscipy_openblas-68440149.so', 'version': '0.3.28', 'threading_layer': 'pthreads', 'architecture': 'Haswell'}, {'user_api': 'openmp', 'internal_api': 'openmp', 'num_threads': 8, 'prefix': 'libgomp', 'filepath': '/home/joaquin/miniconda3/envs/skforecast_16_py12/lib/python3.12/site-packages/scikit_learn.libs/libgomp-a34b3233.so.1.0.0', 'version': None}, {'user_api': 'openmp', 'internal_api': 'openmp', 'num_threads': 8, 'prefix': 'libgomp', 'filepath': '/home/joaquin/miniconda3/envs/skforecast_16_py12/lib/libgomp.so.1.0.0', 'version': None}]
# No BLAS info: module 'numpy.__config__' has no attribute 'get_info'

# %%
# Mock data for benchmarking
# ==========================================================
len_series = 2000
rng = np.random.default_rng(321)
y = pd.Series(
        data = rng.normal(loc=20, scale=5, size=len_series),
        index=pd.date_range(
            start='2010-01-01',
            periods=len_series,
            freq='h'
        ),
        name='y'
    )
rng = np.random.default_rng(321)
exog = pd.DataFrame(index=y.index)
exog['day_of_week'] = exog.index.dayofweek
exog['week_of_year'] = exog.index.isocalendar().week.astype(int)
exog['month'] = exog.index.month
exog_prediction = pd.DataFrame(
                    index=pd.date_range(
                        start=exog.index.max() + pd.Timedelta(hours=1),
                        periods=100,
                        freq='h'
                    )
                 ) 
exog_prediction['day_of_week'] = exog_prediction.index.dayofweek
exog_prediction['week_of_year'] = exog_prediction.index.isocalendar().week.astype(int)
exog_prediction['month'] = exog_prediction.index.month

# %%
import hashlib

def hash_dataframe(df):
    row_hashes = pd.util.hash_pandas_object(df, index=True).values
    combined_hash = hashlib.sha256(row_hashes.tobytes()).hexdigest()
    return combined_hash

hash_y = hash_dataframe(y)
hash_exog = hash_dataframe(exog)
hash_exog_prediction = hash_dataframe(exog_prediction)
print(f"Hash of y: {hash_y}")
print(f"Hash of exog: {hash_exog}")
print(f"Hash of exog_prediction: {hash_exog_prediction}")
display(y.dtypes)
display(exog.dtypes)
display(exog_prediction.dtypes)
# Out:
# Hash of y: f1ba70f786d503ec78f1cd228723bf3d073a5dfe3345f2faa26800d02cabe439
# Hash of exog: 10fb78eb4190dd80df8de7bff30fa2fc8e974c5da5064ef2eaf6b69a5c17cf3d
# Hash of exog_prediction: b533b86d8d547d466cdb52ceba8ae4ce5261765906d976d76078c6f2cfa0c5e4
# dtype('float64')
# day_of_week     int32
# week_of_year    int64
# month           int32
# dtype: object
# day_of_week     int32
# week_of_year    int64
# month           int32
# dtype: object

# %%
regressor = LGBMRegressor(random_state=8520, verbose=-1)
regressor = LinearRegression()
forecaster = ForecasterRecursive(
    regressor=regressor,
    lags=50,
    transformer_y=None,
    transformer_exog=None,
)
forecaster.fit(y=y, exog=exog)

# %% [markdown]
# ## skforecast 0.16.0

# %%
# %%timeit -n 200 -r 100

check_predict_input(
    forecaster_name  = type(forecaster).__name__,
    steps            = 100,
    is_fitted        = forecaster.is_fitted,
    exog_in_         = forecaster.exog_in_,
    index_type_      = forecaster.index_type_,
    index_freq_      = forecaster.index_freq_,
    window_size      = forecaster.window_size,
    last_window      = forecaster.last_window_,
    exog             = exog_prediction,
    exog_names_in_   = forecaster.exog_names_in_,
    interval         = None
)
# Out:
# 453 μs ± 70.3 μs per loop (mean ± std. dev. of 100 runs, 200 loops each)

# %%
# skforecast 0.16.0
# ==============================================================================
def funt_to_profile(forecaster, steps, exog):
    check_predict_input(
        forecaster_name  = type(forecaster).__name__,
        steps            = steps,
        is_fitted        = forecaster.is_fitted,
        exog_in_         = forecaster.exog_in_,
        index_type_      = forecaster.index_type_,
        index_freq_      = forecaster.index_freq_,
        window_size      = forecaster.window_size,
        last_window      = forecaster.last_window_,
        exog             = exog,
        exog_names_in_   = forecaster.exog_names_in_,
        interval         = None
    )


# %lprun -f check_predict_input funt_to_profile(forecaster, 100, exog_prediction)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.00247402 s
# File: /home/joaquin/miniconda3/envs/skforecast_16_py12/lib/python3.12/site-packages/skforecast/utils/utils.py
# Function: check_predict_input at line 773
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    773                                           def check_predict_input(
#    774                                               forecaster_name: str,
#    775                                               steps: int | list[int],
#    776                                               is_fitted: bool,
#    777                                               exog_in_: bool,
#    778                                               index_type_: type,
#    779                                               index_freq_: str,
#    780                                               window_size: int,
#    781                                               last_window: pd.Series | pd.DataFrame | None,
#    782                                               last_window_exog: pd.Series | pd.DataFrame | None = None,
#    783                                               exog: pd.Series | pd.DataFrame | None = None,
#    784                                               exog_type_in_: type | None = None,
#    785                                               exog_names_in_: list[str] | None = None,
#    786                                               interval: list[float] | None = None,
#    787                                               alpha: float | None = None,
#    788                                               max_steps: int | None = None,
#    789                                               levels: str | list[str] | None = None,
#    790                                               levels_forecaster: str | list[str] | None = None,
#    791                                               series_names_in_: list[str] | None = None,
#    792                                               encoding: str | None = None
#    793                                           ) -> None:
#    794                                               """
#    795                                               Check all inputs of predict method. This is a helper function to validate
#    796                                               that inputs used in predict method match attributes of a forecaster already
#    797                                               trained.
#    798
#    799                                               Parameters
#    800                                               ----------
#    801                                               forecaster_name : str
#    802                                                   Forecaster name.
#    803                                               steps : int, list
#    804                                                   Number of future steps predicted.
#    805                                               is_fitted: bool
#    806                                                   Tag to identify if the regressor has been fitted (trained).
#    807                                               exog_in_ : bool
#    808                                                   If the forecaster has been trained using exogenous variable/s.
#    809                                               index_type_ : type
#    810                                                   Type of index of the input used in training.
#    811                                               index_freq_ : str
#    812                                                   Frequency of Index of the input used in training.
#    813                                               window_size: int
#    814                                                   Size of the window needed to create the predictors. It is equal to
#    815                                                   `max_lag`.
#    816                                               last_window : pandas Series, pandas DataFrame, None
#    817                                                   Values of the series used to create the predictors (lags) need in the
#    818                                                   first iteration of prediction (t + 1).
#    819                                               last_window_exog : pandas Series, pandas DataFrame, default None
#    820                                                   Values of the exogenous variables aligned with `last_window` in
#    821                                                   ForecasterSarimax predictions.
#    822                                               exog : pandas Series, pandas DataFrame, default None
#    823                                                   Exogenous variable/s included as predictor/s.
#    824                                               exog_type_in_ : type, default None
#    825                                                   Type of exogenous variable/s used in training.
#    826                                               exog_names_in_ : list, default None
#    827                                                   Names of the exogenous variables used during training.
#    828                                               interval : list, tuple, default None
#    829                                                   Confidence of the prediction interval estimated. Sequence of percentiles
#    830                                                   to compute, which must be between 0 and 100 inclusive. For example,
#    831                                                   interval of 95% should be as `interval = [2.5, 97.5]`.
#    832                                               alpha : float, default None
#    833                                                   The confidence intervals used in ForecasterSarimax are (1 - alpha) %.
#    834                                               max_steps: int, default None
#    835                                                   Maximum number of steps allowed (`ForecasterDirect` and
#    836                                                   `ForecasterDirectMultiVariate`).
#    837                                               levels : str, list, default None
#    838                                                   Time series to be predicted (`ForecasterRecursiveMultiSeries`
#    839                                                   and `ForecasterRnn).
#    840                                               levels_forecaster : str, list, default None
#    841                                                   Time series used as output data of a multiseries problem in a RNN problem
#    842                                                   (`ForecasterRnn`).
#    843                                               series_names_in_ : list, default None
#    844                                                   Names of the columns used during fit (`ForecasterRecursiveMultiSeries`,
#    845                                                   `ForecasterDirectMultiVariate` and `ForecasterRnn`).
#    846                                               encoding : str, default None
#    847                                                   Encoding used to identify the different series (`ForecasterRecursiveMultiSeries`).
#    848
#    849                                               Returns
#    850                                               -------
#    851                                               None
#    852
#    853                                               """
#    854
#    855         1       2309.0   2309.0      0.1      if not is_fitted:
#    856                                                   raise NotFittedError(
#    857                                                       "This Forecaster instance is not fitted yet. Call `fit` with "
#    858                                                       "appropriate arguments before using predict."
#    859                                                   )
#    860
#    861         1       3944.0   3944.0      0.2      if isinstance(steps, (int, np.integer)) and steps < 1:
#    862                                                   raise ValueError(
#    863                                                       f"`steps` must be an integer greater than or equal to 1. Got {steps}."
#    864                                                   )
#    865
#    866         1       1998.0   1998.0      0.1      if isinstance(steps, list) and min(steps) < 1:
#    867                                                   raise ValueError(
#    868                                                      f"The minimum value of `steps` must be equal to or greater than 1. "
#    869                                                      f"Got {min(steps)}."
#    870                                                   )
#    871
#    872         1       1064.0   1064.0      0.0      if max_steps is not None:
#    873                                                   if max(steps) > max_steps:
#    874                                                       raise ValueError(
#    875                                                           f"The maximum value of `steps` must be less than or equal to "
#    876                                                           f"the value of steps defined when initializing the forecaster. "
#    877                                                           f"Got {max(steps)}, but the maximum is {max_steps}."
#    878                                                       )
#    879
#    880         1       1062.0   1062.0      0.0      if interval is not None or alpha is not None:
#    881                                                   check_interval(interval=interval, alpha=alpha)
#    882
#    883         1       1231.0   1231.0      0.0      if forecaster_name in ['ForecasterRecursiveMultiSeries',
#    884                                                                      'ForecasterRnn']:
#    885                                                   if not isinstance(levels, (type(None), str, list)):
#    886                                                       raise TypeError(
#    887                                                           "`levels` must be a `list` of column names, a `str` of a "
#    888                                                           "column name or `None`."
#    889                                                       )
#    890
#    891                                                   levels_to_check = (
#    892                                                       levels_forecaster if forecaster_name == 'ForecasterRnn'
#    893                                                       else series_names_in_
#    894                                                   )
#    895                                                   unknown_levels = set(levels) - set(levels_to_check)
#    896                                                   if forecaster_name == 'ForecasterRnn':
#    897                                                       if len(unknown_levels) != 0:
#    898                                                           raise ValueError(
#    899                                                               f"`levels` names must be included in the series used during fit "
#    900                                                               f"({levels_to_check}). Got {levels}."
#    901                                                           )
#    902                                                   else:
#    903                                                       if len(unknown_levels) != 0 and last_window is not None and encoding is not None:
#    904                                                           if encoding == 'onehot':
#    905                                                               warnings.warn(
#    906                                                                   f"`levels` {unknown_levels} were not included in training. The resulting "
#    907                                                                   f"one-hot encoded columns for this feature will be all zeros.",
#    908                                                                   UnknownLevelWarning
#    909                                                               )
#    910                                                           else:
#    911                                                               warnings.warn(
#    912                                                                   f"`levels` {unknown_levels} were not included in training. "
#    913                                                                   f"Unknown levels are encoded as NaN, which may cause the "
#    914                                                                   f"prediction to fail if the regressor does not accept NaN values.",
#    915                                                                   UnknownLevelWarning
#    916                                                               )
#    917
#    918         1        948.0    948.0      0.0      if exog is None and exog_in_:
#    919                                                   raise ValueError(
#    920                                                       "Forecaster trained with exogenous variable/s. "
#    921                                                       "Same variable/s must be provided when predicting."
#    922                                                   )
#    923
#    924         1       6546.0   6546.0      0.3      if exog is not None and not exog_in_:
#    925                                                   raise ValueError(
#    926                                                       "Forecaster trained without exogenous variable/s. "
#    927                                                       "`exog` must be `None` when predicting."
#    928                                                   )
#    929
#    930                                               # Checks last_window
#    931                                               # Check last_window type (pd.Series or pd.DataFrame according to forecaster)
#    932         1       7449.0   7449.0      0.3      if isinstance(last_window, type(None)) and forecaster_name not in [
#    933                                                   'ForecasterRecursiveMultiSeries',
#    934                                                   'ForecasterRnn'
#    935                                               ]:
#    936                                                   raise ValueError(
#    937                                                       "`last_window` was not stored during training. If you don't want "
#    938                                                       "to retrain the Forecaster, provide `last_window` as argument."
#    939                                                   )
#    940
#    941         1       6815.0   6815.0      0.3      if forecaster_name in ['ForecasterRecursiveMultiSeries',
#    942                                                                      'ForecasterDirectMultiVariate',
#    943                                                                      'ForecasterRnn']:
#    944                                                   if not isinstance(last_window, pd.DataFrame):
#    945                                                       raise TypeError(
#    946                                                           f"`last_window` must be a pandas DataFrame. Got {type(last_window)}."
#    947                                                       )
#    948
#    949                                                   last_window_cols = last_window.columns.to_list()
#    950
#    951                                                   if (
#    952                                                       forecaster_name in ["ForecasterRecursiveMultiSeries", "ForecasterRnn"]
#    953                                                       and len(set(levels) - set(last_window_cols)) != 0
#    954                                                   ):
#    955                                                       missing_levels = set(levels) - set(last_window_cols)
#    956                                                       raise ValueError(
#    957                                                           f"`last_window` must contain a column(s) named as the level(s) to be predicted. "
#    958                                                           f"The following `levels` are missing in `last_window`: {missing_levels}\n"
#    959                                                           f"Ensure that `last_window` contains all the necessary columns "
#    960                                                           f"corresponding to the `levels` being predicted.\n"
#    961                                                           f"    Argument `levels`     : {levels}\n"
#    962                                                           f"    `last_window` columns : {last_window_cols}\n"
#    963                                                           f"Example: If `levels = ['series_1', 'series_2']`, make sure "
#    964                                                           f"`last_window` includes columns named 'series_1' and 'series_2'."
#    965                                                       )
#    966
#    967                                                   if forecaster_name == 'ForecasterDirectMultiVariate':
#    968                                                       if len(set(series_names_in_) - set(last_window_cols)) > 0:
#    969                                                           raise ValueError(
#    970                                                               f"`last_window` columns must be the same as the `series` "
#    971                                                               f"column names used to create the X_train matrix.\n"
#    972                                                               f"    `last_window` columns    : {last_window_cols}\n"
#    973                                                               f"    `series` columns X train : {series_names_in_}"
#    974                                                           )
#    975                                               else:
#    976         1       8150.0   8150.0      0.3          if not isinstance(last_window, (pd.Series, pd.DataFrame)):
#    977                                                       raise TypeError(
#    978                                                           f"`last_window` must be a pandas Series or DataFrame. "
#    979                                                           f"Got {type(last_window)}."
#    980                                                       )
#    981
#    982                                               # Check last_window len, nulls and index (type and freq)
#    983         1      22952.0  22952.0      0.9      if len(last_window) < window_size:
#    984                                                   raise ValueError(
#    985                                                       f"`last_window` must have as many values as needed to "
#    986                                                       f"generate the predictors. For this forecaster it is {window_size}."
#    987                                                   )
#    988         1     383011.0 383011.0     15.5      if last_window.isna().to_numpy().any():
#    989                                                   warnings.warn(
#    990                                                       "`last_window` has missing values. Most of machine learning models do "
#    991                                                       "not allow missing values. Prediction method may fail.",
#    992                                                       MissingValuesWarning
#    993                                                   )
#    994         2      43706.0  21853.0      1.8      _, last_window_index = preprocess_last_window(
#    995         1       8977.0   8977.0      0.4                                 last_window   = last_window,
#    996         1      11098.0  11098.0      0.4                                 return_values = False
#    997                                                                      )
#    998         1       6926.0   6926.0      0.3      if not isinstance(last_window_index, index_type_):
#    999                                                   raise TypeError(
#   1000                                                       f"Expected index of type {index_type_} for `last_window`. "
#   1001                                                       f"Got {type(last_window_index)}."
#   1002                                                   )
#   1003         1      10095.0  10095.0      0.4      if isinstance(last_window_index, pd.DatetimeIndex):
#   1004         1      62968.0  62968.0      2.5          if not last_window_index.freqstr == index_freq_:
#   1005                                                       raise TypeError(
#   1006                                                           f"Expected frequency of type {index_freq_} for `last_window`. "
#   1007                                                           f"Got {last_window_index.freqstr}."
#   1008                                                       )
#   1009
#   1010                                               # Checks exog
#   1011         1       7013.0   7013.0      0.3      if exog is not None:
#   1012
#   1013                                                   # Check type, nulls and expected type
#   1014         1       8148.0   8148.0      0.3          if forecaster_name in ['ForecasterRecursiveMultiSeries']:
#   1015                                                       if not isinstance(exog, (pd.Series, pd.DataFrame, dict)):
#   1016                                                           raise TypeError(
#   1017                                                               f"`exog` must be a pandas Series, DataFrame or dict. Got {type(exog)}."
#   1018                                                           )
#   1019                                                       if exog_type_in_ == dict and not isinstance(exog, dict):
#   1020                                                           raise TypeError(
#   1021                                                               f"Expected type for `exog`: {exog_type_in_}. Got {type(exog)}."
#   1022                                                           )
#   1023                                                   else:
#   1024         1       8957.0   8957.0      0.4              if not isinstance(exog, (pd.Series, pd.DataFrame)):
#   1025                                                           raise TypeError(
#   1026                                                               f"`exog` must be a pandas Series or DataFrame. Got {type(exog)}."
#   1027                                                           )
#   1028
#   1029         1       9409.0   9409.0      0.4          if isinstance(exog, dict):
#   1030                                                       no_exog_levels = set(levels) - set(exog.keys())
#   1031                                                       if no_exog_levels:
#   1032                                                           warnings.warn(
#   1033                                                               f"`exog` does not contain keys for levels {no_exog_levels}. "
#   1034                                                               f"Missing levels are filled with NaN. Most of machine learning "
#   1035                                                               f"models do not allow missing values. Prediction method may fail.",
#   1036                                                               MissingExogWarning
#   1037                                                           )
#   1038                                                       exogs_to_check = [
#   1039                                                           (f"`exog` for series '{k}'", v)
#   1040                                                           for k, v in exog.items()
#   1041                                                           if v is not None and k in levels
#   1042                                                       ]
#   1043                                                   else:
#   1044         1       9226.0   9226.0      0.4              exogs_to_check = [('`exog`', exog)]
#   1045
#   1046         1      27488.0  27488.0      1.1          last_step = max(steps) if isinstance(steps, list) else steps
#   1047         1     819948.0 819948.0     33.1          expected_index = expand_index(last_window.index, 1)[0]
#   1048         2      41289.0  20644.5      1.7          for exog_name, exog_to_check in exogs_to_check:
#   1049
#   1050         1      17123.0  17123.0      0.7              if not isinstance(exog_to_check, (pd.Series, pd.DataFrame)):
#   1051                                                           raise TypeError(
#   1052                                                               f"{exog_name} must be a pandas Series or DataFrame. Got {type(exog_to_check)}"
#   1053                                                           )
#   1054
#   1055         1     622420.0 622420.0     25.2              if exog_to_check.isna().to_numpy().any():
#   1056                                                           warnings.warn(
#   1057                                                               f"{exog_name} has missing values. Most of machine learning models "
#   1058                                                               f"do not allow missing values. Prediction method may fail.",
#   1059                                                               MissingValuesWarning
#   1060                                                           )
#   1061
#   1062                                                       # Check exog has many values as distance to max step predicted
#   1063         1      26340.0  26340.0      1.1              if len(exog_to_check) < last_step:
#   1064                                                           if forecaster_name in ['ForecasterRecursiveMultiSeries']:
#   1065                                                               warnings.warn(
#   1066                                                                   f"{exog_name} doesn't have as many values as steps "
#   1067                                                                   f"predicted, {last_step}. Missing values are filled "
#   1068                                                                   f"with NaN. Most of machine learning models do not "
#   1069                                                                   f"allow missing values. Prediction method may fail.",
#   1070                                                                   MissingValuesWarning
#   1071                                                               )
#   1072                                                           else:
#   1073                                                               raise ValueError(
#   1074                                                                   f"{exog_name} must have at least as many values as "
#   1075                                                                   f"steps predicted, {last_step}."
#   1076                                                               )
#   1077
#   1078                                                       # Check name/columns are in exog_names_in_
#   1079         1      10645.0  10645.0      0.4              if isinstance(exog_to_check, pd.DataFrame):
#   1080         1      30699.0  30699.0      1.2                  col_missing = set(exog_names_in_).difference(set(exog_to_check.columns))
#   1081         1      11961.0  11961.0      0.5                  if col_missing:
#   1082                                                               if forecaster_name in ['ForecasterRecursiveMultiSeries']:
#   1083                                                                   warnings.warn(
#   1084                                                                       f"{col_missing} not present in {exog_name}. All "
#   1085                                                                       f"values will be NaN.",
#   1086                                                                       MissingExogWarning
#   1087                                                                   )
#   1088                                                               else:
#   1089                                                                   raise ValueError(
#   1090                                                                       f"Missing columns in {exog_name}. Expected {exog_names_in_}. "
#   1091                                                                       f"Got {exog_to_check.columns.to_list()}."
#   1092                                                                   )
#   1093                                                       else:
#   1094                                                           if exog_to_check.name is None:
#   1095                                                               raise ValueError(
#   1096                                                                   f"When {exog_name} is a pandas Series, it must have a name. Got None."
#   1097                                                               )
#   1098
#   1099                                                           if exog_to_check.name not in exog_names_in_:
#   1100                                                               if forecaster_name in ['ForecasterRecursiveMultiSeries']:
#   1101                                                                   warnings.warn(
#   1102                                                                       f"'{exog_to_check.name}' was not observed during training. "
#   1103                                                                       f"{exog_name} is ignored. Exogenous variables must be one "
#   1104                                                                       f"of: {exog_names_in_}.",
#   1105                                                                       IgnoredArgumentWarning
#   1106                                                                   )
#   1107                                                               else:
#   1108                                                                   raise ValueError(
#   1109                                                                       f"'{exog_to_check.name}' was not observed during training. "
#   1110                                                                       f"Exogenous variables must be: {exog_names_in_}."
#   1111                                                                   )
#   1112
#   1113                                                       # Check index dtype and freq
#   1114         2      38019.0  19009.5      1.5              _, exog_index = preprocess_exog(
#   1115         1      11010.0  11010.0      0.4                                  exog          = exog_to_check,
#   1116         1      11057.0  11057.0      0.4                                  return_values = False
#   1117                                                                       )
#   1118         1      11882.0  11882.0      0.5              if not isinstance(exog_index, index_type_):
#   1119                                                           raise TypeError(
#   1120                                                               f"Expected index of type {index_type_} for {exog_name}. "
#   1121                                                               f"Got {type(exog_index)}."
#   1122                                                           )
#   1123         1      12102.0  12102.0      0.5              if forecaster_name not in ['ForecasterRecursiveMultiSeries']:
#   1124         1      11549.0  11549.0      0.5                  if isinstance(exog_index, pd.DatetimeIndex):
#   1125         1      40693.0  40693.0      1.6                      if not exog_index.freqstr == index_freq_:
#   1126                                                                   raise TypeError(
#   1127                                                                       f"Expected frequency of type {index_freq_} for {exog_name}. "
#   1128                                                                       f"Got {exog_index.freqstr}."
#   1129                                                                   )
#   1130
#   1131                                                       # Check exog starts one step ahead of last_window end.
#   1132         1      70950.0  70950.0      2.9              if expected_index != exog_index[0]:
#   1133                                                           if forecaster_name in ['ForecasterRecursiveMultiSeries']:
#   1134                                                               warnings.warn(
#   1135                                                                   f"To make predictions {exog_name} must start one step "
#   1136                                                                   f"ahead of `last_window`. Missing values are filled "
#   1137                                                                   f"with NaN.\n"
#   1138                                                                   f"    `last_window` ends at : {last_window.index[-1]}.\n"
#   1139                                                                   f"    {exog_name} starts at : {exog_index[0]}.\n"
#   1140                                                                   f"     Expected index       : {expected_index}.",
#   1141                                                                   MissingValuesWarning
#   1142                                                               )
#   1143                                                           else:
#   1144                                                               raise ValueError(
#   1145                                                                   f"To make predictions {exog_name} must start one step "
#   1146                                                                   f"ahead of `last_window`.\n"
#   1147                                                                   f"    `last_window` ends at : {last_window.index[-1]}.\n"
#   1148                                                                   f"    {exog_name} starts at : {exog_index[0]}.\n"
#   1149                                                                   f"     Expected index : {expected_index}."
#   1150                                                               )
#   1151
#   1152                                               # Checks ForecasterSarimax
#   1153         1      24844.0  24844.0      1.0      if forecaster_name == 'ForecasterSarimax':
#   1154                                                   # Check last_window_exog type, len, nulls and index (type and freq)
#   1155                                                   if last_window_exog is not None:
#   1156                                                       if not exog_in_:
#   1157                                                           raise ValueError(
#   1158                                                               "Forecaster trained without exogenous variable/s. "
#   1159                                                               "`last_window_exog` must be `None` when predicting."
#   1160                                                           )
#   1161
#   1162                                                       if not isinstance(last_window_exog, (pd.Series, pd.DataFrame)):
#   1163                                                           raise TypeError(
#   1164                                                               f"`last_window_exog` must be a pandas Series or a "
#   1165                                                               f"pandas DataFrame. Got {type(last_window_exog)}."
#   1166                                                           )
#   1167                                                       if len(last_window_exog) < window_size:
#   1168                                                           raise ValueError(
#   1169                                                               f"`last_window_exog` must have as many values as needed to "
#   1170                                                               f"generate the predictors. For this forecaster it is {window_size}."
#   1171                                                           )
#   1172                                                       if last_window_exog.isna().to_numpy().any():
#   1173                                                           warnings.warn(
#   1174                                                               "`last_window_exog` has missing values. Most of machine learning "
#   1175                                                               "models do not allow missing values. Prediction method may fail.",
#   1176                                                               MissingValuesWarning
#   1177                                                       )
#   1178                                                       _, last_window_exog_index = preprocess_last_window(
#   1179                                                                                       last_window   = last_window_exog,
#   1180                                                                                       return_values = False
#   1181                                                                                   )
#   1182                                                       if not isinstance(last_window_exog_index, index_type_):
#   1183                                                           raise TypeError(
#   1184                                                               f"Expected index of type {index_type_} for `last_window_exog`. "
#   1185                                                               f"Got {type(last_window_exog_index)}."
#   1186                                                           )
#   1187                                                       if isinstance(last_window_exog_index, pd.DatetimeIndex):
#   1188                                                           if not last_window_exog_index.freqstr == index_freq_:
#   1189                                                               raise TypeError(
#   1190                                                                   f"Expected frequency of type {index_freq_} for "
#   1191                                                                   f"`last_window_exog`. Got {last_window_exog_index.freqstr}."
#   1192                                                               )
#   1193
#   1194                                                       # Check all columns are in the pd.DataFrame, last_window_exog
#   1195                                                       if isinstance(last_window_exog, pd.DataFrame):
#   1196                                                           col_missing = set(exog_names_in_).difference(set(last_window_exog.columns))
#   1197                                                           if col_missing:
#   1198                                                               raise ValueError(
#   1199                                                                   f"Missing columns in `last_window_exog`. Expected {exog_names_in_}. "
#   1200                                                                   f"Got {last_window_exog.columns.to_list()}."
#   1201                                                               )
#   1202                                                       else:
#   1203                                                           if last_window_exog.name is None:
#   1204                                                               raise ValueError(
#   1205                                                                   "When `last_window_exog` is a pandas Series, it must have a "
#   1206                                                                   "name. Got None."
#   1207                                                               )
#   1208
#   1209                                                           if last_window_exog.name not in exog_names_in_:
#   1210                                                               raise ValueError(
#   1211                                                                   f"'{last_window_exog.name}' was not observed during training. "
#   1212                                                                   f"Exogenous variables must be: {exog_names_in_}."
#   1213                                                               )

# %%
# %%timeit -n 100 -r 150

forecaster._create_predict_inputs(
    steps=100, exog=exog_prediction
)
# Out:
# 2.39 ms ± 258 μs per loop (mean ± std. dev. of 150 runs, 100 loops each)

# %%
# skforecast 0.16.0
# ==============================================================================
def funt_to_profile(steps, exog):
    forecaster._create_predict_inputs(
        steps=steps, exog=exog
    )


# %lprun -f forecaster._create_predict_inputs funt_to_profile(100, exog_prediction)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.013549 s
# File: /home/joaquin/miniconda3/envs/skforecast_16_py12/lib/python3.12/site-packages/skforecast/recursive/_forecaster_recursive.py
# Function: _create_predict_inputs at line 1098
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#   1098                                               def _create_predict_inputs(
#   1099                                                   self,
#   1100                                                   steps: int | str | pd.Timestamp,
#   1101                                                   last_window: pd.Series | pd.DataFrame | None = None,
#   1102                                                   exog: pd.Series | pd.DataFrame | None = None,
#   1103                                                   predict_probabilistic: bool = False,
#   1104                                                   use_in_sample_residuals: bool = True,
#   1105                                                   use_binned_residuals: bool = True,
#   1106                                                   check_inputs: bool = True
#   1107                                               ) -> tuple[np.ndarray, np.ndarray | None, pd.Index, int]:
#   1108                                                   """
#   1109                                                   Create the inputs needed for the first iteration of the prediction
#   1110                                                   process. As this is a recursive process, the last window is updated at
#   1111                                                   each iteration of the prediction process.
#   1112
#   1113                                                   Parameters
#   1114                                                   ----------
#   1115                                                   steps : int, str, pandas Timestamp
#   1116                                                       Number of steps to predict.
#   1117
#   1118                                                       - If steps is int, number of steps to predict.
#   1119                                                       - If str or pandas Datetime, the prediction will be up to that date.
#   1120                                                   last_window : pandas Series, pandas DataFrame, default None
#   1121                                                       Series values used to create the predictors (lags) needed in the
#   1122                                                       first iteration of the prediction (t + 1).
#   1123                                                       If `last_window = None`, the values stored in `self.last_window_` are
#   1124                                                       used to calculate the initial predictors, and the predictions start
#   1125                                                       right after training data.
#   1126                                                   exog : pandas Series, pandas DataFrame, default None
#   1127                                                       Exogenous variable/s included as predictor/s.
#   1128                                                   predict_probabilistic : bool, default False
#   1129                                                       If `True`, the necessary checks for probabilistic predictions will be
#   1130                                                       performed.
#   1131                                                   use_in_sample_residuals : bool, default True
#   1132                                                       If `True`, residuals from the training data are used as proxy of
#   1133                                                       prediction error to create predictions.
#   1134                                                       If `False`, out of sample residuals (calibration) are used.
#   1135                                                       Out-of-sample residuals must be precomputed using Forecaster's
#   1136                                                       `set_out_sample_residuals()` method.
#   1137                                                   use_binned_residuals : bool, default True
#   1138                                                       If `True`, residuals are selected based on the predicted values
#   1139                                                       (binned selection).
#   1140                                                       If `False`, residuals are selected randomly.
#   1141                                                   check_inputs : bool, default True
#   1142                                                       If `True`, the input is checked for possible warnings and errors
#   1143                                                       with the `check_predict_input` function. This argument is created
#   1144                                                       for internal use and is not recommended to be changed.
#   1145
#   1146                                                   Returns
#   1147                                                   -------
#   1148                                                   last_window_values : numpy ndarray
#   1149                                                       Series values used to create the predictors needed in the first
#   1150                                                       iteration of the prediction (t + 1).
#   1151                                                   exog_values : numpy ndarray, None
#   1152                                                       Exogenous variable/s included as predictor/s.
#   1153                                                   prediction_index : pandas Index
#   1154                                                       Index of the predictions.
#   1155                                                   steps: int
#   1156                                                       Number of future steps predicted.
#   1157
#   1158                                                   """
#   1159
#   1160         1       3131.0   3131.0      0.0          if last_window is None:
#   1161         1       1247.0   1247.0      0.0              last_window = self.last_window_
#   1162
#   1163         1        965.0    965.0      0.0          if self.is_fitted:
#   1164         2      24630.0  12315.0      0.2              steps = date_to_index_position(
#   1165         1       6318.0   6318.0      0.0                          index        = last_window.index,
#   1166         1       1101.0   1101.0      0.0                          date_input   = steps,
#   1167         1        644.0    644.0      0.0                          method       = 'prediction',
#   1168         1        436.0    436.0      0.0                          date_literal = 'steps'
#   1169                                                               )
#   1170
#   1171         1        710.0    710.0      0.0          if check_inputs:
#   1172         2    3483182.0    2e+06     25.7              check_predict_input(
#   1173         1      18293.0  18293.0      0.1                  forecaster_name  = type(self).__name__,
#   1174         1        695.0    695.0      0.0                  steps            = steps,
#   1175         1        624.0    624.0      0.0                  is_fitted        = self.is_fitted,
#   1176         1        681.0    681.0      0.0                  exog_in_         = self.exog_in_,
#   1177         1       1316.0   1316.0      0.0                  index_type_      = self.index_type_,
#   1178         1        732.0    732.0      0.0                  index_freq_      = self.index_freq_,
#   1179         1        821.0    821.0      0.0                  window_size      = self.window_size,
#   1180         1        459.0    459.0      0.0                  last_window      = last_window,
#   1181         1        452.0    452.0      0.0                  exog             = exog,
#   1182         1        541.0    541.0      0.0                  exog_type_in_    = self.exog_type_in_,
#   1183         1        694.0    694.0      0.0                  exog_names_in_   = self.exog_names_in_,
#   1184         1        580.0    580.0      0.0                  interval         = None
#   1185                                                       )
#   1186
#   1187         1       1346.0   1346.0      0.0              if predict_probabilistic:
#   1188                                                           check_residuals_input(
#   1189                                                               forecaster_name              = type(self).__name__,
#   1190                                                               use_in_sample_residuals      = use_in_sample_residuals,
#   1191                                                               in_sample_residuals_         = self.in_sample_residuals_,
#   1192                                                               out_sample_residuals_        = self.out_sample_residuals_,
#   1193                                                               use_binned_residuals         = use_binned_residuals,
#   1194                                                               in_sample_residuals_by_bin_  = self.in_sample_residuals_by_bin_,
#   1195                                                               out_sample_residuals_by_bin_ = self.out_sample_residuals_by_bin_
#   1196                                                           )
#   1197
#   1198         1    1033112.0    1e+06      7.6          last_window = last_window.iloc[-self.window_size:].copy()
#   1199         2    1134522.0 567261.0      8.4          last_window_values, last_window_index = preprocess_last_window(
#   1200         1        527.0    527.0      0.0                                                      last_window = last_window
#   1201                                                                                           )
#   1202
#   1203         2      14336.0   7168.0      0.1          last_window_values = transform_numpy(
#   1204         1        834.0    834.0      0.0                                   array             = last_window_values,
#   1205         1        926.0    926.0      0.0                                   transformer       = self.transformer_y,
#   1206         1        544.0    544.0      0.0                                   fit               = False,
#   1207         1        321.0    321.0      0.0                                   inverse_transform = False
#   1208                                                                        )
#   1209         1        715.0    715.0      0.0          if self.differentiation is not None:
#   1210                                                       last_window_values = self.differentiator.fit_transform(last_window_values)
#   1211
#   1212         1        632.0    632.0      0.0          if exog is not None:
#   1213         1       9710.0   9710.0      0.1              exog = input_to_frame(data=exog, input_name='exog')
#   1214         1    2173102.0    2e+06     16.0              exog = exog.loc[:, self.exog_names_in_]
#   1215         2      16559.0   8279.5      0.1              exog = transform_dataframe(
#   1216         1        547.0    547.0      0.0                         df                = exog,
#   1217         1       1071.0   1071.0      0.0                         transformer       = self.transformer_exog,
#   1218         1        737.0    737.0      0.0                         fit               = False,
#   1219         1        436.0    436.0      0.0                         inverse_transform = False
#   1220                                                              )
#   1221         1    4110152.0    4e+06     30.3              check_exog_dtypes(exog=exog)
#   1222         1     322654.0 322654.0      2.4              exog_values = exog.to_numpy()[:steps]
#   1223                                                   else:
#   1224                                                       exog_values = None
#   1225
#   1226         2    1171586.0 585793.0      8.6          prediction_index = expand_index(
#   1227         1       1059.0   1059.0      0.0                                 index = last_window_index,
#   1228         1        977.0    977.0      0.0                                 steps = steps,
#   1229                                                                      )
#   1230
#   1231         1       4336.0   4336.0      0.0          return last_window_values, exog_values, prediction_index, steps

# %%
# %%timeit -n 20 -r 10

# skforecast 0.16.0
forecaster.predict(
    steps=100, exog=exog_prediction
)
# Out:
# 4.11 ms ± 544 μs per loop (mean ± std. dev. of 10 runs, 20 loops each)

# %%
# skforecast 0.16.0
# ==============================================================================
def funt_to_profile(steps, exog):
    forecaster.predict(
        steps=steps, exog=exog
    )


# %lprun -f forecaster.predict funt_to_profile(100, exog_prediction)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.0144667 s
# File: /home/joaquin/miniconda3/envs/skforecast_16_py12/lib/python3.12/site-packages/skforecast/recursive/_forecaster_recursive.py
# Function: predict at line 1429
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#   1429                                               def predict(
#   1430                                                   self,
#   1431                                                   steps: int | str | pd.Timestamp,
#   1432                                                   last_window: pd.Series | pd.DataFrame | None = None,
#   1433                                                   exog: pd.Series | pd.DataFrame | None = None,
#   1434                                                   check_inputs: bool = True
#   1435                                               ) -> pd.Series:
#   1436                                                   """
#   1437                                                   Predict n steps ahead. It is an recursive process in which, each prediction,
#   1438                                                   is used as a predictor for the next step.
#   1439
#   1440                                                   Parameters
#   1441                                                   ----------
#   1442                                                   steps : int, str, pandas Timestamp
#   1443                                                       Number of steps to predict.
#   1444
#   1445                                                       - If steps is int, number of steps to predict.
#   1446                                                       - If str or pandas Datetime, the prediction will be up to that date.
#   1447                                                   last_window : pandas Series, pandas DataFrame, default None
#   1448                                                       Series values used to create the predictors (lags) needed in the
#   1449                                                       first iteration of the prediction (t + 1).
#   1450                                                       If `last_window = None`, the values stored in `self.last_window_` are
#   1451                                                       used to calculate the initial predictors, and the predictions start
#   1452                                                       right after training data.
#   1453                                                   exog : pandas Series, pandas DataFrame, default None
#   1454                                                       Exogenous variable/s included as predictor/s.
#   1455                                                   check_inputs : bool, default True
#   1456                                                       If `True`, the input is checked for possible warnings and errors
#   1457                                                       with the `check_predict_input` function. This argument is created
#   1458                                                       for internal use and is not recommended to be changed.
#   1459
#   1460                                                   Returns
#   1461                                                   -------
#   1462                                                   predictions : pandas Series
#   1463                                                       Predicted values.
#   1464
#   1465                                                   """
#   1466
#   1467         1       1707.0   1707.0      0.0          (
#   1468         1        358.0    358.0      0.0              last_window_values,
#   1469         1        335.0    335.0      0.0              exog_values,
#   1470         1        319.0    319.0      0.0              prediction_index,
#   1471         1        347.0    347.0      0.0              steps
#   1472         2   11688831.0    6e+06     80.8          ) = self._create_predict_inputs(
#   1473         1        722.0    722.0      0.0                  steps        = steps,
#   1474         1        610.0    610.0      0.0                  last_window  = last_window,
#   1475         1        626.0    626.0      0.0                  exog         = exog,
#   1476         1        616.0    616.0      0.0                  check_inputs = check_inputs
#   1477                                                       )
#   1478
#   1479         2      28077.0  14038.5      0.2          with warnings.catch_warnings():
#   1480         2      59090.0  29545.0      0.4              warnings.filterwarnings(
#   1481         1        564.0    564.0      0.0                  "ignore",
#   1482         1        618.0    618.0      0.0                  message="X does not have valid feature names",
#   1483         1        995.0    995.0      0.0                  category=UserWarning
#   1484                                                       )
#   1485         2    2299779.0    1e+06     15.9              predictions = self._recursive_predict(
#   1486         1        365.0    365.0      0.0                                steps              = steps,
#   1487         1        340.0    340.0      0.0                                last_window_values = last_window_values,
#   1488         1        310.0    310.0      0.0                                exog_values        = exog_values
#   1489                                                                     )
#   1490
#   1491         1        946.0    946.0      0.0          if self.differentiation is not None:
#   1492                                                       predictions = self.differentiator.inverse_transform_next_window(predictions)
#   1493
#   1494         2       7664.0   3832.0      0.1          predictions = transform_numpy(
#   1495         1        609.0    609.0      0.0                            array             = predictions,
#   1496         1        590.0    590.0      0.0                            transformer       = self.transformer_y,
#   1497         1        428.0    428.0      0.0                            fit               = False,
#   1498         1        365.0    365.0      0.0                            inverse_transform = True
#   1499                                                                 )
#   1500
#   1501         2     366471.0 183235.5      2.5          predictions = pd.Series(
#   1502         1        594.0    594.0      0.0                            data  = predictions,
#   1503         1        521.0    521.0      0.0                            index = prediction_index,
#   1504         1        615.0    615.0      0.0                            name  = 'pred'
#   1505                                                                 )
#   1506
#   1507         1       3321.0   3321.0      0.0          return predictions

# %%
import warnings
warnings.filterwarnings(
    "ignore", 
    message=".*X does not have valid feature names.*", 
    category=UserWarning
)

# %%
last_window_values=forecaster.last_window_.to_numpy().flatten()
exog_values=exog.to_numpy()

# %%
# %%timeit -n 20 -r 20

# skforecast 0.16.0
forecaster._recursive_predict(
    steps=100,
    last_window_values=last_window_values,
    exog_values=exog_values,
    residuals=None,
    use_binned_residuals=True
)
# Out:
# 1.16 ms ± 230 μs per loop (mean ± std. dev. of 20 runs, 20 loops each)

# %%
# skforecast 0.16.0
# ==============================================================================

import warnings
warnings.filterwarnings(
    "ignore", 
    message=".*X does not have valid feature names.*", 
    category=UserWarning
)


def funt_to_profile(steps, exog):
    forecaster._recursive_predict(
        steps=steps,
        last_window_values=forecaster.last_window_.to_numpy().flatten(),
        exog_values=exog.to_numpy(),
        residuals = None,
        use_binned_residuals=True
    )

# %lprun -f forecaster._recursive_predict funt_to_profile(100, exog_prediction)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.00465739 s
# File: /home/joaquin/miniconda3/envs/skforecast_16_py12/lib/python3.12/site-packages/skforecast/recursive/_forecaster_recursive.py
# Function: _recursive_predict at line 1234
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#   1234                                               def _recursive_predict(
#   1235                                                   self,
#   1236                                                   steps: int,
#   1237                                                   last_window_values: np.ndarray,
#   1238                                                   exog_values: np.ndarray | None = None,
#   1239                                                   residuals: np.ndarray | dict[str, np.ndarray] | None = None,
#   1240                                                   use_binned_residuals: bool = True,
#   1241                                               ) -> np.ndarray:
#   1242                                                   """
#   1243                                                   Predict n steps ahead. It is an iterative process in which, each prediction,
#   1244                                                   is used as a predictor for the next step.
#   1245
#   1246                                                   Parameters
#   1247                                                   ----------
#   1248                                                   steps : int
#   1249                                                       Number of steps to predict.
#   1250                                                   last_window_values : numpy ndarray
#   1251                                                       Series values used to create the predictors needed in the first
#   1252                                                       iteration of the prediction (t + 1).
#   1253                                                   exog_values : numpy ndarray, default None
#   1254                                                       Exogenous variable/s included as predictor/s.
#   1255                                                   residuals : numpy ndarray, dict, default None
#   1256                                                       Residuals used to generate bootstrapping predictions.
#   1257                                                   use_binned_residuals : bool, default True
#   1258                                                       If `True`, residuals are selected based on the predicted values
#   1259                                                       (binned selection).
#   1260                                                       If `False`, residuals are selected randomly.
#   1261
#   1262                                                   Returns
#   1263                                                   -------
#   1264                                                   predictions : numpy ndarray
#   1265                                                       Predicted values.
#   1266
#   1267                                                   """
#   1268
#   1269         1      15560.0  15560.0      0.3          original_device = set_cpu_gpu_device(regressor=self.regressor, device='cpu')
#   1270
#   1271         1       2672.0   2672.0      0.1          n_lags = len(self.lags) if self.lags is not None else 0
#   1272         1        563.0    563.0      0.0          n_window_features = (
#   1273                                                       len(self.X_train_window_features_names_out_)
#   1274         1        693.0    693.0      0.0              if self.window_features is not None
#   1275         1        571.0    571.0      0.0              else 0
#   1276                                                   )
#   1277         1       2433.0   2433.0      0.1          n_exog = exog_values.shape[1] if exog_values is not None else 0
#   1278
#   1279         2      28894.0  14447.0      0.6          X = np.full(
#   1280         1       1397.0   1397.0      0.0              shape=(n_lags + n_window_features + n_exog), fill_value=np.nan, dtype=float
#   1281                                                   )
#   1282         1      11419.0  11419.0      0.2          predictions = np.full(shape=steps, fill_value=np.nan, dtype=float)
#   1283         1      14072.0  14072.0      0.3          last_window = np.concatenate((last_window_values, predictions))
#   1284
#   1285       101      91578.0    906.7      2.0          for i in range(steps):
#   1286
#   1287       100      69862.0    698.6      1.5              if self.lags is not None:
#   1288       100    1034388.0  10343.9     22.2                  X[:n_lags] = last_window[-self.lags - (steps - i)]
#   1289       100      86862.0    868.6      1.9              if self.window_features is not None:
#   1290                                                           X[n_lags : n_lags + n_window_features] = np.concatenate(
#   1291                                                               [
#   1292                                                                   wf.transform(last_window[i : -(steps - i)])
#   1293                                                                   for wf in self.window_features
#   1294                                                               ]
#   1295                                                           )
#   1296       100      69666.0    696.7      1.5              if exog_values is not None:
#   1297       100     248934.0   2489.3      5.3                  X[n_lags + n_window_features:] = exog_values[i]
#   1298
#   1299       100    2600796.0  26008.0     55.8              pred = self.regressor.predict(X.reshape(1, -1)).ravel()
#   1300
#   1301       100      74346.0    743.5      1.6              if residuals is not None:
#   1302                                                           if use_binned_residuals:
#   1303                                                               predicted_bin = self.binner.transform(pred).item()
#   1304                                                               step_residual = residuals[predicted_bin][i]
#   1305                                                           else:
#   1306                                                               step_residual = residuals[i]
#   1307
#   1308                                                           pred += step_residual
#   1309
#   1310       100     157332.0   1573.3      3.4              predictions[i] = pred[0]
#   1311
#   1312                                                       # Update `last_window` values. The first position is discarded and
#   1313                                                       # the new prediction is added at the end.
#   1314       100     132377.0   1323.8      2.8              last_window[-(steps - i)] = pred[0]
#   1315
#   1316         1       8667.0   8667.0      0.2          set_cpu_gpu_device(regressor=self.regressor, device=original_device)
#   1317
#   1318         1       4309.0   4309.0      0.1          return predictions

# %%
import numpy as np
rng = np.random.default_rng(321)
X_test = rng.random((1, len(forecaster.lags) + exog.shape[1])).astype(np.float64)
print(X_test.flags)
# Out:
#   C_CONTIGUOUS : True
#   F_CONTIGUOUS : True
#   OWNDATA : True
#   WRITEABLE : True
#   ALIGNED : True
#   WRITEBACKIFCOPY : False

# %%
# %%timeit
forecaster.regressor.predict(X_test)
# Out:
# 2.35 μs ± 79.6 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %%timeit -n 10 -r 10

# skforecast 0.16.0
cv = TimeSeriesFold(
    initial_train_size=int(len(y)/ 2),
    steps=100,
    fixed_train_size=False,
    refit=False,
)

backtesting_forecaster(
    forecaster=forecaster,
    y=y,
    exog=exog,
    cv=cv,
    metric='mean_squared_error',
    show_progress=False,
    verbose=False
)
# Out:
# 251 ms ± 25.9 ms per loop (mean ± std. dev. of 10 runs, 10 loops each)
