# %% [markdown]
# # Compare autoarima from Skforecast, pmdarima and statsforecast

# %%
# %load_ext autoreload
# %autoreload 2
import sys
from pathlib import Path
path = str(Path.cwd().parent)
print(path)
sys.path.insert(1, path)
import skforecast

print(skforecast.__version__)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/joaquin/Documents/GitHub/skforecast
# 0.21.0

# %%
# Libraries
# ==============================================================================
import numpy as np
import pandas as pd
from pmdarima import auto_arima
from skforecast.stats import Arima
from statsforecast.models import AutoARIMA
from statsforecast.arima import arima_string
import warnings
import timeit

# %%
# Datasets
# ==============================================================================
from fixtures_arima import datasets

# %%
# Benchmarking ARIMA implementations
# ==============================================================================
warnings.filterwarnings("ignore", message=".*force_all_finite.*")
warnings.filterwarnings("ignore", message=".*Non-stationary starting seasonal autoregressive.*")
warnings.filterwarnings("ignore", message=".*Too few observations to estimate starting parameters.*")
warnings.filterwarnings("ignore", message=".*Too few observations to estimate starting parameters for seasonal ARMA.*")

results = []
for key, value in datasets.items():
    data = value['data']
    m = value['seasonal_periods']
    name = key
    print(f"Dataset: {name}")

    # pmdarima
    try:
        print("    pmdarima...")
        start = timeit.default_timer()
        res = auto_arima(
            y=data,
            start_p=0,
            start_q=0,
            max_p=5,
            max_q=5,
            max_P=2,
            max_D=1,
            max_Q=2,
            seasonal=True,
            information_criterion="aic",
            test="kpss",
            m=m,
            d=None,
            D=None,
            trace=False,
            n_fits=94,
            method="bfgs",
            maxiter=500,
            error_action="ignore",
            suppress_warnings=True,
            stepwise=True,
        )
        end = timeit.default_timer()
        elapsed_time = end - start
        best_model = f"{res.order}{res.seasonal_order[:3]}[{res.seasonal_order[3]}]"
        aic = res.aic()
    except Exception as e:
        elapsed_time = np.nan
        best_model = "(nan, nan, nan)(nan, nan, nan)[nan]"
        aic = np.nan
    results.append([name, "pmdarima", best_model, aic, elapsed_time])
    print(f"        time: {elapsed_time:.2f} seconds")
    print(f"        best model: {best_model}")

    # skforecast
    print("    skforecast...")
    try:
        start = timeit.default_timer()
        res = Arima(
            order=None,
            seasonal_order=None,
            start_p=0,
            start_q=0,
            max_p=5,
            max_q=5,
            max_P=2,
            max_Q=2,
            max_order=5,
            max_d=2,
            max_D=1,
            ic="aic",
            seasonal=True,
            test="kpss",
            nmodels=94,
            optim_method="BFGS",
            m=m,
            trace=False,
            stepwise=True,
        )
        res.fit(y=data, suppress_warnings=True)
        end = timeit.default_timer()
        elapsed_time = end - start
        best_model = f"{res.best_params_['order']}{res.best_params_['seasonal_order']}[{res.best_params_['m']}]"
        aic = res.aic_
    except Exception as e:
        elapsed_time = np.nan
        best_model = "(nan, nan, nan)(nan, nan, nan)[nan]"
        aic = np.nan
    results.append([name, "skforecast", best_model, aic, elapsed_time])
    print(f"        time: {elapsed_time:.2f} seconds")
    print(f"        best model: {best_model}")

    # statsforecast
    print("    statsforecast...")
    try:
        start = timeit.default_timer()
        res = AutoARIMA(
            start_p=0,
            start_q=0,
            max_p=5,
            max_q=5,
            max_P=2,
            max_D=1,
            max_Q=2,
            nmodels=94,
            test="kpss",
            ic="aic",
            d=None,
            D=None,
            seasonal=True,
            season_length=m,
            stepwise=True,
            trace=False,
        )
        res.fit(y=data)
        end = timeit.default_timer()
        elapsed_time = end - start
        best_model = arima_string(res.model_)[5:].replace(",", ", ")
        aic = res.model_['aic']
    except Exception as e:
        elapsed_time = np.nan
        best_model = "(nan, nan, nan)(nan, nan, nan)[nan]"
        aic = np.nan
    results.append([name, "statsforecast", best_model, aic, elapsed_time])
    print(f"        time: {elapsed_time:.2f} seconds")
    print(f"        best model: {best_model}")
# Out:
# Dataset: air_passengers
#     pmdarima...
#         time: 48.05 seconds
#         best model: (0, 1, 1)(2, 1, 1)[12]
#     skforecast...
#         time: 3.01 seconds
#         best model: (2, 1, 1)(0, 1, 0)[12]
#     statsforecast...
#         time: 0.40 seconds
#         best model: (1, 1, 0)(0, 1, 0)[12]
# Dataset: monthly_data
#     pmdarima...
#         time: 1.36 seconds
#         best model: (0, 0, 0)(0, 1, 0)[12]
#     skforecast...
#         time: 0.22 seconds
#         best model: (0, 0, 0)(0, 1, 0)[12]
#     statsforecast...
#         time: 0.33 seconds
#         best model: (0, 0, 0)(0, 1, 0)[12]
# Dataset: quarterly_data
#     pmdarima...
#         time: 3.13 seconds
#         best model: (0, 0, 0)(0, 1, 1)[4]
#     skforecast...
#         time: 0.62 seconds
#         best model: (0, 0, 0)(0, 1, 1)[4]
#     statsforecast...
#         time: 0.70 seconds
#         best model: (0, 0, 0)(0, 1, 1)[4]
# Dataset: daily_data
#     pmdarima...
#         time: 8.08 seconds
#         best model: (0, 0, 0)(1, 1, 0)[7]
#     skforecast...
#         time: 0.54 seconds
#         best model: (0, 0, 0)(1, 1, 1)[7]
#     statsforecast...
#         time: 0.46 seconds
#         best model: (0, 0, 0)(0, 1, 1)[7]
# Dataset: hourly_data
#     pmdarima...
#         time: 28.94 seconds
#         best model: (1, 0, 0)(1, 0, 0)[24]
#     skforecast...
#         time: 2.15 seconds
#         best model: (1, 0, 0)(0, 1, 1)[24]
#     statsforecast...
#         time: 1.63 seconds
#         best model: (0, 0, 1)(0, 1, 1)[24] with drift
# Dataset: no_seasonal_data
#     pmdarima...
#         time: 0.29 seconds
#         best model: (0, 0, 1)(0, 0, 0)[0]
#     skforecast...
#         time: 0.07 seconds
#         best model: (1, 0, 0)(0, 0, 0)[1]
#     statsforecast...
#         time: 0.26 seconds
#         best model: (0, 0, 1) with non-zero mean
# Dataset: strong_seasonal
#     pmdarima...
#         time: 66.71 seconds
#         best model: (0, 0, 0)(2, 1, 1)[12]
#     skforecast...
#         time: 6.40 seconds
#         best model: (0, 0, 0)(2, 1, 1)[12]
#     statsforecast...
#         time: 1.88 seconds
#         best model: (0, 0, 0)(0, 1, 1)[12]
# Dataset: multi_seasonal
#     pmdarima...
#         time: 132.28 seconds
#         best model: (5, 1, 1)(1, 0, 0)[7]
#     skforecast...
#         time: 13.78 seconds
#         best model: (5, 1, 3)(0, 0, 0)[7]
#     statsforecast...
#         time: 6.45 seconds
#         best model: (3, 1, 2) with drift
# Dataset: sunspots_data
#     pmdarima...
#         time: 347.38 seconds
#         best model: (4, 1, 2)(2, 0, 0)[11]
#     skforecast...
#         time: 26.22 seconds
#         best model: (5, 1, 2)(0, 0, 0)[11]
#     statsforecast...
#         time: 10.40 seconds
#         best model: (3, 0, 0)(2, 1, 1)[11] with drift
# Dataset: co2_data
#     pmdarima...
#         time: 91.53 seconds
#         best model: (1, 1, 0)(1, 0, 1)[12]
#     skforecast...
#         time: 100.19 seconds
#         best model: (4, 1, 4)(0, 1, 1)[12]
#     statsforecast...
#         time: 20.94 seconds
#         best model: (3, 1, 3)(2, 1, 2)[12]
# Dataset: macrodata_data
#     pmdarima...
#         time: 0.68 seconds
#         best model: (2, 0, 0)(0, 0, 0)[0]
#     skforecast...
#         time: 0.17 seconds
#         best model: (2, 0, 0)(0, 0, 0)[1]
#     statsforecast...
#         time: 0.48 seconds
#         best model: (2, 0, 0) with non-zero mean
# Dataset: nile_data
#     pmdarima...
#         time: 1.36 seconds
#         best model: (1, 1, 1)(0, 0, 0)[0]
#     skforecast...
#         time: 0.23 seconds
#         best model: (1, 1, 1)(0, 0, 0)[1]
#     statsforecast...
#         time: 0.64 seconds
#         best model: (1, 1, 1)
# Dataset: fuel_consumption
#     pmdarima...
#         time: 63.85 seconds
#         best model: (1, 1, 1)(0, 1, 1)[12]
#     skforecast...
#         time: 16.19 seconds
#         best model: (1, 1, 1)(2, 1, 2)[12]
#     statsforecast...
# /home/joaquin/miniconda3/envs/skforecast_21_py13/lib/python3.13/site-packages/statsforecast/arima.py:1130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return np.all(x[0] == x)
#         time: 1.81 seconds
#         best model: (1, 1, 1)(0, 1, 1)[12]
# Dataset: h2o_data
#     pmdarima...
#         time: 206.71 seconds
#         best model: (3, 0, 1)(1, 1, 1)[12]
#     skforecast...
#         time: 11.22 seconds
#         best model: (3, 0, 1)(0, 1, 1)[12]
#     statsforecast...
# /home/joaquin/miniconda3/envs/skforecast_21_py13/lib/python3.13/site-packages/statsforecast/arima.py:1130: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return np.all(x[0] == x)
#         time: 5.96 seconds
#         best model: (3, 0, 1)(0, 1, 1)[12] with drift

# %%
# Results
# ==============================================================================
results_df = pd.DataFrame(
    results,
    columns=["dataset", "library", "Best Model", "AIC", "Time"]
)
results_df['Best Model'] = results_df['Best Model'].str.replace(', ', ',').str.strip()
results_df = results_df.set_index(['dataset'])
results_df['All_Same_Model'] = results_df.groupby('dataset')['Best Model'].transform(lambda x: x.nunique() == 1)
results_df
# Out:
#                         library                     Best Model          AIC  \
# dataset
# air_passengers         pmdarima             (0,1,1)(2,1,1)[12]  1018.243685
# air_passengers       skforecast             (2,1,1)(0,1,0)[12]  1018.270024
# air_passengers    statsforecast             (1,1,0)(0,1,0)[12]  1020.394372
# monthly_data           pmdarima             (0,0,0)(0,1,0)[12]   201.117107
# monthly_data         skforecast             (0,0,0)(0,1,0)[12]   201.805756
# monthly_data      statsforecast             (0,0,0)(0,1,0)[12]   201.117107
# quarterly_data         pmdarima              (0,0,0)(0,1,1)[4]   153.509042
# quarterly_data       skforecast              (0,0,0)(0,1,1)[4]   154.527856
# quarterly_data    statsforecast              (0,0,0)(0,1,1)[4]   153.554007
# daily_data             pmdarima              (0,0,0)(1,1,0)[7]   363.314420
# daily_data           skforecast              (0,0,0)(1,1,1)[7]   364.842344
# daily_data        statsforecast              (0,0,0)(0,1,1)[7]   363.976210
# hourly_data            pmdarima             (1,0,0)(1,0,0)[24]   777.407703
# hourly_data          skforecast             (1,0,0)(0,1,1)[24]   564.955725
# hourly_data       statsforecast  (0,0,1)(0,1,1)[24] with drift   567.595430
# no_seasonal_data       pmdarima              (0,0,1)(0,0,0)[0]   174.570396
# no_seasonal_data     skforecast              (1,0,0)(0,0,0)[1]   174.467101
# no_seasonal_data  statsforecast     (0,0,1) with non-zero mean   174.570396
# strong_seasonal        pmdarima             (0,0,0)(2,1,1)[12]  1429.442005
# strong_seasonal      skforecast             (0,0,0)(2,1,1)[12]  1430.515255
# strong_seasonal   statsforecast             (0,0,0)(0,1,1)[12]  1429.134533
# multi_seasonal         pmdarima              (5,1,1)(1,0,0)[7]  5540.075389
# multi_seasonal       skforecast              (5,1,3)(0,0,0)[7]  5527.908709
# multi_seasonal    statsforecast             (3,1,2) with drift  5508.623482
# sunspots_data          pmdarima             (4,1,2)(2,0,0)[11]  2599.724593
# sunspots_data        skforecast             (5,1,2)(0,0,0)[11]  2568.473143
# sunspots_data     statsforecast  (3,0,0)(2,1,1)[11] with drift  2535.665286
# co2_data               pmdarima             (1,1,0)(1,0,1)[12]   732.882768
# co2_data             skforecast             (4,1,4)(0,1,1)[12]   596.801084
# co2_data          statsforecast             (3,1,3)(2,1,2)[12]   618.785324
# macrodata_data         pmdarima              (2,0,0)(0,0,0)[0] -1353.828251
# macrodata_data       skforecast              (2,0,0)(0,0,0)[1] -1354.075841
# macrodata_data    statsforecast     (2,0,0) with non-zero mean -1353.828251
# nile_data              pmdarima              (1,1,1)(0,0,0)[0]  1267.218697
# nile_data            skforecast              (1,1,1)(0,0,0)[1]  1268.266770
# nile_data         statsforecast                        (1,1,1)  1267.276297
# fuel_consumption       pmdarima             (1,1,1)(0,1,1)[12]  5469.858171
# fuel_consumption     skforecast             (1,1,1)(2,1,2)[12]  5379.165964
# fuel_consumption  statsforecast             (1,1,1)(0,1,1)[12]  5384.467162
# h2o_data               pmdarima             (3,0,1)(1,1,1)[12]  -546.902600
# h2o_data             skforecast             (3,0,1)(0,1,1)[12]  -546.578130
# h2o_data          statsforecast  (3,0,1)(0,1,1)[12] with drift  -547.493798
#
#                         Time  All_Same_Model
# dataset
# air_passengers     48.052674           False
# air_passengers      3.009328           False
# air_passengers      0.400602           False
# monthly_data        1.361342            True
# monthly_data        0.217323            True
# monthly_data        0.325813            True
# quarterly_data      3.134594            True
# quarterly_data      0.615376            True
# quarterly_data      0.701067            True
# daily_data          8.082583           False
# daily_data          0.535777           False
# daily_data          0.455451           False
# hourly_data        28.937207           False
# hourly_data         2.149583           False
# hourly_data         1.628322           False
# no_seasonal_data    0.292776           False
# no_seasonal_data    0.066113           False
# no_seasonal_data    0.255638           False
# strong_seasonal    66.710426           False
# strong_seasonal     6.395547           False
# strong_seasonal     1.880603           False
# multi_seasonal    132.277526           False
# multi_seasonal     13.781017           False
# multi_seasonal      6.453361           False
# sunspots_data     347.380327           False
# sunspots_data      26.217231           False
# sunspots_data      10.402097           False
# co2_data           91.526084           False
# co2_data          100.190089           False
# co2_data           20.937880           False
# macrodata_data      0.684787           False
# macrodata_data      0.168374           False
# macrodata_data      0.476132           False
# nile_data           1.359124           False
# nile_data           0.234785           False
# nile_data           0.636257           False
# fuel_consumption   63.849953           False
# fuel_consumption   16.188930           False
# fuel_consumption    1.811074           False
# h2o_data          206.713175           False
# h2o_data           11.217760           False
# h2o_data            5.958156           False

# %%
# Plot searching times
# ==============================================================================
from matplotlib import pyplot as plt
from skforecast.plot import set_dark_theme
set_dark_theme()

df_plot = results_df.pivot(columns="library", values="Time")
ax = df_plot.plot(kind="bar", figsize=(8,4))
plt.yscale("log") 
ax.set_ylabel("Time to fit AutoARIMA (log scale)")
ax.set_xlabel("Dataset")
plt.title("Time to fit AutoARIMA per Library for Each Dataset (log scale)")
plt.xticks(rotation=45)
plt.legend(title="Library")
plt.tight_layout()
plt.show()

# %%
# Number of datasets where skforecast and statsforecast found the same best model
# ==============================================================================
results_skforecast_statsforecast = (
    results_df
    .query("library in ['skforecast', 'statsforecast']")
).copy()
results_skforecast_statsforecast['All_Same_Model'] = (
    results_skforecast_statsforecast
    .groupby('dataset')['Best Model']
    .transform(lambda x: x.nunique() == 1)
)
n_same_model = results_skforecast_statsforecast.groupby('dataset')['All_Same_Model'].first().sum()
print(f"Number of datasets where skforecast and statsforecast found the same best model: {n_same_model} out of {len(datasets)}")
results_skforecast_statsforecast
# Out:
# Number of datasets where skforecast and statsforecast found the same best model: 2 out of 14
#                         library                     Best Model          AIC  \
# dataset
# air_passengers       skforecast             (2,1,1)(0,1,0)[12]  1018.270024
# air_passengers    statsforecast             (1,1,0)(0,1,0)[12]  1020.394372
# monthly_data         skforecast             (0,0,0)(0,1,0)[12]   201.805756
# monthly_data      statsforecast             (0,0,0)(0,1,0)[12]   201.117107
# quarterly_data       skforecast              (0,0,0)(0,1,1)[4]   154.527856
# quarterly_data    statsforecast              (0,0,0)(0,1,1)[4]   153.554007
# daily_data           skforecast              (0,0,0)(1,1,1)[7]   364.842344
# daily_data        statsforecast              (0,0,0)(0,1,1)[7]   363.976210
# hourly_data          skforecast             (1,0,0)(0,1,1)[24]   564.955725
# hourly_data       statsforecast  (0,0,1)(0,1,1)[24] with drift   567.595430
# no_seasonal_data     skforecast              (1,0,0)(0,0,0)[1]   174.467101
# no_seasonal_data  statsforecast     (0,0,1) with non-zero mean   174.570396
# strong_seasonal      skforecast             (0,0,0)(2,1,1)[12]  1430.515255
# strong_seasonal   statsforecast             (0,0,0)(0,1,1)[12]  1429.134533
# multi_seasonal       skforecast              (5,1,3)(0,0,0)[7]  5527.908709
# multi_seasonal    statsforecast             (3,1,2) with drift  5508.623482
# sunspots_data        skforecast             (5,1,2)(0,0,0)[11]  2568.473143
# sunspots_data     statsforecast  (3,0,0)(2,1,1)[11] with drift  2535.665286
# co2_data             skforecast             (4,1,4)(0,1,1)[12]   596.801084
# co2_data          statsforecast             (3,1,3)(2,1,2)[12]   618.785324
# macrodata_data       skforecast              (2,0,0)(0,0,0)[1] -1354.075841
# macrodata_data    statsforecast     (2,0,0) with non-zero mean -1353.828251
# nile_data            skforecast              (1,1,1)(0,0,0)[1]  1268.266770
# nile_data         statsforecast                        (1,1,1)  1267.276297
# fuel_consumption     skforecast             (1,1,1)(2,1,2)[12]  5379.165964
# fuel_consumption  statsforecast             (1,1,1)(0,1,1)[12]  5384.467162
# h2o_data             skforecast             (3,0,1)(0,1,1)[12]  -546.578130
# h2o_data          statsforecast  (3,0,1)(0,1,1)[12] with drift  -547.493798
#
#                         Time  All_Same_Model
# dataset
# air_passengers      3.009328           False
# air_passengers      0.400602           False
# monthly_data        0.217323            True
# monthly_data        0.325813            True
# quarterly_data      0.615376            True
# quarterly_data      0.701067            True
# daily_data          0.535777           False
# daily_data          0.455451           False
# hourly_data         2.149583           False
# hourly_data         1.628322           False
# no_seasonal_data    0.066113           False
# no_seasonal_data    0.255638           False
# strong_seasonal     6.395547           False
# strong_seasonal     1.880603           False
# multi_seasonal     13.781017           False
# multi_seasonal      6.453361           False
# sunspots_data      26.217231           False
# sunspots_data      10.402097           False
# co2_data          100.190089           False
# co2_data           20.937880           False
# macrodata_data      0.168374           False
# macrodata_data      0.476132           False
# nile_data           0.234785           False
# nile_data           0.636257           False
# fuel_consumption   16.188930           False
# fuel_consumption    1.811074           False
# h2o_data           11.217760           False
# h2o_data            5.958156           False

# %%
# Number of datasets where skforecast and pmdarima found the same best model
# ==============================================================================
results_skforecast_pdmarima = (
    results_df
    .query("library in ['skforecast', 'pmdarima']")
).copy()
results_skforecast_pdmarima['All_Same_Model'] = (
    results_skforecast_pdmarima
    .groupby('dataset')['Best Model']
    .transform(lambda x: x.nunique() == 1)
)
n_same_model = results_skforecast_pdmarima.groupby('dataset')['All_Same_Model'].first().sum()
print(f"Number of datasets where skforecast and pmdarima found the same best model: {n_same_model} out of {len(datasets)}")
results_skforecast_pdmarima
# Out:
# Number of datasets where skforecast and pmdarima found the same best model: 3 out of 14
#                      library          Best Model          AIC        Time  \
# dataset
# air_passengers      pmdarima  (0,1,1)(2,1,1)[12]  1018.243685   48.052674
# air_passengers    skforecast  (2,1,1)(0,1,0)[12]  1018.270024    3.009328
# monthly_data        pmdarima  (0,0,0)(0,1,0)[12]   201.117107    1.361342
# monthly_data      skforecast  (0,0,0)(0,1,0)[12]   201.805756    0.217323
# quarterly_data      pmdarima   (0,0,0)(0,1,1)[4]   153.509042    3.134594
# quarterly_data    skforecast   (0,0,0)(0,1,1)[4]   154.527856    0.615376
# daily_data          pmdarima   (0,0,0)(1,1,0)[7]   363.314420    8.082583
# daily_data        skforecast   (0,0,0)(1,1,1)[7]   364.842344    0.535777
# hourly_data         pmdarima  (1,0,0)(1,0,0)[24]   777.407703   28.937207
# hourly_data       skforecast  (1,0,0)(0,1,1)[24]   564.955725    2.149583
# no_seasonal_data    pmdarima   (0,0,1)(0,0,0)[0]   174.570396    0.292776
# no_seasonal_data  skforecast   (1,0,0)(0,0,0)[1]   174.467101    0.066113
# strong_seasonal     pmdarima  (0,0,0)(2,1,1)[12]  1429.442005   66.710426
# strong_seasonal   skforecast  (0,0,0)(2,1,1)[12]  1430.515255    6.395547
# multi_seasonal      pmdarima   (5,1,1)(1,0,0)[7]  5540.075389  132.277526
# multi_seasonal    skforecast   (5,1,3)(0,0,0)[7]  5527.908709   13.781017
# sunspots_data       pmdarima  (4,1,2)(2,0,0)[11]  2599.724593  347.380327
# sunspots_data     skforecast  (5,1,2)(0,0,0)[11]  2568.473143   26.217231
# co2_data            pmdarima  (1,1,0)(1,0,1)[12]   732.882768   91.526084
# co2_data          skforecast  (4,1,4)(0,1,1)[12]   596.801084  100.190089
# macrodata_data      pmdarima   (2,0,0)(0,0,0)[0] -1353.828251    0.684787
# macrodata_data    skforecast   (2,0,0)(0,0,0)[1] -1354.075841    0.168374
# nile_data           pmdarima   (1,1,1)(0,0,0)[0]  1267.218697    1.359124
# nile_data         skforecast   (1,1,1)(0,0,0)[1]  1268.266770    0.234785
# fuel_consumption    pmdarima  (1,1,1)(0,1,1)[12]  5469.858171   63.849953
# fuel_consumption  skforecast  (1,1,1)(2,1,2)[12]  5379.165964   16.188930
# h2o_data            pmdarima  (3,0,1)(1,1,1)[12]  -546.902600  206.713175
# h2o_data          skforecast  (3,0,1)(0,1,1)[12]  -546.578130   11.217760
#
#                   All_Same_Model
# dataset
# air_passengers             False
# air_passengers             False
# monthly_data                True
# monthly_data                True
# quarterly_data              True
# quarterly_data              True
# daily_data                 False
# daily_data                 False
# hourly_data                False
# hourly_data                False
# no_seasonal_data           False
# no_seasonal_data           False
# strong_seasonal             True
# strong_seasonal             True
# multi_seasonal             False
# multi_seasonal             False
# sunspots_data              False
# sunspots_data              False
# co2_data                   False
# co2_data                   False
# macrodata_data             False
# macrodata_data             False
# nile_data                  False
# nile_data                  False
# fuel_consumption           False
# fuel_consumption           False
# h2o_data                   False
# h2o_data                   False
