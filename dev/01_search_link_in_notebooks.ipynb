# %% [markdown]
# # Search links in docs
#
# pip install nbformat

# %%
import os
import nbformat

def search_text_in_files(directory, search_text_base):
    notebooks_with_text = []
    markdown_files_with_text = []

    # Recorre todos los archivos de la carpeta
    for root, dirs, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            if file.endswith(".ipynb"):
                with open(file_path, 'r', encoding='utf-8') as f:
                    nb = nbformat.read(f, as_version=4)
                    
                    # Recorre todas las celdas del notebook
                    for cell in nb.cells:
                        if cell.cell_type == 'markdown':
                            if search_text_base in cell.source:
                                notebooks_with_text.append(file_path)
                                break
            elif file.endswith(".md"):
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                    if search_text_base in content:
                        markdown_files_with_text.append(file_path)

    return notebooks_with_text, markdown_files_with_text

# Especifica la carpeta que contiene los notebooks y el texto a buscar
directory_path = '../docs/'
search_texts = [
    "https://skforecast.org/latest/introduction-forecasting/forecaster-parameters",
    "https://skforecast.org/latest/introduction-forecasting/forecaster-attributes",
    "https://skforecast.org/latest/user_guides/quick-start-skforecast",
    "https://skforecast.org/latest/user_guides/input-data",
    "https://skforecast.org/0.",
    "https://skforecast.org/0.12.1/user_guides/plot-forecaster-residuals",
    "https://skforecast.org/latest/user_guides/plot-forecaster-residuals"
]
search_texts = [
    "https://skforecast.org",
    "https://skforecast.org/latest/user_guides/user_guides",
    "../user_guides/user_guides",
    "https://skforecast.org/latest/faq/faq",
    "../faq/faq",
    "joaquin"
]

for search_text_base in search_texts:

    print(search_text_base)
    print("=" * len(search_text_base))

    # Llama a la función y obtén los notebooks que contienen el texto buscado
    notebooks, markdown_files = search_text_in_files(directory_path, search_text_base)

    # Imprime la lista de notebooks que contienen el texto
    if notebooks:
        print("The following notebooks contain the specified text:")
        for notebook in notebooks:
            print(notebook)
    else:
        print("No notebooks contain the specified text.")

    if markdown_files:
        print("\nThe following markdown files contain the specified text:")
        for markdown_file in markdown_files:
            print(markdown_file)
    else:
        print("No markdown files contain the specified text.")

    print("=" * len(search_text_base))
    print("\n")
# Out:
# https://skforecast.org
# ======================
# The following notebooks contain the specified text:
# ../docs/user_guides\forecasting-sarimax-arima.ipynb
# ../docs/user_guides\probabilistic-forecasting.ipynb
# ../docs/user_guides\weighted-time-series-forecasting.ipynb
#
# The following markdown files contain the specified text:
# ../docs/README.md
# ../docs/releases\releases.md
# ======================
#
#
# https://skforecast.org/latest/user_guides/user_guides
# =====================================================
# c:\Users\jaesc2\Miniconda3\envs\skforecast_py11\Lib\site-packages\nbformat\__init__.py:93: MissingIDFieldWarning: Code cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# No notebooks contain the specified text.
# No markdown files contain the specified text.
# =====================================================
#
#
# ../user_guides/user_guides
# ==========================
# No notebooks contain the specified text.
# No markdown files contain the specified text.
# ==========================
#
#
# https://skforecast.org/latest/faq/faq
# =====================================
# No notebooks contain the specified text.
# No markdown files contain the specified text.
# =====================================
#
#
# ../faq/faq
# ==========
# No notebooks contain the specified text.
# No markdown files contain the specified text.
# ==========
#
#
# joaquin
# =======
# No notebooks contain the specified text.
#
# The following markdown files contain the specified text:
# ../docs/README.md
# ../docs/releases\releases.md
# =======

# %% [markdown]
# # Test links docs

# %%
base_url = "https://skforecast.org/0.14.0/"

# Lista de rutas extraídas del archivo mkdocs.yml
paths_general = [
    "",

    "examples/examples_english.md",
    "examples/examples_spanish.md",

    "api/ForecasterRecursive.md",
    "api/ForecasterDirect.md",
    "api/ForecasterRecursiveMultiSeries.md",
    "api/ForecasterDirectMultiVariate.md",
    "api/ForecasterRnn.md",
    "api/Sarimax.md",
    "api/ForecasterSarimax.md",
    "api/ForecasterEquivalentDate.md",
    "api/model_selection.md",
    "api/feature_selection.md",
    "api/preprocessing.md",
    "api/metrics.md",
    "api/plot.md",
    "api/utils.md",
    "api/datasets.md",
    "api/exceptions.md",

    "releases/releases.md",

    "authors/authors.md"
]

paths_user_guides = [
    "introduction-forecasting/introduction-forecasting.md",

    "user_guides/migration-guide.ipynb",
    
    "quick-start/quick-start-skforecast.ipynb",
    "quick-start/forecaster-parameters.md",
    "quick-start/forecaster-attributes.ipynb",
    "quick-start/how-to-install.md",
    
    "user_guides/table-of-contents.md",
    "user_guides/migration-guide.html",
    "user_guides/input-data.ipynb",
    "user_guides/autoregresive-forecaster.ipynb",
    "user_guides/direct-multi-step-forecasting.ipynb",
    "user_guides/forecasting-sarimax-arima.ipynb",
    "user_guides/forecasting-baseline.ipynb",
    "user_guides/independent-multi-time-series-forecasting.ipynb",
    "user_guides/multi-series-with-different-length-and-different_exog.ipynb",
    "user_guides/dependent-multi-series-multivariate-forecasting.ipynb",
    "user_guides/forecasting-with-deep-learning-rnn-lstm.ipynb",
    "user_guides/exogenous-variables.ipynb",
    "user_guides/window-features-and-custom-features.ipynb",
    "user_guides/categorical-features.ipynb",
    "user_guides/calendar-features.ipynb",
    "user_guides/sklearn-transformers-and-pipeline.ipynb",
    "user_guides/time-series-differentiation.ipynb",
    "user_guides/feature-selection.ipynb",
    "user_guides/metrics.ipynb",
    "user_guides/backtesting.ipynb",
    "user_guides/hyperparameter-tuning-and-lags-selection.ipynb",
    "user_guides/feature-selection.ipynb",
    "user_guides/probabilistic-forecasting.ipynb",
    "user_guides/explainability.ipynb",
    "user_guides/save-load-forecaster.ipynb",
    "user_guides/forecaster-in-production.ipynb",
    "user_guides/plotting.ipynb",
    "user_guides/datasets.ipynb",
    "user_guides/training-and-prediction-matrices.ipynb",
    "user_guides/weighted-time-series-forecasting.ipynb",
    "user_guides/stacking-ensemble-models-forecasting.ipynb",
    "user_guides/forecasting-xgboost-lightgbm.ipynb",
    "user_guides/skforecast-in-GPU.ipynb",

    "faq/table-of-contents.md",
    "faq/non-negative-predictions.ipynb",
    "faq/forecasting-time-series-with-missing-values.ipynb",
    "faq/forecasting-with-delayed-historical-data.ipynb",
    "faq/parameters-search-backtesting-vs-one-step-ahead.ipynb",
    "faq/cyclical-features-time-series.ipynb",
    "faq/time-series-aggregation.ipynb",
    "faq/parallelization-skforecast.ipynb",
    "faq/profiling-skforecast.ipynb",
]


# Función para cambiar la extensión a .html
def change_extension_to_html(path):
    if path.endswith(".md") or path.endswith(".ipynb"):
        return path.rsplit(".", 1)[0] + ".html"
    return path


# Generar enlaces completos con extensión .html
links_general = [
    base_url + change_extension_to_html(path) for path in paths_general
]
links_user_guides = [
    base_url + change_extension_to_html(path) for path in paths_user_guides
]

# %%
from colorama import Fore, Style

print("Esto es un texto normal")
print(Fore.RED + "Este texto es rojo" + Style.RESET_ALL)
print(Fore.GREEN + "Este texto es verde" + Style.RESET_ALL)
print(Fore.BLUE + "Este texto es azul" + Style.RESET_ALL)
print(Style.BRIGHT + Fore.RED + "Este texto es rojo en negrita" + Style.RESET_ALL)
print("Esto es un texto normal")
# Out:
# Esto es un texto normal
# Este texto es rojo
# Este texto es verde
# Este texto es azul
# Este texto es rojo en negrita
# Esto es un texto normal

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from colorama import Fore, Style


def check_links_ignoring_nav_links(url):
    try:
        # Realizar la solicitud a la página
        response = requests.get(url)
        response.raise_for_status()  # Verificar si la solicitud fue exitosa
        print(f"[OK] Página accesible: {url}")
    except requests.exceptions.RequestException as e:
        print(
            Style.BRIGHT + Fore.RED + 
            f"[ERROR] No se pudo acceder a {url}: {e}"
            + Style.RESET_ALL
        )
        return [url]

    # Parsear el contenido HTML
    soup = BeautifulSoup(response.content, "html.parser")

    # Encontrar todos los enlaces en la página
    links = soup.find_all("a", href=True)

    # Filtrar los enlaces que no tengan alguna de las siguientes clases
    classes_no_to_visit = [
        'md-header__button', 'md-logo', "md-nav__link", "md-tabs__link",
        'md-source', 'md-social__link', 'autorefs-external'
    ]

    # Recorrer todos los enlaces filtrados
    broken_links = []
    for link in links:
        class_link = link.get("class", [])

        # Ignorar los enlaces que tengan alguna de las clases en "classes_no_to_visit"
        if any(class_no_to_visit in class_link for class_no_to_visit in classes_no_to_visit):
            continue

        # Convertir enlaces relativos en absolutos
        href = link['href']
        if href[0] == "#":
            continue

        full_url = urljoin(url, href)

        try:
            link_response = requests.get(full_url)
            link_response.raise_for_status()  # Verificar si el enlace es accesible
            print(f"  [OK] Enlace accesible: {class_link} - {full_url}")
        except requests.exceptions.RequestException:
            print(
                Style.BRIGHT + Fore.RED + 
                f"  [ERROR] Enlace roto o inaccesible: {full_url}" 
                + Style.RESET_ALL
            )
            broken_links.append(
                f"[ERROR] Enlace roto o inaccesible en {url}: {full_url}"
            )

    return broken_links

# Ejemplo de uso
url_to_check = "https://skforecast.org/0.14.0/user_guides/table-of-contents.html"
# check_links_ignoring_nav_links(url_to_check)

# %%
# Check all links in user guides list
# ==============================================================================
broken_links_list = []
for link in links_user_guides:
    broken_links = check_links_ignoring_nav_links(link)
    broken_links_list.extend(broken_links)

print("")
print("")
print(Style.BRIGHT + Fore.RED + "Resumen de enlaces rotos:")
print("-" * 80)
print("\n".join(broken_links_list) + Style.RESET_ALL)
# Out:
# [OK] Página accesible: https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting#recursive-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/quick-start/forecaster-attributes
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/exogenous-variables
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py29-forecasting-electricity-power-demand-python.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/migration-guide.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/window-features-and-custom-features
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/quick-start/quick-start-skforecast.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/table-of-contents
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/quick-start/forecaster-attributes
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/hyperparameter-tuning-and-lags-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.HistGradientBoostingRegressor.html
#   [OK] Enlace accesible: [] - https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMRegressor.html
#   [OK] Enlace accesible: [] - https://xgboost.readthedocs.io/en/stable/python/python_api.html#module-xgboost.sklearn
#   [OK] Enlace accesible: [] - https://catboost.ai/en/docs/concepts/python-reference_catboostregressor
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting#machine-learning-for-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/window-features-and-custom-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/weighted-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/time-series-differentiation
#   [OK] Enlace accesible: [] - https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMRegressor.html#lightgbm.LGBMRegressor.fit
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/preprocessing#skforecast.preprocessing.preprocessing.QuantileBinner
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.KBinsDiscretizer.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/probabilistic-forecasting#intervals-conditioned-on-predicted-values-binned-residuals
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting#direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirect
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirectmultivariate
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/parallelization-skforecast
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/quick-start/forecaster-attributes.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: ['sk-estimator-doc-link', 'fitted'] - https://scikit-learn.org/1.5/modules/generated/sklearn.ensemble.RandomForestRegressor.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirect
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirectmultivariate
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecaster-in-production
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirect
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirectmultivariate
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/quick-start/how-to-install.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://pypi.org/project/skforecast/
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/table-of-contents.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-baseline
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/exogenous-variables
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/window-features-and-custom-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/categorical-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/calendar-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/time-series-differentiation
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/feature-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/metrics
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/hyperparameter-tuning-and-lags-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/feature-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/probabilistic-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/save-load-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecaster-in-production
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/plotting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/datasets
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/migration-guide
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/weighted-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/stacking-ensemble-models-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-xgboost-lightgbm
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/skforecast-in-gpu
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/non-negative-predictions
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/forecasting-time-series-with-missing-values
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/forecasting-with-delayed-historical-data
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/parameters-search-backtesting-vs-one-step-ahead
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/cyclical-features-time-series
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/time-series-aggregation
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/parallelization-skforecast
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/profiling-skforecast
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/table-of-contents
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/migration-guide.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/window-features-and-custom-features
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/input-data.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/probabilistic-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/training-and-prediction-matrices
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py49-modelling-time-series-trend-with-tree-based-models.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/parallelization-skforecast
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirect
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/training-and-prediction-matrices
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://www.statsmodels.org/stable/index.html
#   [OK] Enlace accesible: [] - http://alkaline-ml.com/pmdarima/
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/sarimax
#   [OK] Enlace accesible: [] - https://www.statsmodels.org/stable/generated/statsmodels.tsa.statespace.sarimax.SARIMAX.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py51-arima-sarimax-models-python.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/user_guides/forecasting-sarimax-arima#forecastersarimax
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/exogenous-variables
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting#backtesting-forecasting-models
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/hyperparameter-tuning-and-lags-selection
#   [ERROR] Enlace roto o inaccesible: https://robjhyndman.com/hyndsight/aic/
#   [OK] Enlace accesible: [] - https://sites.warnercnr.colostate.edu/kenburnham/wp-content/uploads/sites/25/2016/08/AIC-Myths-and-Misunderstandings.pdf
#   [OK] Enlace accesible: [] - https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.sarimax.SARIMAXResults.fittedvalues.html#statsmodels.tsa.statespace.sarimax.SARIMAXResults.fittedvalues
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/sarimax
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/forecasting-baseline.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://pandas.pydata.org/docs/reference/offset_frequency.html
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting#recursive-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py44-multi-series-forecasting-skforecast.html
#   [ERROR] Enlace roto o inaccesible: https://www.cienciadedatos.net/documentos/py59-scalable-forecasting-model.html
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py53-global-forecasting-models
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py54-forecasting-with-deep-learning
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/hyperparameter-tuning-and-lags-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/hyperparameter-tuning-and-lags-selection#bayesian-search
#   [OK] Enlace accesible: [] - https://optuna.readthedocs.io/en/stable/reference/generated/optuna.study.Study.html#optuna.study.Study
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/exogenous-variables
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/probabilistic-forecasting#out-sample-residuals-non-conditioned-on-predicted-values
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py49-modelling-time-series-trend-with-tree-based-models.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/feature_selection.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/feature-selection#global-forecasting-models-feature-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/metrics
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/training-and-prediction-matrices
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting#hyperparameter-tuning-and-lags-selection-multi-series
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting#direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py44-multi-series-forecasting-skforecast.html
#   [ERROR] Enlace roto o inaccesible: https://www.cienciadedatos.net/documentos/py59-scalable-forecasting-model.html
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py53-global-forecasting-models
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py54-forecasting-with-deep-learning
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/parallelization-skforecast
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirectmultivariate
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/hyperparameter-tuning-and-lags-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/hyperparameter-tuning-and-lags-selection#bayesian-search
#   [OK] Enlace accesible: [] - https://optuna.readthedocs.io/en/stable/reference/generated/optuna.study.Study.html#optuna.study.Study
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/exogenous-variables
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirectmultivariate
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/weighted-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/training-and-prediction-matrices
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/forecasting-with-deep-learning-rnn-lstm.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py54-forecasting-with-deep-learning.html
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/exogenous-variables.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/categorical-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting#backtesting-with-exogenous-variables
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/window-features-and-custom-features.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rolling.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/preprocessing#skforecast.preprocessing.preprocessing.RollingFeatures
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/categorical-features.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py39-forecasting-time-series-with-skforecast-xgboost-lightgbm-catboost.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html#sklearn.preprocessing.OneHotEncoder
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.compose.ColumnTransformer.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: ['sk-estimator-doc-link', 'fitted'] - https://scikit-learn.org/1.5/modules/generated/sklearn.compose.ColumnTransformer.html
#   [OK] Enlace accesible: ['sk-estimator-doc-link', 'fitted'] - https://scikit-learn.org/1.5/modules/generated/sklearn.preprocessing.OneHotEncoder.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OrdinalEncoder.html
#   [OK] Enlace accesible: [] - https://feature-engine.trainindata.com/en/latest/user_guide/encoding/OrdinalEncoder.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://scikit-learn.org/dev/modules/generated/sklearn.preprocessing.TargetEncoder.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/preprocessing.html#target-encoder
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/calendar-features.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/exogenous-variables
#   [OK] Enlace accesible: [] - https://pandas.pydata.org/docs/user_guide/timeseries.html
#   [OK] Enlace accesible: [] - https://feature-engine.trainindata.com/en/latest/user_guide/datetime/DatetimeFeatures.html#datetime-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/cyclical-features-time-series
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/sklearn-transformers-and-pipeline.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/training-and-prediction-matrices
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.FunctionTransformer.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.FunctionTransformer.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.FunctionTransformer.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/whats_new/v1.2.html#version-1-2-1
#   [OK] Enlace accesible: ['sk-estimator-doc-link'] - https://scikit-learn.org/1.5/modules/generated/sklearn.pipeline.Pipeline.html
#   [OK] Enlace accesible: ['sk-estimator-doc-link'] - https://scikit-learn.org/1.5/modules/generated/sklearn.preprocessing.StandardScaler.html
#   [OK] Enlace accesible: ['sk-estimator-doc-link'] - https://scikit-learn.org/1.5/modules/generated/sklearn.linear_model.Ridge.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting#scikit-learn-transformers-in-multi-series
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting#scikit-learn-transformers-in-multivariate
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/time-series-differentiation.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/preprocessing#skforecast.preprocessing.preprocessing.TimeSeriesDifferentiator
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py49-modelling-time-series-trend-with-tree-based-models.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/preprocessing#skforecast.preprocessing.preprocessing.TimeSeriesDifferentiator
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/feature-selection.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/feature_selection.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFE.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFECV.html#sklearn.feature_selection.RFECV
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SequentialFeatureSelector.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectFromModel.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/metrics.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_absolute_error.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_absolute_percentage_error.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_log_error.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.median_absolute_error.html
#   [OK] Enlace accesible: [] - https://en.wikipedia.org/wiki/Mean_absolute_scaled_error#:~:text=In%20statistics%2C%20the%20mean%20absolute,2005%20by%20statistician%20Rob%20J.
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/backtesting.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py29-forecasting-electricity-power-demand-python.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/parallelization-skforecast
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/probabilistic-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/exogenous-variables
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/training-and-prediction-matrices
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/hyperparameter-tuning-and-lags-selection.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting#which-strategy-should-i-use
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/parallelization-skforecast
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://optuna.readthedocs.io/en/stable/reference/generated/optuna.study.Study.html#optuna.study.Study
#   [OK] Enlace accesible: [] - https://optuna.readthedocs.io/en/stable/reference/generated/optuna.study.create_study.html
#   [OK] Enlace accesible: [] - https://optuna.readthedocs.io/en/stable/reference/generated/optuna.study.Study.html#optuna.study.Study.optimize
#   [OK] Enlace accesible: [] - https://optuna.readthedocs.io/en/stable/reference/generated/optuna.trial.Trial.html#optuna.trial.Trial
#   [OK] Enlace accesible: [] - https://optuna.readthedocs.io/en/stable/reference/generated/optuna.study.Study.html#optuna.study.Study
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/parameters-search-backtesting-vs-one-step-ahead
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/feature-selection.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/feature_selection.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFE.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFECV.html#sklearn.feature_selection.RFECV
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SequentialFeatureSelector.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectFromModel.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/probabilistic-forecasting.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://otexts.com/fpp3/prediction-intervals.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://docs.scipy.org/doc/scipy/reference/stats.html#continuous-distributions
#   [ERROR] Enlace roto o inaccesible: https://robjhyndman.com/hyndsight/narrow-pi/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/preprocessing#skforecast.preprocessing.preprocessing.QuantileBinner
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.KBinsDiscretizer.html
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/issues
#   [OK] Enlace accesible: [] - https://docs.scipy.org/doc/scipy/reference/stats.html#continuous-distributions
#   [OK] Enlace accesible: [] - https://lightgbm.readthedocs.io/en/latest/index.html
#   [OK] Enlace accesible: [] - https://xgboost.readthedocs.io/en/stable/python/index.html
#   [OK] Enlace accesible: [] - https://catboost.ai/en/docs/concepts/python-reference_catboostregressor
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.HistGradientBoostingRegressor.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.QuantileRegressor.html#sklearn.linear_model.QuantileRegressor
#   [OK] Enlace accesible: [] - https://skranger.readthedocs.io/en/stable/index.html
#   [OK] Enlace accesible: [] - https://en.wikipedia.org/wiki/Quantile_regression
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirect
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirectmultivariate
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/explainability.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py57-interpretable-forecasting-models.html
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/issues
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://shap.readthedocs.io/en/latest/index.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/training-and-prediction-matrices
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/partial_dependence.html#partial-dependence-and-individual-conditional-expectation-plots
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/save-load-forecaster.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecaster-in-production
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/window-features-and-custom-features#create-your-custom-window-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/weighted-time-series-forecasting
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/forecaster-in-production.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/save-load-forecaster
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/plotting.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/datasets.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast-datasets
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/training-and-prediction-matrices.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/time-series-differentiation
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/time-series-differentiation
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/time-series-differentiation
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/utils#skforecast.utils.utils.transform_numpy
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/utils#skforecast.utils.utils.transform_series
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/utils#skforecast.utils.utils.transform_dataframe
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting#series-encoding-in-multi-series
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirectmultivariate
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/time-series-differentiation
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/time-series-differentiation
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/utils#skforecast.utils.utils.transform_numpy
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/utils#skforecast.utils.utils.transform_series
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/utils#skforecast.utils.utils.transform_dataframe
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/weighted-time-series-forecasting.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://github.com/microsoft/LightGBM/issues/5553
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/stacking-ensemble-models-forecasting.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.StackingRegressor.html#sklearn.ensemble.StackingRegressor
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py52-stacking-ensemble-models-forecasting.html
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.StackingRegressor.html#sklearn.ensemble.StackingRegressor
#   [OK] Enlace accesible: ['sk-estimator-doc-link'] - https://scikit-learn.org/1.5/modules/generated/sklearn.ensemble.StackingRegressor.html
#   [OK] Enlace accesible: ['sk-estimator-doc-link'] - https://scikit-learn.org/1.5/modules/generated/sklearn.linear_model.Ridge.html
#   [OK] Enlace accesible: ['sk-estimator-doc-link'] - https://scikit-learn.org/1.5/modules/generated/sklearn.linear_model.Ridge.html
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/forecasting-xgboost-lightgbm.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://xgboost.readthedocs.io/en/stable/index.html
#   [OK] Enlace accesible: [] - https://lightgbm.readthedocs.io/en/latest/
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.HistGradientBoostingRegressor.html#sklearn.ensemble.HistGradientBoostingRegressor
#   [OK] Enlace accesible: [] - https://catboost.ai/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/categorical-features#native-implementation-for-categorical-features
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py39-forecasting-time-series-with-skforecast-xgboost-lightgbm-catboost
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py56-forecasting-time-series-with-xgboost.html
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py29-forecasting-electricity-power-demand-python
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py49-modelling-time-series-trend-with-tree-based-models.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/skforecast-in-GPU.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://colab.research.google.com/drive/10PYQFQN9oNkAHh0X7wwyBLQ3JQ_Cm7pP?usp=sharing
#   [OK] Enlace accesible: [] - https://colab.research.google.com/drive/17Csc70AY-GQA-tvZjq9TYCbmnrNOzslh?usp=sharing
#   [OK] Enlace accesible: [] - https://colab.research.google.com/drive/1Z-n0kKEnQvY02e9-HxKbkTdLc10RNd_-?usp=sharing
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/faq/table-of-contents.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/issues
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/non-negative-predictions
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/forecasting-time-series-with-missing-values
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/forecasting-with-delayed-historical-data
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/parameters-search-backtesting-vs-one-step-ahead
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/cyclical-features-time-series
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/time-series-aggregation
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/parallelization-skforecast
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/profiling-skforecast
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/faq/non-negative-predictions.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://florianwilhelm.info/2020/05/honey_i_shrunk_the_target_variable/
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.FunctionTransformer.html
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/faq/forecasting-time-series-with-missing-values.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/weighted-time-series-forecasting
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/faq/forecasting-with-delayed-historical-data.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecaster-in-production
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/faq/parameters-search-backtesting-vs-one-step-ahead.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/faq/cyclical-features-time-series.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/auto_examples/applications/plot_cyclical_feature_engineering.html#sphx-glr-auto-examples-applications-plot-cyclical-feature-engineering-py
#   [OK] Enlace accesible: [] - https://scikit-lego.netlify.app/preprocessing.html#Repeating-Basis-Function-Transformer
#   [OK] Enlace accesible: [] - https://developer.nvidia.com/blog/three-approaches-to-encoding-time-information-as-features-for-ml-models/
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/faq/time-series-aggregation.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/faq/parallelization-skforecast.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/model_selection#skforecast.model_selection._utils.select_n_jobs_backtesting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/utils#skforecast.utils.utils.select_n_jobs_fit_forecaster
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/faq/profiling-skforecast.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
#
# Resumen de enlaces rotos:
# --------------------------------------------------------------------------------
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html: https://robjhyndman.com/hyndsight/aic/
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html: https://www.cienciadedatos.net/documentos/py59-scalable-forecasting-model.html
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting.html: https://www.cienciadedatos.net/documentos/py59-scalable-forecasting-model.html
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/user_guides/probabilistic-forecasting.html: https://robjhyndman.com/hyndsight/narrow-pi/

# %%
# Check all links in general list
# ==============================================================================
broken_links_list = []
for link in links_general:
    broken_links = check_links_ignoring_nav_links(link)
    broken_links_list.extend(broken_links)

print("")
print("")
print(Style.BRIGHT + Fore.RED + "Resumen de enlaces rotos:")
print("-" * 80)
print("\n".join(broken_links_list) + Style.RESET_ALL)
# Out:
# [OK] Página accesible: https://skforecast.org/0.14.0/
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://pypi.org/project/skforecast/
#   [OK] Enlace accesible: [] - https://codecov.io/gh/skforecast/skforecast
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/actions/workflows/unit-tests.yml/badge.svg
#   [OK] Enlace accesible: [] - https://www.repostatus.org/#active
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/graphs/commit-activity
#   [OK] Enlace accesible: [] - https://pepy.tech/project/skforecast
#   [OK] Enlace accesible: [] - https://pepy.tech/project/skforecast
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/blob/master/LICENSE
#   [OK] Enlace accesible: [] - https://zenodo.org/doi/10.5281/zenodo.8382787
#   [OK] Enlace accesible: [] - https://www.paypal.com/donate/?hosted_button_id=D2JZSWRLTZDL6
#   [OK] Enlace accesible: [] - https://www.buymeacoffee.com/skforecast
#   [OK] Enlace accesible: [] - https://www.linkedin.com/company/skforecast/
#   [ERROR] Enlace roto o inaccesible: https://numfocus.org/sponsored-projects/affiliated-projects
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/issues
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/blob/master/CONTRIBUTING.md
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/quick-start/how-to-install
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/table-of-contents
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/examples/examples_english
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/issues
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/examples/examples_english
#   [OK] Enlace accesible: [] - https://docs.pytest.org/en/latest/
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/blob/master/CONTRIBUTING.md
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/authors/authors
#   [ERROR] Enlace roto o inaccesible: https://doi.org/10.1109/SusTech60925.2024.10553570
#   [OK] Enlace accesible: [] - https://doi.org/10.1016/j.jaridenv.2024.105160
#   [ERROR] Enlace roto o inaccesible: https://doi.org/10.1109/AMPS59207.2023.10297192
#   [OK] Enlace accesible: [] - https://doi.org/10.37431/conectividad.v5i2.126
#   [OK] Enlace accesible: [] - https://doi.org/10.19139/soic-2310-5070-1822
#   [OK] Enlace accesible: [] - https://doi.org/10.3390/en16031495
#   [OK] Enlace accesible: [] - https://doi.org/10.3390/en16186726
#   [OK] Enlace accesible: [] - https://doi.org/10.3390/en16186731
#   [OK] Enlace accesible: [] - https://doi.org/10.1007/978-3-031-22200-9_32
#   [OK] Enlace accesible: [] - https://www.buymeacoffee.com/skforecast
#   [OK] Enlace accesible: [] - https://www.paypal.com/donate/?hosted_button_id=D2JZSWRLTZDL6
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/blob/master/LICENSE
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/examples/examples_english.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py27-time-series-forecasting-python-scikitlearn.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py51-arima-sarimax-models-python.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py39-forecasting-time-series-with-skforecast-xgboost-lightgbm-catboost.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py56-forecasting-time-series-with-xgboost.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py58-forecasting-time-series-with-lightgbm.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py44-multi-series-forecasting-skforecast.html
#   [ERROR] Enlace roto o inaccesible: https://www.cienciadedatos.net/documentos/py59-scalable-forecasting-model.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py53-global-forecasting-models.html
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py54-forecasting-with-deep-learning
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py42-probabilistic-forecasting.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py49-modelling-time-series-trend-with-tree-based-models.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py46-forecasting-time-series-missing-values.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py57-interpretable-forecasting-models.html
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py52-stacking-ensemble-models-forecasting.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py29-forecasting-electricity-power-demand-python.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py37-forecasting-web-traffic-machine-learning.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py48-intermittent-demand-forecasting.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py45-weighted-time-series-forecasting.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py41-forecasting-cryptocurrency-bitcoin-machine-learning-python.html
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/examples/examples_spanish.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py27-forecasting-series-temporales-python-scikitlearn.html
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py51-modelos-arima-sarimax-python.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py39-forecasting-series-temporales-con-skforecast-xgboost-lightgbm-catboost.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py56-forecasting-series-temporales-con-xgboost.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py58-forecasting-series-temporales-con-lightgbm.html
#   [OK] Enlace accesible: [] - https://youtu.be/MlktVhReO0E
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py44-multi-series-forecasting-skforecast-español.html
#   [ERROR] Enlace roto o inaccesible: https://www.cienciadedatos.net/documentos/py59-modelos-forecasting-escalable.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py53-modelos-forecasting-globales.html
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py54-forecasting-con-deep-learning
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py42-forecasting-probabilistico.html
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py49-modelar-tendencia-en-series-temporales-modelos-de-arboles.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py46-forecasting-series-temporales-incompletas.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py57-modelos-forecasting-interpretables.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py29-forecasting-demanda-energia-electrica-python.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py37-forecasting-visitas-web-machine-learning.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py48-forecasting-demanda-intermitente.html
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py45-weighted-time-series-forecasting-es
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py41-forecasting-criptomoneda-bitcoin-machine-learning-python.html
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/api/ForecasterRecursive.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['autorefs', 'autorefs-internal'] - https://skforecast.org/0.14.0/api/preprocessing#skforecast.preprocessing.preprocessing.TimeSeriesDifferentiator
#   [OK] Enlace accesible: [] - https://otexts.com/fpp3/prediction-intervals.html#prediction-intervals-from-bootstrapped-residuals
#   [OK] Enlace accesible: [] - https://otexts.com/fpp2/prediction-intervals.html
#   [OK] Enlace accesible: [] - https://otexts.com/fpp2/prediction-intervals.html
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/api/ForecasterDirect.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['autorefs', 'autorefs-internal'] - https://skforecast.org/0.14.0/api/preprocessing#skforecast.preprocessing.preprocessing.TimeSeriesDifferentiator
#   [OK] Enlace accesible: [] - https://otexts.com/fpp3/prediction-intervals.html#prediction-intervals-from-bootstrapped-residuals
#   [OK] Enlace accesible: [] - https://otexts.com/fpp2/prediction-intervals.html
#   [OK] Enlace accesible: [] - https://otexts.com/fpp2/prediction-intervals.html
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/api/ForecasterRecursiveMultiSeries.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['autorefs', 'autorefs-internal'] - https://skforecast.org/0.14.0/api/preprocessing#skforecast.preprocessing.preprocessing.TimeSeriesDifferentiator
#   [OK] Enlace accesible: [] - https://otexts.com/fpp3/prediction-intervals.html#prediction-intervals-from-bootstrapped-residuals
#   [OK] Enlace accesible: [] - https://otexts.com/fpp2/prediction-intervals.html
#   [OK] Enlace accesible: [] - https://otexts.com/fpp2/prediction-intervals.html
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/api/ForecasterDirectMultiVariate.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['autorefs', 'autorefs-internal'] - https://skforecast.org/0.14.0/api/preprocessing#skforecast.preprocessing.preprocessing.TimeSeriesDifferentiator
#   [OK] Enlace accesible: [] - https://otexts.com/fpp3/prediction-intervals.html#prediction-intervals-from-bootstrapped-residuals
#   [OK] Enlace accesible: [] - https://otexts.com/fpp2/prediction-intervals.html
#   [OK] Enlace accesible: [] - https://otexts.com/fpp2/prediction-intervals.html
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/api/ForecasterRnn.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/api/Sarimax.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://www.statsmodels.org/stable/generated/statsmodels.tsa.statespace.sarimax.SARIMAX.html
#   [OK] Enlace accesible: [] - https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.sarimax.SARIMAXResults.html
#   [OK] Enlace accesible: [] - https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.mlemodel.MLEResults.append.html#statsmodels.tsa.statespace.mlemodel.MLEResults.append
#   [OK] Enlace accesible: [] - https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.mlemodel.MLEResults.apply.html#statsmodels.tsa.statespace.mlemodel.MLEResults.apply
#   [OK] Enlace accesible: [] - https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.mlemodel.MLEResults.extend.html#statsmodels.tsa.statespace.mlemodel.MLEResults.extend
#   [OK] Enlace accesible: [] - https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.sarimax.SARIMAXResults.info_criteria.html
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/api/ForecasterSarimax.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['autorefs', 'autorefs-internal'] - https://skforecast.org/0.14.0/api/sarimax#skforecast.sarimax._sarimax.Sarimax
#   [OK] Enlace accesible: ['autorefs', 'autorefs-internal'] - https://skforecast.org/0.14.0/api/sarimax#skforecast.sarimax._sarimax.Sarimax
#   [OK] Enlace accesible: [] - https://www.statsmodels.org/dev/generated/statsmodels.tsa.arima.model.ARIMAResults.append.html
#   [OK] Enlace accesible: [] - https://www.statsmodels.org/dev/generated/statsmodels.tsa.arima.model.ARIMAResults.append.html
#   [OK] Enlace accesible: [] - https://www.statsmodels.org/dev/generated/statsmodels.tsa.arima.model.ARIMAResults.append.html
#   [OK] Enlace accesible: [] - https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.sarimax.SARIMAXResults.info_criteria.html
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/api/ForecasterEquivalentDate.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://pandas.pydata.org/docs/reference/offset_frequency.html
#   [OK] Enlace accesible: [] - https://pandas.pydata.org/docs/reference/offset_frequency.html
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/api/model_selection.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/api/feature_selection.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/api/preprocessing.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/api/metrics.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/api/plot.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/api/utils.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/api/datasets.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/api/exceptions.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/releases/releases.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/migration-guide
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/preprocessing#skforecast.preprocessing.preprocessing.RollingFeatures
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/window-features-and-custom-features
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._split.TimeSeriesFold
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._split.OneStepAheadFold
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/hyperparameter-tuning-and-lags-selection#one-step-ahead-validation
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._split.OneStepAheadFold
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/exogenous-variables#handling-missing-exogenous-data-in-initial-training-periods
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/migration-guide
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecasterautoregcustom
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/forecastersarimax
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/sarimax
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/preprocessing#skforecast.preprocessing.preprocessing.RollingFeatures
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._split.OneStepAheadFold
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://github.com/imMoya
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/pull/811
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/forecasterrnn#skforecast.deep_learning.utils.create_and_compile_model
#   [OK] Enlace accesible: [] - https://github.com/pablorodriper
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/pull/824
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecasterautoregcustom
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._search.bayesian_search_forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._search.bayesian_search_forecaster_multiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/forecastersarimax
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/sarimax
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._split.TimeSeriesFold
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._split.OneStepAheadFold
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/feature_selection
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/feature_selection#skforecast.feature_selection.feature_selection.select_features
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/feature_selection#skforecast.feature_selection.feature_selection.select_features_multiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/feature_selection#skforecast.feature_selection.feature_selection.select_features
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/feature_selection#skforecast.feature_selection.feature_selection.select_features_multiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecastermultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecastermultiseriescustom
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/user_guides/independent-multi-time-series-forecasting#forecasting-unknown-series
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecastermultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecastermultiseriescustom
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/user_guides/independent-multi-time-series-forecasting#series-encoding-in-multi-series
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/metrics
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/metrics#skforecast.metrics.metrics.mean_absolute_scaled_error
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/metrics#skforecast.metrics.metrics.root_mean_squared_scaled_error
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/user_guides/metrics
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/model_selection_multiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/user_guides/backtesting#backtesting-with-skip-folds
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecastermultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecastermultiseriescustom
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/forecasterrnn
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/forecasterrnn
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/plot#skforecast.plot.plot.plot_prediction_intervals
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/plot
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/metrics
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/model_selection_multiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/plot#skforecast.plot.plot.plot_prediction_intervals
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/plot
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecastermultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecastermultiseriescustom
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecastermultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecastermultiseriescustom
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._search.grid_search_forecaster_multiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._search.random_search_forecaster_multiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._search.bayesian_search_forecaster_multiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/preprocessing#skforecast.preprocessing.DateTimeFeatureTransformer
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/preprocessing#skforecast.preprocessing.create_datetime_features
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/preprocessing
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/quick-start/how-to-install
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecasterautoreg
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecastermultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecastermultiseriescustom
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/metrics
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/exceptions
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._validation.backtesting_sarimax
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection._validation.backtesting_forecaster_multiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecastermultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/api/forecastermultiseriescustom
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/user_guides/feature-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/model_selection#skforecast.model_selection.model_selection.select_features
#   [ERROR] Enlace roto o inaccesible: https://skforecast.org/latest/api/model_selection_multiseries#skforecast.model_selection_multiseries.model_selection_multiseries.select_features_multiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/api/forecasterrnn
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/user_guides/probabilistic-forecasting#intervals-conditioned-on-predicted-values-binned-residuals
#   [ERROR] Enlace roto o inaccesible: https://skforecast.org/latest/api/forecasterautoreg
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/user_guides/independent-multi-time-series-forecasting#hyperparameter-tuning-and-lags-selection-multi-series
#   [ERROR] Enlace roto o inaccesible: https://skforecast.org/latest/faq/time-series-differentiation
#   [ERROR] Enlace roto o inaccesible: https://skforecast.org/latest/api/forecastermultiseries
#   [ERROR] Enlace roto o inaccesible: https://skforecast.org/latest/api/forecastermultiseriescustom
#   [ERROR] Enlace roto o inaccesible: https://skforecast.org/latest/api/forecastermultivariate
#   [OK] Enlace accesible: [] - https://github.com/Metaming
#   [OK] Enlace accesible: [] - http://alkaline-ml.com/pmdarima/modules/generated/pmdarima.arima.ARIMA.html#pmdarima.arima.ARIMA
#   [OK] Enlace accesible: [] - https://github.com/Pablo-Davila
#   [OK] Enlace accesible: [] - https://github.com/Bennett561
#   [OK] Enlace accesible: [] - https://github.com/tkaraouzene
#   [OK] Enlace accesible: [] - https://github.com/Pablo-Davila
#   [OK] Enlace accesible: [] - https://skforecast.org
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast#introduction
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast#introduction
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
# [OK] Página accesible: https://skforecast.org/0.14.0/authors/authors.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/blob/master/CONTRIBUTING.md
#   [ERROR] Enlace roto o inaccesible: mailto:j.amatrodrigo@gmail.com
#   [ERROR] Enlace roto o inaccesible: mailto:javier.escobar.ortiz@gmail.com
#   [OK] Enlace accesible: [] - https://github.com/fernando-carazo
#   [OK] Enlace accesible: [] - https://github.com/josh-wong
#   [OK] Enlace accesible: [] - https://github.com/edgBR
#   [OK] Enlace accesible: [] - https://github.com/syndct
#   [OK] Enlace accesible: [] - https://github.com/KishManani
#   [OK] Enlace accesible: [] - https://github.com/Sergio-Quijano-Stratesys
#   [OK] Enlace accesible: [] - https://github.com/schoulten
#   [OK] Enlace accesible: [] - https://github.com/tyg3rr
#   [OK] Enlace accesible: [] - https://github.com/IvanLiuTW
#   [OK] Enlace accesible: [] - https://github.com/imMoya
#   [OK] Enlace accesible: [] - https://github.com/pablorodriper
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
#
# Resumen de enlaces rotos:
# --------------------------------------------------------------------------------
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/: https://numfocus.org/sponsored-projects/affiliated-projects
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/: https://doi.org/10.1109/SusTech60925.2024.10553570
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/: https://doi.org/10.1109/AMPS59207.2023.10297192
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/examples/examples_english.html: https://www.cienciadedatos.net/documentos/py59-scalable-forecasting-model.html
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/examples/examples_spanish.html: https://www.cienciadedatos.net/documentos/py59-modelos-forecasting-escalable.html
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/releases/releases.html: https://skforecast.org/latest/api/model_selection_multiseries#skforecast.model_selection_multiseries.model_selection_multiseries.select_features_multiseries
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/releases/releases.html: https://skforecast.org/latest/api/forecasterautoreg
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/releases/releases.html: https://skforecast.org/latest/faq/time-series-differentiation
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/releases/releases.html: https://skforecast.org/latest/api/forecastermultiseries
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/releases/releases.html: https://skforecast.org/latest/api/forecastermultiseriescustom
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/releases/releases.html: https://skforecast.org/latest/api/forecastermultivariate
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/authors/authors.html: mailto:j.amatrodrigo@gmail.com
# [ERROR] Enlace roto o inaccesible en https://skforecast.org/0.14.0/authors/authors.html: mailto:javier.escobar.ortiz@gmail.com
