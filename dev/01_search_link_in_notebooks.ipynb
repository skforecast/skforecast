# %% [markdown]
# # Search links in docs
#
# pip install nbformat

# %%
import os
import nbformat

def search_text_in_files(directory, search_text_base):
    notebooks_with_text = []
    markdown_files_with_text = []

    # Recorre todos los archivos de la carpeta
    for root, dirs, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            if file.endswith(".ipynb"):
                with open(file_path, 'r', encoding='utf-8') as f:
                    nb = nbformat.read(f, as_version=4)
                    
                    # Recorre todas las celdas del notebook
                    for cell in nb.cells:
                        if cell.cell_type == 'markdown':
                            if search_text_base in cell.source:
                                notebooks_with_text.append(file_path)
                                break
            elif file.endswith(".md"):
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                    if search_text_base in content:
                        markdown_files_with_text.append(file_path)

    return notebooks_with_text, markdown_files_with_text

# Especifica la carpeta que contiene los notebooks y el texto a buscar
directory_path = '../docs/'
search_texts = [
    "https://skforecast.org/latest/introduction-forecasting/forecaster-parameters",
    "https://skforecast.org/latest/introduction-forecasting/forecaster-attributes",
    "https://skforecast.org/latest/user_guides/quick-start-skforecast",
    "https://skforecast.org/latest/user_guides/input-data",
    "https://skforecast.org/0.",
    "https://skforecast.org/0.12.1/user_guides/plot-forecaster-residuals",
    "https://skforecast.org/latest/user_guides/plot-forecaster-residuals"
]
search_texts = [
    "https://skforecast.org",
    "https://skforecast.org/latest/user_guides/user_guides",
    "../user_guides/user_guides",
    "https://skforecast.org/latest/faq/faq",
    "../faq/faq",
    "joaquin"
]

for search_text_base in search_texts:

    print(search_text_base)
    print("=" * len(search_text_base))

    # Llama a la función y obtén los notebooks que contienen el texto buscado
    notebooks, markdown_files = search_text_in_files(directory_path, search_text_base)

    # Imprime la lista de notebooks que contienen el texto
    if notebooks:
        print("The following notebooks contain the specified text:")
        for notebook in notebooks:
            print(notebook)
    else:
        print("No notebooks contain the specified text.")

    if markdown_files:
        print("\nThe following markdown files contain the specified text:")
        for markdown_file in markdown_files:
            print(markdown_file)
    else:
        print("No markdown files contain the specified text.")

    print("=" * len(search_text_base))
    print("\n")
# Out:
# https://skforecast.org
# ======================
# The following notebooks contain the specified text:
# ../docs/user_guides\forecasting-sarimax-arima.ipynb
# ../docs/user_guides\probabilistic-forecasting.ipynb
# ../docs/user_guides\weighted-time-series-forecasting.ipynb
#
# The following markdown files contain the specified text:
# ../docs/README.md
# ../docs/releases\releases.md
# ======================
#
#
# https://skforecast.org/latest/user_guides/user_guides
# =====================================================
# c:\Users\jaesc2\Miniconda3\envs\skforecast_py11\Lib\site-packages\nbformat\__init__.py:93: MissingIDFieldWarning: Code cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# No notebooks contain the specified text.
# No markdown files contain the specified text.
# =====================================================
#
#
# ../user_guides/user_guides
# ==========================
# No notebooks contain the specified text.
# No markdown files contain the specified text.
# ==========================
#
#
# https://skforecast.org/latest/faq/faq
# =====================================
# No notebooks contain the specified text.
# No markdown files contain the specified text.
# =====================================
#
#
# ../faq/faq
# ==========
# No notebooks contain the specified text.
# No markdown files contain the specified text.
# ==========
#
#
# joaquin
# =======
# No notebooks contain the specified text.
#
# The following markdown files contain the specified text:
# ../docs/README.md
# ../docs/releases\releases.md
# =======

# %% [markdown]
# # Test links docs

# %%
base_url = "https://skforecast.org/0.14.0/"

# Lista de rutas extraídas del archivo mkdocs.yml
paths_general = [
    "",

    "examples/examples_english.md",
    "examples/examples_spanish.md",

    "api/ForecasterRecursive.md",
    "api/ForecasterDirect.md",
    "api/ForecasterRecursiveMultiSeries.md",
    "api/ForecasterDirectMultiVariate.md",
    "api/ForecasterRnn.md",
    "api/Sarimax.md",
    "api/ForecasterSarimax.md",
    "api/ForecasterEquivalentDate.md",
    "api/model_selection.md",
    "api/feature_selection.md",
    "api/preprocessing.md",
    "api/metrics.md",
    "api/plot.md",
    "api/utils.md",
    "api/datasets.md",
    "api/exceptions.md",

    "releases/releases.md",

    "authors/authors.md"
]

paths_user_guides = [
    "introduction-forecasting/introduction-forecasting.md",

    "user_guides/migration-guide.ipynb",
    
    "quick-start/quick-start-skforecast.ipynb",
    "quick-start/forecaster-parameters.md",
    "quick-start/forecaster-attributes.ipynb",
    "quick-start/how-to-install.md",
    
    "user_guides/table-of-contents.md",
    "user_guides/migration-guide.html",
    "user_guides/input-data.ipynb",
    "user_guides/autoregresive-forecaster.ipynb",
    "user_guides/direct-multi-step-forecasting.ipynb",
    "user_guides/forecasting-sarimax-arima.ipynb",
    "user_guides/forecasting-baseline.ipynb",
    "user_guides/independent-multi-time-series-forecasting.ipynb",
    "user_guides/multi-series-with-different-length-and-different_exog.ipynb",
    "user_guides/dependent-multi-series-multivariate-forecasting.ipynb",
    "user_guides/forecasting-with-deep-learning-rnn-lstm.ipynb",
    "user_guides/exogenous-variables.ipynb",
    "user_guides/window-features-and-custom-features.ipynb",
    "user_guides/categorical-features.ipynb",
    "user_guides/calendar-features.ipynb",
    "user_guides/sklearn-transformers-and-pipeline.ipynb",
    "user_guides/time-series-differentiation.ipynb",
    "user_guides/feature-selection.ipynb",
    "user_guides/metrics.ipynb",
    "user_guides/backtesting.ipynb",
    "user_guides/hyperparameter-tuning-and-lags-selection.ipynb",
    "user_guides/feature-selection.ipynb",
    "user_guides/probabilistic-forecasting.ipynb",
    "user_guides/explainability.ipynb",
    "user_guides/save-load-forecaster.ipynb",
    "user_guides/forecaster-in-production.ipynb",
    "user_guides/plotting.ipynb",
    "user_guides/datasets.ipynb",
    "user_guides/training-and-prediction-matrices.ipynb",
    "user_guides/weighted-time-series-forecasting.ipynb",
    "user_guides/stacking-ensemble-models-forecasting.ipynb",
    "user_guides/forecasting-xgboost-lightgbm.ipynb",
    "user_guides/skforecast-in-GPU.ipynb",

    "faq/table-of-contents.md",
    "faq/non-negative-predictions.ipynb",
    "faq/forecasting-time-series-with-missing-values.ipynb",
    "faq/forecasting-with-delayed-historical-data.ipynb",
    "faq/parameters-search-backtesting-vs-one-step-ahead.ipynb",
    "faq/cyclical-features-time-series.ipynb",
    "faq/time-series-aggregation.ipynb",
    "faq/parallelization-skforecast.ipynb",
    "faq/profiling-skforecast.ipynb",
]


# Función para cambiar la extensión a .html
def change_extension_to_html(path):
    if path.endswith(".md") or path.endswith(".ipynb"):
        return path.rsplit(".", 1)[0] + ".html"
    return path


# Generar enlaces completos con extensión .html
links_general = [
    base_url + change_extension_to_html(path) for path in paths_general
]
links_user_guides = [
    base_url + change_extension_to_html(path) for path in paths_user_guides
]

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from colorama import Fore, Style, init

# Inicializar colorama
init(autoreset=True)

def check_links_ignoring_nav_links(url):
    try:
        # Realizar la solicitud a la página
        response = requests.get(url)
        response.raise_for_status()  # Verificar si la solicitud fue exitosa
        print(f"[OK] Página accesible: {url}")
    except requests.exceptions.RequestException as e:
        print(f"{Fore.RED}{Style.BRIGHT}[ERROR] No se pudo acceder a {url}: {e}")
        return

    # Parsear el contenido HTML
    soup = BeautifulSoup(response.content, "html.parser")

    # Encontrar todos los enlaces en la página
    links = soup.find_all("a", href=True)

    # Filtrar los enlaces que no tengan alguna de las siguientes clases
    classes_no_to_visit = [
        'md-header__button', 'md-logo', "md-nav__link", "md-tabs__link",
        'md-source', 'md-social__link', 'autorefs-external'
    ]

    # Recorrer todos los enlaces filtrados
    for link in links:
        class_link = link.get("class", [])

        # Ignorar los enlaces que tengan alguna de las clases en "classes_no_to_visit"
        if any(class_no_to_visit in class_link for class_no_to_visit in classes_no_to_visit):
            continue

        # Convertir enlaces relativos en absolutos
        href = link['href']
        if href[0] == "#":
            continue

        full_url = urljoin(url, href)

        try:
            link_response = requests.get(full_url)
            link_response.raise_for_status()  # Verificar si el enlace es accesible
            print(f"  [OK] Enlace accesible: {class_link} - {full_url}")
        except requests.exceptions.RequestException:
            print(f"{Fore.RED}{Style.BRIGHT}  [ERROR] Enlace roto o inaccesible: {class_link} - {full_url}")

    print("")

# Ejemplo de uso
url_to_check = "https://skforecast.org/0.14.0/user_guides/table-of-contents.html"
check_links_ignoring_nav_links(url_to_check)
# Out:
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/table-of-contents.html
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-baseline
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/exogenous-variables
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/window-features-and-custom-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/categorical-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/calendar-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/time-series-differentiation
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/feature-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/metrics
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/hyperparameter-tuning-and-lags-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/feature-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/probabilistic-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/save-load-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecaster-in-production
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/plotting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/datasets
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/migration-guide
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/weighted-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/stacking-ensemble-models-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-xgboost-lightgbm
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/skforecast-in-gpu
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/non-negative-predictions
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/forecasting-time-series-with-missing-values
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/forecasting-with-delayed-historical-data
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/parameters-search-backtesting-vs-one-step-ahead
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/cyclical-features-time-series
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/time-series-aggregation
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/parallelization-skforecast
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/profiling-skforecast
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/table-of-contents
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/

# %%
for link in links_user_guides:
    check_links_ignoring_nav_links(link)
# Out:
# [OK] Página accesible: https://skforecast.org/0.14.0/
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/#about-the-project
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: [] - https://pypi.org/project/skforecast/
#   [OK] Enlace accesible: [] - https://codecov.io/gh/skforecast/skforecast
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/actions/workflows/unit-tests.yml/badge.svg
#   [OK] Enlace accesible: [] - https://www.repostatus.org/#active
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/graphs/commit-activity
#   [OK] Enlace accesible: [] - https://pepy.tech/project/skforecast
#   [OK] Enlace accesible: [] - https://pepy.tech/project/skforecast
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/blob/master/LICENSE
#   [OK] Enlace accesible: [] - https://zenodo.org/doi/10.5281/zenodo.8382787
#   [OK] Enlace accesible: [] - https://www.paypal.com/donate/?hosted_button_id=D2JZSWRLTZDL6
#   [OK] Enlace accesible: [] - https://www.buymeacoffee.com/skforecast
#   [OK] Enlace accesible: [] - https://www.linkedin.com/company/skforecast/
#   [ERROR] Enlace roto o inaccesible: https://numfocus.org/sponsored-projects/affiliated-projects
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/#about-the-project
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/#why-use-skforecast
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/#get-involved
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/issues
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/blob/master/CONTRIBUTING.md
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/#installation-dependencies
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/quick-start/how-to-install
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/#forecasters
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/#features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/table-of-contents
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/#examples-and-tutorials
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/examples/examples_english
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/#how-to-contribute
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/issues
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/examples/examples_english
#   [OK] Enlace accesible: [] - https://docs.pytest.org/en/latest/
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/blob/master/CONTRIBUTING.md
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/authors/authors
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/#citation
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/#publications-citing-skforecast
#   [ERROR] Enlace roto o inaccesible: https://doi.org/10.1109/SusTech60925.2024.10553570
#   [OK] Enlace accesible: [] - https://doi.org/10.1016/j.jaridenv.2024.105160
#   [ERROR] Enlace roto o inaccesible: https://doi.org/10.1109/AMPS59207.2023.10297192
#   [OK] Enlace accesible: [] - https://doi.org/10.37431/conectividad.v5i2.126
#   [OK] Enlace accesible: [] - https://doi.org/10.19139/soic-2310-5070-1822
#   [OK] Enlace accesible: [] - https://doi.org/10.3390/en16031495
#   [OK] Enlace accesible: [] - https://doi.org/10.3390/en16186726
#   [OK] Enlace accesible: [] - https://doi.org/10.3390/en16186731
#   [OK] Enlace accesible: [] - https://doi.org/10.1007/978-3-031-22200-9_32
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/#donating
#   [OK] Enlace accesible: [] - https://www.buymeacoffee.com/skforecast
#   [OK] Enlace accesible: [] - https://www.paypal.com/donate/?hosted_button_id=D2JZSWRLTZDL6
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/#license
#   [OK] Enlace accesible: [] - https://github.com/skforecast/skforecast/blob/master/LICENSE
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#introduction-to-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#introduction-to-forecasting
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#time-series-and-forecasting
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#machine-learning-for-forecasting
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#single-step-forecasting
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#multi-step-forecasting
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#recursive-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#multiple-output-forecasting
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#global-forecasting-models
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#independent-multi-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting#recursive-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#dependent-multi-series-forecasting-multivariate-time-series
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#forecasters
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/quick-start/forecaster-attributes
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#exogenous-variables-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/exogenous-variables
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#backtesting-forecasting-models
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#backtesting-without-refit
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#backtesting-with-refit-and-increasing-training-size-fixed-origin
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#backtesting-with-refit-and-fixed-training-size-rolling-origin
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#backtesting-with-intermittent-refit
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#backtesting-including-gap
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting.html#which-strategy-should-i-use
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py29-forecasting-electricity-power-demand-python.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/migration-guide.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/user_guides/migration-guide.html#skforecast-014-migration-guide
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/migration-guide.html#skforecast-014-migration-guide
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/migration-guide.html#changes-in-the-import-of-the-library
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/migration-guide.html#custom-features-window-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/window-features-and-custom-features
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/migration-guide.html#changes-in-the-backtesting
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/migration-guide.html#changes-in-hyperparameters-search
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/migration-guide.html#overall-structure-of-the-repository
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/quick-start/quick-start-skforecast.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/quick-start/quick-start-skforecast.html#quick-start-skforecast
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/quick-start/quick-start-skforecast.html#quick-start-skforecast
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/table-of-contents
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/quick-start/quick-start-skforecast.html#libraries-and-data
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/quick-start/quick-start-skforecast.html#train-a-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/quick-start/forecaster-attributes
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/quick-start/quick-start-skforecast.html#prediction
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/quick-start/quick-start-skforecast.html#backtesting-forecaster-validation
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/quick-start/quick-start-skforecast.html#hyperparameter-tuning-and-lags-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/hyperparameter-tuning-and-lags-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html#understanding-the-forecaster-parameters
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html#understanding-the-forecaster-parameters
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html#general-parameters
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html#regressor
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.HistGradientBoostingRegressor.html
#   [OK] Enlace accesible: [] - https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMRegressor.html
#   [OK] Enlace accesible: [] - https://xgboost.readthedocs.io/en/stable/python/python_api.html#module-xgboost.sklearn
#   [OK] Enlace accesible: [] - https://catboost.ai/en/docs/concepts/python-reference_catboostregressor
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html#lags
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting#machine-learning-for-forecasting
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html#window-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/window-features-and-custom-features
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html#transformers
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html#custom-weights
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/weighted-time-series-forecasting
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html#differentiation
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/time-series-differentiation
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html#inclusion-of-kwargs-in-the-regressor-fit-method
#   [OK] Enlace accesible: [] - https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMRegressor.html#lightgbm.LGBMRegressor.fit
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html#intervals-conditioned-on-predicted-values-binned-residuals
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/preprocessing#skforecast.preprocessing.preprocessing.QuantileBinner
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.KBinsDiscretizer.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/probabilistic-forecasting#intervals-conditioned-on-predicted-values-binned-residuals
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html#forecaster-id
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html#direct-multi-step-parameters
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting#direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirect
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirectmultivariate
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html#steps
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/forecaster-parameters.html#number-of-jobs
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/parallelization-skforecast
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/quick-start/forecaster-attributes.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/quick-start/forecaster-attributes.html#understanding-the-forecaster-attributes
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/quick-start/forecaster-attributes.html#understanding-the-forecaster-attributes
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/quick-start/forecaster-attributes.html#create-and-train-a-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/quick-start/forecaster-attributes.html#regressor
#   [OK] Enlace accesible: ['sk-estimator-doc-link', 'fitted'] - https://scikit-learn.org/1.5/modules/generated/sklearn.ensemble.RandomForestRegressor.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirect
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirectmultivariate
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/quick-start/forecaster-attributes.html#lags
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/quick-start/forecaster-attributes.html#window-features
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/quick-start/forecaster-attributes.html#window-size
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/quick-start/forecaster-attributes.html#last-window
#   [ERROR] Enlace roto o inaccesible: https://skforecast.org/0.14.0/quick-start/..user_guides/forecaster-in-production.html
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/quick-start/forecaster-attributes.html#in-sample-residuals
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirect
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirectmultivariate
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/quick-start/forecaster-attributes.html#out-of-sample-residuals
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/quick-start/how-to-install.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/quick-start/how-to-install.html#installation-guide
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/how-to-install.html#installation-guide
#   [OK] Enlace accesible: [] - https://pypi.org/project/skforecast/
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/how-to-install.html#basic-installation
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/how-to-install.html#optional-dependencies
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/how-to-install.html#sarimax
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/how-to-install.html#plotting
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/quick-start/how-to-install.html#deeplearning
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/table-of-contents.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/user_guides/table-of-contents.html#table-of-contents
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/user_guides/table-of-contents.html#table-of-contents
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-baseline
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/exogenous-variables
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/window-features-and-custom-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/categorical-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/calendar-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/sklearn-transformers-and-pipeline
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/time-series-differentiation
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/feature-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/metrics
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/hyperparameter-tuning-and-lags-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/feature-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/probabilistic-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/save-load-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecaster-in-production
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/plotting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/datasets
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/migration-guide
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/weighted-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/stacking-ensemble-models-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-xgboost-lightgbm
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/skforecast-in-gpu
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/non-negative-predictions
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/forecasting-time-series-with-missing-values
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/forecasting-with-delayed-historical-data
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/parameters-search-backtesting-vs-one-step-ahead
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/cyclical-features-time-series
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/time-series-aggregation
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/parallelization-skforecast
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/profiling-skforecast
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/table-of-contents
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/migration-guide.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/user_guides/migration-guide.html#skforecast-014-migration-guide
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/migration-guide.html#skforecast-014-migration-guide
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/migration-guide.html#changes-in-the-import-of-the-library
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/migration-guide.html#custom-features-window-features
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/window-features-and-custom-features
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/migration-guide.html#changes-in-the-backtesting
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/migration-guide.html#changes-in-hyperparameters-search
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/migration-guide.html#overall-structure-of-the-repository
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/input-data.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/user_guides/input-data.html#input-data
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/input-data.html#input-data
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/input-data.html#libraries-and-data
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/input-data.html#train-and-predict-using-input-with-datetime-and-frequency-index
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/input-data.html#train-and-predict-using-input-without-datetime-index
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster.html#recursive-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster.html#recursive-multi-step-forecasting
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster.html#libraries-and-data
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster.html#create-and-train-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster.html#prediction
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster.html#prediction-intervals
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/probabilistic-forecasting
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster.html#feature-importances
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster.html#training-and-prediction-matrices
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/training-and-prediction-matrices
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster.html#differentiation
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py49-modelling-time-series-trend-with-tree-based-models.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursive
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/autoregresive-forecaster
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting.html#direct-multi-step-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting.html#direct-multi-step-forecaster
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting.html#libraries-and-data
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting.html#create-and-train-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/faq/parallelization-skforecast
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterdirect
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting.html#prediction
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting.html#feature-importances
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/direct-multi-step-forecasting.html#training-and-prediction-matrices
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/training-and-prediction-matrices
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html#arima-and-sarimax
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html#arima-and-sarimax
#   [OK] Enlace accesible: [] - https://www.statsmodels.org/stable/index.html
#   [OK] Enlace accesible: [] - http://alkaline-ml.com/pmdarima/
#   [OK] Enlace accesible: [] - https://skforecast.org/latest/
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/sarimax
#   [OK] Enlace accesible: [] - https://www.statsmodels.org/stable/generated/statsmodels.tsa.statespace.sarimax.SARIMAX.html
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py51-arima-sarimax-models-python.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.13.0/user_guides/forecasting-sarimax-arima#forecastersarimax
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html#libraries-and-data
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html#statsmodels-pmdarima-and-skforecast
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html#forecastersarimax
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html#training
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html#prediction
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html#interval-prediction
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html#exogenous-variables
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/exogenous-variables
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html#using-an-already-trained-arima
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html#feature-importances
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html#backtesting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting#backtesting-forecasting-models
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html#model-tunning
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/hyperparameter-tuning-and-lags-selection
#   [ERROR] Enlace roto o inaccesible: https://robjhyndman.com/hyndsight/aic/
#   [ERROR] Enlace roto o inaccesible: https://sites.warnercnr.colostate.edu/anderson/wp-content/uploads/sites/26/2016/11/AIC-Myths-and-Misunderstandings.pdf
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html#grid-search-with-backtesting
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html#auto-arima
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-sarimax-arima.html#prediction-on-training-data-in-sample-predictions
#   [OK] Enlace accesible: [] - https://www.statsmodels.org/dev/generated/statsmodels.tsa.statespace.sarimax.SARIMAXResults.fittedvalues.html#statsmodels.tsa.statespace.sarimax.SARIMAXResults.fittedvalues
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/sarimax
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/forecasting-baseline.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/user_guides/forecasting-baseline.html#baseline-forecaster
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-baseline.html#baseline-forecaster
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-baseline.html#forecasterequivalentdate
#   [OK] Enlace accesible: [] - https://pandas.pydata.org/docs/reference/offset_frequency.html
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-baseline.html#libraries-and-data
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-baseline.html#create-and-train-forecaster
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-baseline.html#prediction
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/forecasting-baseline.html#backtesting
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html#global-forecasting-models-independent-multi-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html#global-forecasting-models-independent-multi-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting#recursive-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py44-multi-series-forecasting-skforecast.html
#   [ERROR] Enlace roto o inaccesible: https://www.cienciadedatos.net/documentos/py59-scalable-forecasting-model.html
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py53-global-forecasting-models
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py54-forecasting-with-deep-learning
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html#libraries-and-data
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html#forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html#backtesting-multiple-series
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html#hyperparameter-search-and-lags-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/hyperparameter-tuning-and-lags-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/hyperparameter-tuning-and-lags-selection#bayesian-search
#   [OK] Enlace accesible: [] - https://optuna.readthedocs.io/en/stable/reference/generated/optuna.study.Study.html#optuna.study.Study
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html#exogenous-variables-in-multi-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/exogenous-variables
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html#series-transformations
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html#series-with-different-lengths-and-different-exogenous-variables
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html#series-encoding-in-multi-series
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html#forecasting-unknown-series
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/probabilistic-forecasting#out-sample-residuals-non-conditioned-on-predicted-values
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html#weights-in-multi-series
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html#differentiation
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py49-modelling-time-series-trend-with-tree-based-models.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html#feature-selection-in-multi-series
#   [OK] Enlace accesible: [] - https://scikit-learn.org/stable/modules/feature_selection.html
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/feature-selection#global-forecasting-models-feature-selection
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html#compare-multiple-metrics
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/metrics
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting.html#training-and-prediction-matrices
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/training-and-prediction-matrices
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog.html#global-forecasting-models-time-series-with-different-lengths-and-different-exogenous-variables
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog.html#global-forecasting-models-time-series-with-different-lengths-and-different-exogenous-variables
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog.html#libraries-and-data
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog.html#train-and-predict
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog.html#missing-values-in-the-series
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/api/forecasterrecursivemultiseries
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog.html#backtesting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/backtesting
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog.html#hyperparameter-tuning-and-lags-selection
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting#hyperparameter-tuning-and-lags-selection-multi-series
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog.html#categorical-variables
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting.html#global-forecasting-models-dependent-multi-series-forecasting-multivariate-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting.html#global-forecasting-models-dependent-multi-series-forecasting-multivariate-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/introduction-forecasting/introduction-forecasting#direct-multi-step-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/independent-multi-time-series-forecasting
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/multi-series-with-different-length-and-different_exog
#   [OK] Enlace accesible: [] - https://skforecast.org/0.14.0/user_guides/forecasting-with-deep-learning-rnn-lstm
#   [OK] Enlace accesible: [] - https://www.cienciadedatos.net/documentos/py44-multi-series-forecasting-skforecast.html
#   [ERROR] Enlace roto o inaccesible: https://www.cienciadedatos.net/documentos/py59-scalable-forecasting-model.html
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py53-global-forecasting-models
#   [OK] Enlace accesible: [] - https://cienciadedatos.net/documentos/py54-forecasting-with-deep-learning
#   [OK] Enlace accesible: ['anchor-link'] - https://skforecast.org/0.14.0/user_guides/dependent-multi-series-multivariate-forecasting.html#libraries-and-data
# ...
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#int
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#bool
#   [OK] Enlace accesible: [] - https://squidfunk.github.io/mkdocs-material/
#
# [OK] Página accesible: https://skforecast.org/0.14.0/api/ForecasterRnn.html
#   [OK] Enlace accesible: ['md-skip'] - https://skforecast.org/0.14.0/api/ForecasterRnn.html#forecasterrnn
#   [OK] Enlace accesible: [] - https://skforecast.org/
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/api/ForecasterRnn.html#forecasterrnn
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/api/ForecasterRnn.html#skforecast.deep_learning._forecaster_rnn.ForecasterRnn
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#str
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#list
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#int
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#list
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#str
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#object
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#dict
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#dict
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#str
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#int
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#int
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#list
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#str
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/typing.html#typing.Optional
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/typing.html#typing.Union
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#int
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#list
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#str
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#str
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#list
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#object
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#dict
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#dict
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#int
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#int
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#type
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#str
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#list
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#bool
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#list
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#type
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#dict
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#dict
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#dict
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#dict
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#dict
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#dict
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#str
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#bool
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#str
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#str
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#str
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#str
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#int
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#dict
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/api/ForecasterRnn.html#skforecast.deep_learning._forecaster_rnn.ForecasterRnn._create_lags
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/api/ForecasterRnn.html#skforecast.deep_learning._forecaster_rnn.ForecasterRnn.create_train_X_y
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#dict
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/api/ForecasterRnn.html#skforecast.deep_learning._forecaster_rnn.ForecasterRnn.fit
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#bool
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#bool
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/api/ForecasterRnn.html#skforecast.deep_learning._forecaster_rnn.ForecasterRnn.predict
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#int
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#list
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#str
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#list
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/functions.html#bool
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/api/ForecasterRnn.html#skforecast.deep_learning._forecaster_rnn.ForecasterRnn.plot_history
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#dict
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/api/ForecasterRnn.html#skforecast.deep_learning._forecaster_rnn.ForecasterRnn.set_params
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#dict
#   [OK] Enlace accesible: ['headerlink'] - https://skforecast.org/0.14.0/api/ForecasterRnn.html#skforecast.deep_learning._forecaster_rnn.ForecasterRnn.set_fit_kwargs
#   [OK] Enlace accesible: ['autorefs', 'autorefs-external'] - https://docs.python.org/3/library/stdtypes.html#dict
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 2
#       1 for link in links:
# ----> 2     check_links_ignoring_nav_links(link)
#
# Cell In[39], line 40, in check_links_ignoring_nav_links(url)
#      37 full_url = urljoin(url, href)
#      39 try:
# ---> 40     link_response = requests.get(full_url)
#      41     link_response.raise_for_status()  # Verificar si el enlace es accesible
#      42     print(f"  [OK] Enlace accesible: {class_link} - {full_url}")
#
# File c:\Users\jaesc2\Miniconda3\envs\skforecast_py11\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\jaesc2\Miniconda3\envs\skforecast_py11\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\jaesc2\Miniconda3\envs\skforecast_py11\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\jaesc2\Miniconda3\envs\skforecast_py11\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\jaesc2\Miniconda3\envs\skforecast_py11\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\jaesc2\Miniconda3\envs\skforecast_py11\Lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File c:\Users\jaesc2\Miniconda3\envs\skforecast_py11\Lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     464 try:
#     465     # Trigger any extra validation we need to do.
#     466     try:
# --> 467         self._validate_conn(conn)
#     468     except (SocketTimeout, BaseSSLError) as e:
#     469         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\jaesc2\Miniconda3\envs\skforecast_py11\Lib\site-packages\urllib3\connectionpool.py:1096, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 # Force connect early to allow us to validate the connection.
#    1095 if conn.is_closed:
# -> 1096     conn.connect()
#    1098 if not conn.is_verified:
#    1099     warnings.warn(
#    1100         (
#    1101             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1106         InsecureRequestWarning,
#    1107     )
#
# File c:\Users\jaesc2\Miniconda3\envs\skforecast_py11\Lib\site-packages\urllib3\connection.py:642, in HTTPSConnection.connect(self)
#     633 if is_time_off:
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#     661 self.is_verified = sock_and_verified.is_verified
#
# File c:\Users\jaesc2\Miniconda3\envs\skforecast_py11\Lib\site-packages\urllib3\connection.py:782, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     779     if is_ipaddress(normalized):
#     780         server_hostname = normalized
# --> 782 ssl_sock = ssl_wrap_socket(
#     783     sock=sock,
#     784     keyfile=key_file,
#     785     certfile=cert_file,
#     786     key_password=key_password,
#     787     ca_certs=ca_certs,
#     788     ca_cert_dir=ca_cert_dir,
#     789     ca_cert_data=ca_cert_data,
#     790     server_hostname=server_hostname,
#     791     ssl_context=context,
#     792     tls_in_tls=tls_in_tls,
#     793 )
#     795 try:
#     796     if assert_fingerprint:
#
# File c:\Users\jaesc2\Miniconda3\envs\skforecast_py11\Lib\site-packages\urllib3\util\ssl_.py:445, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     443 if ca_certs or ca_cert_dir or ca_cert_data:
#     444     try:
# --> 445         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     446     except OSError as e:
#     447         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %%
for link in links_general:
    check_links_ignoring_nav_links(link)
