# %% [markdown]
# # Profiling main skforecast classes and methods

# %%
# %load_ext autoreload
# %autoreload 2
import sys
from pathlib import Path
sys.path.insert(1, str(Path.cwd().parent))
str(Path.cwd().parent)
# Out:
# '/home/ubuntu/varios/skforecast'

# %%
import platform
import psutil
import skforecast
import pandas as pd
import numpy as np
import scipy
import sklearn

import numpy as np
import pandas as pd
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler
from lightgbm import LGBMRegressor

from skforecast.ForecasterAutoreg import ForecasterAutoreg
from skforecast.ForecasterAutoregMultiSeries import ForecasterAutoregMultiSeries
from skforecast.model_selection import backtesting_forecaster
from skforecast.model_selection import grid_search_forecaster
from skforecast.model_selection_multiseries import grid_search_forecaster_multiseries
from skforecast.model_selection_multiseries import bayesian_search_forecaster_multiseries
from skforecast.model_selection_multiseries import backtesting_forecaster_multiseries
from skforecast.utils import *
from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import make_column_transformer
from skforecast.preprocessing import series_long_to_dict
from skforecast.preprocessing import exog_long_to_dict
from skforecast.datasets import fetch_dataset

# %load_ext pyinstrument
# %load_ext line_profiler

# %% [markdown]
# # Information system and libraries

# %%
# Versions
# ==============================================================================
print(f"Python version: {platform.python_version()}")
print(f"scikit-learn version: {sklearn.__version__}")
print(f"skforecast version: {skforecast.__version__}")
print(f"pandas version: {pd.__version__}")
print(f"numpy version: {np.__version__}")
print(f"scipy version: {scipy.__version__}")
print(f"psutil version: {psutil.__version__}")
print("")

# Computer information
# ==============================================================================
#Computer network name
print(f"Computer network name: {platform.node()}")
#Machine type
print(f"Machine type: {platform.machine()}")
#Processor type
print(f"Processor type: {platform.processor()}")
#Platform type
print(f"Platform type: {platform.platform()}")
#Operating system
print(f"Operating system: {platform.system()}")
#Operating system release
print(f"Operating system release: {platform.release()}")
#Operating system version
print(f"Operating system version: {platform.version()}")
#Physical cores
print(f"Number of physical cores: {psutil.cpu_count(logical=False)}")
#Logical cores
print(f"Number of logical cores: {psutil.cpu_count(logical=True)}")
# Out:
# Python version: 3.11.9
# scikit-learn version: 1.3.0
# skforecast version: 0.13.0
# pandas version: 2.2.2
# numpy version: 1.26.4
# scipy version: 1.13.1
# psutil version: 6.0.0
#
# Computer network name: ip-10-2-1-218
# Machine type: x86_64
# Processor type: x86_64
# Platform type: Linux-5.15.0-1064-aws-x86_64-with-glibc2.31
# Operating system: Linux
# Operating system release: 5.15.0-1064-aws
# Operating system version: #70~20.04.1-Ubuntu SMP Fri Jun 14 15:42:13 UTC 2024
# Number of physical cores: 4
# Number of logical cores: 8

# %% [markdown]
# # ForecasterAutoreg

# %%
# Data
# ==============================================================================
len_series = 1_000
n_exog = 300
rgn = np.random.default_rng(seed=123)
y = pd.Series(
    rgn.random(size=(len_series)),
    name="y",
    index=pd.date_range(start="2000-01-01", periods=len_series, freq="h"),
)
exog = pd.DataFrame(rgn.random(size=(len_series, n_exog)), index=y.index)
exog.columns = [f"exog_{i}" for i in range(exog.shape[1])]
exog_test = exog.copy()
exog_test.index = exog.index + pd.DateOffset(hours=len_series)
exog_test = exog_test.asfreq("h")
print(f"Shape of y: {y.shape}")
print(f"Shape of exog: {exog.shape}")
print(f"Shape of exog_test: {exog_test.shape}")

display(y.head(2))
display(exog.head(2))
display(exog_test.head(2))

# %%
# Forecaster
# ==============================================================================
forecaster = ForecasterAutoreg(
    regressor=Ridge(),
    lags=24,
    transformer_exog=StandardScaler(),
    transformer_y=StandardScaler(),
)

# %%
# %%pyinstrument
#
# forecaster.fit(y=y, exog=exog)
# Out:
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 14:51:16  Samples:  82
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 0.104     CPU time: 0.447
# /   _/                      v4.6.2
#
# Program: /home/ubuntu/anaconda3/envs/skforecast_13_py11/lib/python3.11/site-packages/ipykernel_launcher.py --f=/home/ubuntu/.local/share/jupyter/runtime/kernel-v2-49123l3BPimopyoSU.json
#
# 0.103 <module>  ../../../../tmp/ipykernel_53931/3742849773.py:1
# |- 0.102 ForecasterAutoreg.fit  skforecast/ForecasterAutoreg/ForecasterAutoreg.py:527
# |  |- 0.035 ForecasterAutoreg.create_train_X_y  skforecast/ForecasterAutoreg/ForecasterAutoreg.py:379
# |  |  |- 0.030 transform_dataframe  skforecast/utils/utils.py:1520
# |  |  |  `- 0.030 StandardScaler.wrapped  sklearn/utils/_set_output.py:138
# |  |  |        [34 frames hidden]  sklearn, numpy, <built-in>, pandas
# |  |  |- 0.002 DatetimeIndex.__getitem__  pandas/core/indexes/base.py:5373
# |  |  |     [2 frames hidden]  pandas
# |  |  `- 0.002 concat  pandas/core/reshape/concat.py:157
# |  |        [8 frames hidden]  pandas, <built-in>
# |  |- 0.025 wrapper  sklearn/base.py:1134
# |  |     [26 frames hidden]  sklearn, pandas, scipy, <built-in>
# |  |- 0.024 Ridge.predict  sklearn/linear_model/_base.py:372
# |  |     [15 frames hidden]  sklearn, pandas
# |  |- 0.015 ForecasterAutoreg._binning_in_sample_residuals  skforecast/ForecasterAutoreg/ForecasterAutoreg.py:623
# |  |  |- 0.004 SeriesGroupBy.apply  pandas/core/groupby/generic.py:224
# |  |  |     [4 frames hidden]  pandas
# |  |  |- 0.003 merge  pandas/core/reshape/merge.py:135
# |  |  |     [7 frames hidden]  pandas
# |  |  |- 0.002 DataFrame.__setitem__  pandas/core/frame.py:4271
# |  |  |     [10 frames hidden]  pandas, warnings, re
# |  |  |- 0.002 wrapper  sklearn/base.py:1134
# |  |  `- 0.002 DataFrame.__getitem__  pandas/core/frame.py:4062
# |  |        [4 frames hidden]  pandas
# |  `- 0.002 get_exog_dtypes  skforecast/utils/utils.py:431
# |     `- 0.001 DataFrame.dtypes  pandas/core/generic.py:6432
# |           [7 frames hidden]  pandas
# `- 0.002 [self]  ../../../../tmp/ipykernel_53931/3742849773.py

# %%
# Profiling fit()
# ==============================================================================
def funt_to_profile(forecaster, y, exog):
    forecaster.fit(y=y, exog=exog)

# %lprun -f forecaster.fit funt_to_profile(forecaster, y, exog)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.103863 s
# File: /home/ubuntu/varios/skforecast/skforecast/ForecasterAutoreg/ForecasterAutoreg.py
# Function: fit at line 527
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    527                                               def fit(
#    528                                                   self,
#    529                                                   y: pd.Series,
#    530                                                   exog: Optional[Union[pd.Series, pd.DataFrame]]=None,
#    531                                                   store_last_window: bool=True,
#    532                                                   store_in_sample_residuals: bool=True
#    533                                               ) -> None:
#    534                                                   """
#    535                                                   Training Forecaster.
#    536
#    537                                                   Additional arguments to be passed to the `fit` method of the regressor
#    538                                                   can be added with the `fit_kwargs` argument when initializing the forecaster.
#    539
#    540                                                   Parameters
#    541                                                   ----------
#    542                                                   y : pandas Series
#    543                                                       Training time series.
#    544                                                   exog : pandas Series, pandas DataFrame, default `None`
#    545                                                       Exogenous variable/s included as predictor/s. Must have the same
#    546                                                       number of observations as `y` and their indexes must be aligned so
#    547                                                       that y[i] is regressed on exog[i].
#    548                                                   store_last_window : bool, default `True`
#    549                                                       Whether or not to store the last window of training data.
#    550                                                   store_in_sample_residuals : bool, default `True`
#    551                                                       If `True`, in-sample residuals will be stored in the forecaster object
#    552                                                       after fitting.
#    553
#    554                                                   Returns
#    555                                                   -------
#    556                                                   None
#    557
#    558                                                   """
#    559
#    560                                                   # Reset values in case the forecaster has already been fitted.
#    561         1       1490.0   1490.0      0.0          self.index_type          = None
#    562         1       2130.0   2130.0      0.0          self.index_freq          = None
#    563         1      18160.0  18160.0      0.0          self.last_window         = None
#    564         1        410.0    410.0      0.0          self.included_exog       = False
#    565         1        500.0    500.0      0.0          self.exog_type           = None
#    566         1       4300.0   4300.0      0.0          self.exog_dtypes         = None
#    567         1       1300.0   1300.0      0.0          self.exog_col_names      = None
#    568         1       2050.0   2050.0      0.0          self.X_train_col_names   = None
#    569         1       1370.0   1370.0      0.0          self.in_sample_residuals = None
#    570         1        440.0    440.0      0.0          self.fitted              = False
#    571         1       2960.0   2960.0      0.0          self.training_range      = None
#    572
#    573         1   33463062.0    3e+07     32.2          X_train, y_train = self.create_train_X_y(y=y, exog=exog)
#    574         1       5580.0   5580.0      0.0          sample_weight = self.create_sample_weights(X_train=X_train)
#    575
#    576         1        260.0    260.0      0.0          if sample_weight is not None:
#    577                                                       self.regressor.fit(X=X_train, y=y_train, sample_weight=sample_weight,
#    578                                                                          **self.fit_kwargs)
#    579                                                   else:
#    580         1   39268210.0    4e+07     37.8              self.regressor.fit(X=X_train, y=y_train, **self.fit_kwargs)
#    581
#    582         1       1600.0   1600.0      0.0          self.fitted = True
#    583         1      59051.0  59051.0      0.1          self.fit_date = pd.Timestamp.today().strftime('%Y-%m-%d %H:%M:%S')
#    584         1     649648.0 649648.0      0.6          self.training_range = preprocess_y(y=y, return_values=False)[1][[0, -1]]
#    585         1       6640.0   6640.0      0.0          self.index_type = type(X_train.index)
#    586         1       1390.0   1390.0      0.0          if isinstance(X_train.index, pd.DatetimeIndex):
#    587         1      27070.0  27070.0      0.0              self.index_freq = X_train.index.freqstr
#    588                                                   else:
#    589                                                       self.index_freq = X_train.index.step
#    590
#    591         1        330.0    330.0      0.0          if exog is not None:
#    592         1        430.0    430.0      0.0              self.included_exog = True
#    593         1       2020.0   2020.0      0.0              self.exog_type = type(exog)
#    594         1    1357857.0    1e+06      1.3              self.exog_dtypes = get_exog_dtypes(exog=exog)
#    595         1        520.0    520.0      0.0              self.exog_col_names = (
#    596         1       8420.0   8420.0      0.0                  exog.columns.to_list()
#    597         1       1150.0   1150.0      0.0                  if isinstance(exog, pd.DataFrame)
#    598                                                           else [exog.name]
#    599                                                       )
#    600
#    601                                                   # This is done to save time during fit in functions such as backtesting()
#    602         1        280.0    280.0      0.0          if store_in_sample_residuals:
#    603         2     233353.0 116676.5      0.2              in_sample_predictions = pd.Series(
#    604         1   16825412.0    2e+07     16.2                                          data  = self.regressor.predict(X_train),
#    605         1       3140.0   3140.0      0.0                                          index = X_train.index
#    606                                                                               )
#    607         2   11443717.0    6e+06     11.0              self._binning_in_sample_residuals(
#    608         1        440.0    440.0      0.0                  y_true = y_train,
#    609         1        250.0    250.0      0.0                  y_pred = in_sample_predictions
#    610                                                       )
#    611
#    612                                                   # The last time window of training data is stored so that lags needed as
#    613                                                   # predictors in the first iteration of `predict()` can be calculated. It
#    614                                                   # also includes the values need to calculate the diferenctiation.
#    615         1        640.0    640.0      0.0          if store_last_window:
#    616         1        760.0    760.0      0.0              self.last_window = (
#    617         1     174242.0 174242.0      0.2                  y.iloc[-self.window_size_diff:]
#    618         1      86821.0  86821.0      0.1                  .copy()
#    619         1     205663.0 205663.0      0.2                  .to_frame(name=y.name if y.name is not None else 'y')
#    620                                                       )

# %%
# Profiling create_train_X_y()
# ==============================================================================
def funt_to_profile(forecaster, y, exog):
    forecaster.create_train_X_y(y=y, exog=exog)

# %lprun -f forecaster.create_train_X_y funt_to_profile(forecaster, y, exog)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.0239219 s
# File: /home/ubuntu/varios/skforecast/skforecast/ForecasterAutoreg/ForecasterAutoreg.py
# Function: create_train_X_y at line 379
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    379                                               def create_train_X_y(
#    380                                                   self,
#    381                                                   y: pd.Series,
#    382                                                   exog: Optional[Union[pd.Series, pd.DataFrame]]=None
#    383                                               ) -> Tuple[pd.DataFrame, pd.Series]:
#    384                                                   """
#    385                                                   Create training matrices from univariate time series and exogenous
#    386                                                   variables.
#    387
#    388                                                   Parameters
#    389                                                   ----------
#    390                                                   y : pandas Series
#    391                                                       Training time series.
#    392                                                   exog : pandas Series, pandas DataFrame, default `None`
#    393                                                       Exogenous variable/s included as predictor/s. Must have the same
#    394                                                       number of observations as `y` and their indexes must be aligned.
#    395
#    396                                                   Returns
#    397                                                   -------
#    398                                                   X_train : pandas DataFrame
#    399                                                       Training values (predictors).
#    400                                                       Shape: (len(y) - self.max_lag, len(self.lags))
#    401                                                   y_train : pandas Series
#    402                                                       Values (target) of the time series related to each row of `X_train`.
#    403                                                       Shape: (len(y) - self.max_lag, )
#    404
#    405                                                   """
#    406
#    407         1     391875.0 391875.0      1.6          check_y(y=y)
#    408         1     245473.0 245473.0      1.0          y = input_to_frame(data=y, input_name='y')
#    409
#    410         1       1070.0   1070.0      0.0          fit_transformer = False if self.fitted else True
#    411         2    5075801.0    3e+06     21.2          y = transform_dataframe(
#    412         1        290.0    290.0      0.0                  df                = y,
#    413         1        490.0    490.0      0.0                  transformer       = self.transformer_y,
#    414         1        260.0    260.0      0.0                  fit               = fit_transformer,
#    415         1        290.0    290.0      0.0                  inverse_transform = False,
#    416                                                       )
#    417         1      36991.0  36991.0      0.2          y_values, y_index = preprocess_y(y=y)
#    418
#    419         1       1720.0   1720.0      0.0          if self.differentiation is not None:
#    420                                                       if not self.fitted:
#    421                                                           y_values = self.differentiator.fit_transform(y_values)
#    422                                                       else:
#    423                                                           differentiator = clone(self.differentiator)
#    424                                                           y_values = differentiator.fit_transform(y_values)
#    425
#    426         1        280.0    280.0      0.0          if exog is not None:
#    427         1       4620.0   4620.0      0.0              check_exog(exog=exog, allow_nan=True)
#    428         1       3440.0   3440.0      0.0              exog = input_to_frame(data=exog, input_name='exog')
#    429         1       6300.0   6300.0      0.0              if len(exog) != len(y):
#    430                                                           raise ValueError(
#    431                                                               (f"`exog` must have same number of samples as `y`. "
#    432                                                                f"length `exog`: ({len(exog)}), length `y`: ({len(y)})")
#    433                                                           )
#    434
#    435         2   12408769.0    6e+06     51.9              exog = transform_dataframe(
#    436         1        280.0    280.0      0.0                         df                = exog,
#    437         1        460.0    460.0      0.0                         transformer       = self.transformer_exog,
#    438         1        250.0    250.0      0.0                         fit               = fit_transformer,
#    439         1        270.0    270.0      0.0                         inverse_transform = False
#    440                                                              )
#    441
#    442         1    1348646.0    1e+06      5.6              check_exog_dtypes(exog, call_check_exog=True)
#    443
#    444         1       9540.0   9540.0      0.0              _, exog_index = preprocess_exog(exog=exog, return_values=False)
#    445         1     259273.0 259273.0      1.1              if not (exog_index[:len(y_index)] == y_index).all():
#    446                                                           raise ValueError(
#    447                                                               ("Different index for `y` and `exog`. They must be equal "
#    448                                                                "to ensure the correct alignment of values.")
#    449                                                           )
#    450
#    451         1     141962.0 141962.0      0.6          X_train, y_train = self._create_lags(y=y_values)
#    452         1      27761.0  27761.0      0.1          X_train_col_names = [f"lag_{i}" for i in self.lags]
#    453         2     235623.0 117811.5      1.0          X_train = pd.DataFrame(
#    454         1        350.0    350.0      0.0                        data    = X_train,
#    455         1        240.0    240.0      0.0                        columns = X_train_col_names,
#    456         1      42300.0  42300.0      0.2                        index   = y_index[self.max_lag: ]
#    457                                                             )
#    458
#    459         1        470.0    470.0      0.0          if exog is not None:
#    460                                                       # The first `self.max_lag` positions have to be removed from exog
#    461                                                       # since they are not in X_train.
#    462         1     191752.0 191752.0      0.8              exog_to_train = exog.iloc[self.max_lag:, ]
#    463         1      54531.0  54531.0      0.2              exog_to_train.index = exog_index[self.max_lag:]
#    464         1    3230079.0    3e+06     13.5              X_train = pd.concat((X_train, exog_to_train), axis=1)
#    465
#    466                                                   # TODO: move self to fit method and make X_train_col_names a return
#    467         1        800.0    800.0      0.0          if not self.fitted:
#    468                                                       self.X_train_col_names = X_train.columns.to_list()
#    469
#    470                                                   # TODO: DataFrame or Series?
#    471         2     143291.0  71645.5      0.6          y_train = pd.Series(
#    472         1        280.0    280.0      0.0                        data  = y_train,
#    473         1      53671.0  53671.0      0.2                        index = y_index[self.max_lag: ],
#    474         1        420.0    420.0      0.0                        name  = 'y'
#    475                                                             )
#    476
#    477         1       1590.0   1590.0      0.0          if self.differentiation is not None:
#    478                                                       X_train = X_train.iloc[self.differentiation: ]
#    479                                                       y_train = y_train.iloc[self.differentiation: ]
#    480
#    481         1        400.0    400.0      0.0          return X_train, y_train

# %%
# Profiling funt_to_profile()
# ==============================================================================
def funt_to_profile(forecaster, exog_test):
    forecaster.predict(steps=100, exog=exog_test)

# %lprun -f forecaster.predict funt_to_profile(forecaster, exog_test)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.0438469 s
# File: /home/ubuntu/varios/skforecast/skforecast/ForecasterAutoreg/ForecasterAutoreg.py
# Function: predict at line 890
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    890                                               def predict(
#    891                                                   self,
#    892                                                   steps: int,
#    893                                                   last_window: Optional[Union[pd.Series, pd.DataFrame]]=None,
#    894                                                   exog: Optional[Union[pd.Series, pd.DataFrame]]=None
#    895                                               ) -> pd.Series:
#    896                                                   """
#    897                                                   Predict n steps ahead. It is an recursive process in which, each prediction,
#    898                                                   is used as a predictor for the next step.
#    899
#    900                                                   Parameters
#    901                                                   ----------
#    902                                                   steps : int
#    903                                                       Number of future steps predicted.
#    904                                                   last_window : pandas Series, pandas DataFrame, default `None`
#    905                                                       Series values used to create the predictors (lags) needed in the
#    906                                                       first iteration of the prediction (t + 1).
#    907                                                       If `last_window = None`, the values stored in `self.last_window` are
#    908                                                       used to calculate the initial predictors, and the predictions start
#    909                                                       right after training data.
#    910                                                   exog : pandas Series, pandas DataFrame, default `None`
#    911                                                       Exogenous variable/s included as predictor/s.
#    912
#    913                                                   Returns
#    914                                                   -------
#    915                                                   predictions : pandas Series
#    916                                                       Predicted values.
#    917
#    918                                                   """
#    919
#    920         2   17426439.0    9e+06     39.7          last_window_values, last_window_index, exog_values = self._create_predict_inputs(
#    921         1        310.0    310.0      0.0              steps=steps, last_window=last_window, exog=exog
#    922                                                   )
#    923
#    924         2   23416070.0    1e+07     53.4          predictions = self._recursive_predict(
#    925         1        220.0    220.0      0.0                            steps       = steps,
#    926         1        260.0    260.0      0.0                            last_window = last_window_values,
#    927         1        210.0    210.0      0.0                            exog        = exog_values
#    928                                                                 )
#    929
#    930         1       2250.0   2250.0      0.0          if self.differentiation is not None:
#    931                                                       predictions = self.differentiator.inverse_transform_next_window(predictions)
#    932
#    933         2     163902.0  81951.0      0.4          predictions = pd.Series(
#    934         1        280.0    280.0      0.0                            data  = predictions,
#    935         2     330013.0 165006.5      0.8                            index = expand_index(
#    936         1        240.0    240.0      0.0                                        index = last_window_index,
#    937         1        170.0    170.0      0.0                                        steps = steps
#    938                                                                             ),
#    939         1        550.0    550.0      0.0                            name = 'pred'
#    940                                                                 )
#    941
#    942         2    2504310.0    1e+06      5.7          predictions = transform_series(
#    943         1        270.0    270.0      0.0                            series            = predictions,
#    944         1        670.0    670.0      0.0                            transformer       = self.transformer_y,
#    945         1        260.0    260.0      0.0                            fit               = False,
#    946         1        200.0    200.0      0.0                            inverse_transform = True
#    947                                                                 )
#    948
#    949         1        310.0    310.0      0.0          return predictions

# %%
# Profiling _create_predict_inputs()
# ==============================================================================
last_window = forecaster.last_window

def funt_to_profile(forecaster, steps, last_window, exog):
    forecaster._create_predict_inputs(steps=steps, last_window=last_window, exog=exog)

# %lprun -f forecaster._create_predict_inputs funt_to_profile(forecaster, 100, last_window, exog_test)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.0171847 s
# File: /home/ubuntu/varios/skforecast/skforecast/ForecasterAutoreg/ForecasterAutoreg.py
# Function: _create_predict_inputs at line 693
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    693                                               def _create_predict_inputs(
#    694                                                   self,
#    695                                                   steps: int,
#    696                                                   last_window: Optional[Union[pd.Series, pd.DataFrame]]=None,
#    697                                                   exog: Optional[Union[pd.Series, pd.DataFrame]]=None
#    698                                               ) -> Tuple[np.ndarray, np.ndarray, pd.Index]:
#    699                                                   """
#    700                                                   Create inputs needed for the first iteration of the prediction process.
#    701                                                   Since it is a recursive process, last window is updated at each
#    702                                                   iteration of the prediction process.
#    703
#    704                                                   Parameters
#    705                                                   ----------
#    706                                                   steps : int
#    707                                                       Number of future steps predicted.
#    708                                                   last_window : pandas Series, pandas DataFrame, default `None`
#    709                                                       Series values used to create the predictors (lags) needed in the
#    710                                                       first iteration of the prediction (t + 1).
#    711                                                       If `last_window = None`, the values stored in `self.last_window` are
#    712                                                       used to calculate the initial predictors, and the predictions start
#    713                                                       right after training data.
#    714                                                   exog : pandas Series, pandas DataFrame, default `None`
#    715                                                       Exogenous variable/s included as predictor/s.
#    716
#    717                                                   Returns
#    718                                                   -------
#    719                                                   last_window_values : numpy ndarray
#    720                                                       Series predictors.
#    721                                                   last_window_index : pandas Index
#    722                                                       Last window Index.
#    723                                                   exog_values : numpy ndarray, default `None`
#    724                                                       Exogenous variable/s included as predictor/s.
#    725
#    726                                                   """
#    727
#    728         1        830.0    830.0      0.0          if last_window is None:
#    729                                                       last_window = self.last_window
#    730
#    731        18    2648152.0 147119.6     15.4          check_predict_input(
#    732         1       2500.0   2500.0      0.0              forecaster_name  = type(self).__name__,
#    733         1        430.0    430.0      0.0              steps            = steps,
#    734         1        670.0    670.0      0.0              fitted           = self.fitted,
#    735         1        410.0    410.0      0.0              included_exog    = self.included_exog,
#    736         1        690.0    690.0      0.0              index_type       = self.index_type,
#    737         1       1100.0   1100.0      0.0              index_freq       = self.index_freq,
#    738         1        860.0    860.0      0.0              window_size      = self.window_size_diff,
#    739         1        340.0    340.0      0.0              last_window      = last_window,
#    740         1        360.0    360.0      0.0              last_window_exog = None,
#    741         1        290.0    290.0      0.0              exog             = exog,
#    742         1        770.0    770.0      0.0              exog_type        = self.exog_type,
#    743         1        380.0    380.0      0.0              exog_col_names   = self.exog_col_names,
#    744         1        320.0    320.0      0.0              interval         = None,
#    745         1        350.0    350.0      0.0              alpha            = None,
#    746         1        250.0    250.0      0.0              max_steps        = None,
#    747         1        250.0    250.0      0.0              levels           = None,
#    748         1        250.0    250.0      0.0              series_col_names = None
#    749                                                   )
#    750
#    751         1     172932.0 172932.0      1.0          last_window = last_window.iloc[-self.window_size_diff:].copy()
#    752         1       4010.0   4010.0      0.0          last_window = input_to_frame(data=last_window, input_name='last_window')
#    753
#    754         1        280.0    280.0      0.0          if exog is not None:
#    755         1       2240.0   2240.0      0.0              exog = input_to_frame(data=exog, input_name='exog')
#    756         1    1242455.0    1e+06      7.2              exog = exog.loc[:, self.exog_col_names]
#    757         2    9765587.0    5e+06     56.8              exog = transform_dataframe(
#    758         1        240.0    240.0      0.0                         df                = exog,
#    759         1        770.0    770.0      0.0                         transformer       = self.transformer_exog,
#    760         1        260.0    260.0      0.0                         fit               = False,
#    761         1        230.0    230.0      0.0                         inverse_transform = False
#    762                                                              )
#    763         1    1109593.0    1e+06      6.5              check_exog_dtypes(exog=exog)
#    764         1      17070.0  17070.0      0.1              exog_values = exog.to_numpy()[:steps]
#    765                                                   else:
#    766                                                       exog_values = None
#    767
#    768         2    2177626.0    1e+06     12.7          last_window = transform_dataframe(
#    769         1        240.0    240.0      0.0                            df                = last_window,
#    770         1        890.0    890.0      0.0                            transformer       = self.transformer_y,
#    771         1        280.0    280.0      0.0                            fit               = False,
#    772         1        230.0    230.0      0.0                            inverse_transform = False
#    773                                                                 )
#    774         2      28350.0  14175.0      0.2          last_window_values, last_window_index = preprocess_last_window(
#    775         1        250.0    250.0      0.0                                                      last_window = last_window
#    776                                                                                           )
#    777         1       1630.0   1630.0      0.0          if self.differentiation is not None:
#    778                                                       last_window_values = self.differentiator.fit_transform(last_window_values)
#    779
#    780         1        350.0    350.0      0.0          return last_window_values, last_window_index, exog_values

# %% [markdown]
# # ForecasterAutoregMultiSeries

# %%
# Data
# ==============================================================================
data = fetch_dataset(name='bdg2_daily')

infrequent_types = (
    data
    .drop_duplicates(subset=['building_id'])['primaryspaceusage']
    .value_counts()
    .loc[lambda x: x < 100]
    .index
    .tolist()
)
infrequent_subtypes = (
    data
    .drop_duplicates(subset=['building_id'])['sub_primaryspaceusage']
    .value_counts()
    .loc[lambda x: x < 50]
    .index
    .tolist()
)

data['primaryspaceusage'] = np.where(
    data['primaryspaceusage'].isin(infrequent_types),
    'Other',
    data['primaryspaceusage']
)
data['sub_primaryspaceusage'] = np.where(
    data['sub_primaryspaceusage'].isin(infrequent_subtypes),
    'Other',
    data['sub_primaryspaceusage']
)

# Calendar features
# ==============================================================================
data['day_of_week'] = data.index.dayofweek
data['week_of_year'] = data.index.isocalendar().week.astype(int)
data['month'] = data.index.month

# Cyclical encoding of calendar features
# ==============================================================================
data['sin_day_of_week'] = np.sin(2*np.pi*data['day_of_week']/7)
data['cos_day_of_week'] = np.cos(2*np.pi*data['day_of_week']/7)
data['sin_week_of_year'] = np.sin(2*np.pi*data['week_of_year']/52)
data['cos_week_of_year'] = np.cos(2*np.pi*data['week_of_year']/52)
data['sin_month'] = np.sin(2*np.pi*data['month']/12)
data['cos_month'] = np.cos(2*np.pi*data['month']/12)

# Transformer: ordinal encoding
# ==============================================================================
# A ColumnTransformer is used to transform categorical (not numerical) features
# using ordinal encoding. Numeric features are left untouched. Missing values
# are coded as -1. If a new category is found in the test set, it is encoded
# as -1.
categorical_features = ['primaryspaceusage', 'sub_primaryspaceusage', 'timezone']
transformer_exog = make_column_transformer(
                       (
                           OrdinalEncoder(
                               dtype=float,
                               handle_unknown="use_encoded_value",
                               unknown_value=np.nan,
                               encoded_missing_value=np.nan
                           ),
                           categorical_features
                       ),
                       remainder="passthrough",
                       verbose_feature_names_out=False,
                   ).set_output(transform="pandas")
transformer_exog

# Exogenous features selected for modeling
# ==============================================================================
exog_features = [
    "primaryspaceusage",
    "sub_primaryspaceusage",
    "timezone",
    "sqm",
    "airTemperature",
    "cloudCoverage",
    "dewTemperature",
    "precipDepth1HR",
    "precipDepth6HR",
    "seaLvlPressure",
    "windDirection",
    "windSpeed",
    "sin_day_of_week",
    "cos_day_of_week",
    "sin_week_of_year",
    "cos_week_of_year",
    "sin_month",
    "cos_month",
]

# Transform series and exog to dictionaries
# ==============================================================================
series_dict = series_long_to_dict(
    data      = data.reset_index(),
    series_id = 'building_id',
    index     = 'timestamp',
    values    = 'meter_reading',
    freq      = 'D'
)

exog_dict = exog_long_to_dict(
    data      = data[exog_features + ['building_id']].reset_index(),
    series_id = 'building_id',
    index     = 'timestamp',
    freq      = 'D'
)

data = data.sort_index()
end_train = '2017-08-31 23:59:00'
end_validation = '2017-10-31 23:59:00'
series_dict_train = {k: v.loc[: end_train,] for k, v in series_dict.items()}
series_dict_valid = {k: v.loc[end_train: end_validation,] for k, v in series_dict.items()}
series_dict_test = {k: v.loc[end_validation:,] for k, v in series_dict.items()}
exog_dict_train = {k: v.loc[: end_train,] for k, v in exog_dict.items()}
exog_dict_valid = {k: v.loc[end_train: end_validation,] for k, v in exog_dict.items()}
exog_dict_test = {k: v.loc[end_validation:,] for k, v in exog_dict.items()}
# Out:
# bdg2_daily
# ----------
# Daily energy consumption data from the The Building Data Genome Project 2 with
# building metadata and weather data. https://github.com/buds-lab/building-data-
# genome-project-2
# Miller, C., Kathirgamanathan, A., Picchetti, B. et al. The Building Data Genome
# Project 2, energy meter data from the ASHRAE Great Energy Predictor III
# competition. Sci Data 7, 368 (2020). https://doi.org/10.1038/s41597-020-00712-x
# Shape of the dataset: (1153518, 17)

# %%
# Forecaster
# ==============================================================================
forecaster = ForecasterAutoregMultiSeries(
    regressor=LGBMRegressor(random_state=8520, verbose=-1),
    lags=14,
    transformer_series=None,
    transformer_exog=transformer_exog,
    fit_kwargs={'categorical_feature': categorical_features},
    encoding="ordinal"
)

# %%
# %%pyinstrument
#
# forecaster.fit(series=series_dict_train, exog=exog_dict_train)
# Out:
# /home/ubuntu/varios/skforecast/skforecast/ForecasterAutoregMultiSeries/ForecasterAutoregMultiSeries.py:821: MissingValuesWarning: NaNs detected in `X_train`. Some regressors do not allow NaN values during training. If you want to drop them, set `forecaster.dropna_from_series = True`.
#  You can suppress this warning using: warnings.simplefilter('ignore', category=MissingValuesWarning)
#   warnings.warn(
#   _     ._   __/__   _ _  _  _ _/_   Recorded: 14:51:34  Samples:  9252
#  /_//_/// /_\ / //_// / //_'/ //     Duration: 18.470    CPU time: 36.179
# /   _/                      v4.6.2
#
# Program: /home/ubuntu/anaconda3/envs/skforecast_13_py11/lib/python3.11/site-packages/ipykernel_launcher.py --f=/home/ubuntu/.local/share/jupyter/runtime/kernel-v2-49123l3BPimopyoSU.json
#
# 18.469 <module>  ../../../../tmp/ipykernel_53931/2636560737.py:1
# `- 18.467 ForecasterAutoregMultiSeries.fit  skforecast/ForecasterAutoregMultiSeries/ForecasterAutoregMultiSeries.py:1052
#    |- 8.814 ForecasterAutoregMultiSeries._create_train_X_y  skforecast/ForecasterAutoregMultiSeries/ForecasterAutoregMultiSeries.py:595
#    |  |- 2.749 align_series_and_exog_multiseries  skforecast/utils/utils.py:2532
#    |  |  |- 1.708 _LocIndexer.__getitem__  pandas/core/indexing.py:1176
#    |  |  |     [17 frames hidden]  pandas
#    |  |  |- 0.422 Series.first_valid_index  pandas/core/generic.py:12792
#    |  |  |     [7 frames hidden]  pandas
#    |  |  `- 0.395 Series.last_valid_index  pandas/core/generic.py:12868
#    |  |        [7 frames hidden]  pandas
#    |  |- 2.309 ForecasterAutoregMultiSeries._create_train_X_y_single_series  skforecast/ForecasterAutoregMultiSeries/ForecasterAutoregMultiSeries.py:505
#    |  |  |- 0.733 DataFrame.__setitem__  pandas/core/frame.py:4271
#    |  |  |     [6 frames hidden]  pandas
#    |  |  |- 0.638 DataFrame.__init__  pandas/core/frame.py:694
#    |  |  |     [5 frames hidden]  pandas
#    |  |  |- 0.254 _iLocIndexer.__getitem__  pandas/core/indexing.py:1176
#    |  |  |     [2 frames hidden]  pandas
#    |  |  |- 0.217 ForecasterAutoregMultiSeries._create_lags  skforecast/ForecasterAutoregMultiSeries/ForecasterAutoregMultiSeries.py:456
#    |  |  `- 0.195 DatetimeIndex.__getitem__  pandas/core/indexes/base.py:5373
#    |  |        [2 frames hidden]  pandas
#    |  |- 0.995 concat  pandas/core/reshape/concat.py:157
#    |  |     [5 frames hidden]  pandas
#    |  |- 0.825 check_preprocess_exog_multiseries  skforecast/utils/utils.py:2361
#    |  |  |- 0.269 <listcomp>  skforecast/utils/utils.py:2505
#    |  |  |  `- 0.268 DataFrame.dtypes  pandas/core/generic.py:6432
#    |  |  |        [2 frames hidden]  pandas
#    |  |  |- 0.266 concat  pandas/core/reshape/concat.py:157
#    |  |  |     [4 frames hidden]  pandas
#    |  |  `- 0.256 <genexpr>  skforecast/utils/utils.py:2453
#    |  |     `- 0.253 DataFrame.copy  pandas/core/generic.py:6662
#    |  |           [2 frames hidden]  pandas
#    |  |- 0.824 transform_dataframe  skforecast/utils/utils.py:1520
#    |  |  `- 0.822 ColumnTransformer.wrapped  sklearn/utils/_set_output.py:138
#    |  |        [18 frames hidden]  sklearn, joblib, <built-in>
#    |  |- 0.419 check_preprocess_series  skforecast/utils/utils.py:2258
#    |  |  `- 0.279 Series.__array_ufunc__  pandas/core/generic.py:2167
#    |  |        [4 frames hidden]  pandas
#    |  |- 0.310 <dictcomp>  skforecast/ForecasterAutoregMultiSeries/ForecasterAutoregMultiSeries.py:865
#    |  `- 0.253 OrdinalEncoder.wrapped  sklearn/utils/_set_output.py:138
#    |        [7 frames hidden]  sklearn
#    |- 6.270 LGBMRegressor.fit  lightgbm/sklearn.py:1075
#    |     [10 frames hidden]  lightgbm
#    |        4.872 Booster.update  lightgbm/basic.py:3831
#    |- 1.286 [self]  skforecast/ForecasterAutoregMultiSeries/ForecasterAutoregMultiSeries.py
#    |- 1.064 LGBMRegressor.predict  lightgbm/sklearn.py:919
#    |     [6 frames hidden]  lightgbm
#    |- 0.634 <dictcomp>  skforecast/ForecasterAutoregMultiSeries/ForecasterAutoregMultiSeries.py:1157
#    |  `- 0.630 DatetimeIndex.__getitem__  pandas/core/indexes/base.py:5373
#    |        [8 frames hidden]  pandas
#    `- 0.352 DataFrame.__getitem__  pandas/core/frame.py:4062

# %%
# Profiling fit()
# ==============================================================================
def funt_to_profile(forecaster, series, exog):
    forecaster.fit(series=series, exog=exog)

# %lprun -f forecaster.fit funt_to_profile(forecaster, series_dict_train, exog_dict_train)
# Out:
# /home/ubuntu/varios/skforecast/skforecast/ForecasterAutoregMultiSeries/ForecasterAutoregMultiSeries.py:821: MissingValuesWarning: NaNs detected in `X_train`. Some regressors do not allow NaN values during training. If you want to drop them, set `forecaster.dropna_from_series = True`.
#  You can suppress this warning using: warnings.simplefilter('ignore', category=MissingValuesWarning)
#   warnings.warn(
# Timer unit: 1e-09 s
#
# Total time: 17.3253 s
# File: /home/ubuntu/varios/skforecast/skforecast/ForecasterAutoregMultiSeries/ForecasterAutoregMultiSeries.py
# Function: fit at line 1052
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#   1052                                               def fit(
#   1053                                                   self,
#   1054                                                   series: Union[pd.DataFrame, dict],
#   1055                                                   exog: Optional[Union[pd.Series, pd.DataFrame, dict]]=None,
#   1056                                                   store_last_window: Union[bool, list]=True,
#   1057                                                   store_in_sample_residuals: bool=True,
#   1058                                                   suppress_warnings: bool=False
#   1059                                               ) -> None:
#   1060                                                   """
#   1061                                                   Training Forecaster. See Notes section for more details depending on
#   1062                                                   the type of `series` and `exog`.
#   1063
#   1064                                                   Additional arguments to be passed to the `fit` method of the regressor
#   1065                                                   can be added with the `fit_kwargs` argument when initializing the forecaster.
#   1066
#   1067                                                   Parameters
#   1068                                                   ----------
#   1069                                                   series : pandas DataFrame, dict
#   1070                                                       Training time series.
#   1071                                                   exog : pandas Series, pandas DataFrame, dict, default `None`
#   1072                                                       Exogenous variable/s included as predictor/s.
#   1073                                                   store_last_window : bool, list, default `True`
#   1074                                                       Whether or not to store the last window of training data.
#   1075
#   1076                                                       - If `True`, last_window is stored for all series.
#   1077                                                       - If `list`, last_window is stored for the series present in the list.
#   1078                                                       - If `False`, last_window is not stored.
#   1079                                                   store_in_sample_residuals : bool, default `True`
#   1080                                                       If `True`, in-sample residuals will be stored in the forecaster object
#   1081                                                       after fitting.
#   1082                                                   suppress_warnings : bool, default `False`
#   1083                                                       If `True`, skforecast warnings will be suppressed during the training
#   1084                                                       process. See skforecast.exceptions.warn_skforecast_categories for more
#   1085                                                       information.
#   1086
#   1087                                                   Returns
#   1088                                                   -------
#   1089                                                   None
#   1090
#   1091                                                   Notes
#   1092                                                   -----
#   1093                                                   - If `series` is a pandas DataFrame and `exog` is a pandas Series or
#   1094                                                   DataFrame, each exog is duplicated for each series. Exog must have the
#   1095                                                   same index as `series` (type, length and frequency).
#   1096                                                   - If `series` is a pandas DataFrame and `exog` is a dict of pandas Series
#   1097                                                   or DataFrames. Each key in `exog` must be a column in `series` and the
#   1098                                                   values are the exog for each series. Exog must have the same index as
#   1099                                                   `series` (type, length and frequency).
#   1100                                                   - If `series` is a dict of pandas Series, `exog`must be a dict of pandas
#   1101                                                   Series or DataFrames. The keys in `series` and `exog` must be the same.
#   1102                                                   All series and exog must have a pandas DatetimeIndex with the same
#   1103                                                   frequency.
#   1104
#   1105                                                   """
#   1106
#   1107         1       3390.0   3390.0      0.0          set_skforecast_warnings(suppress_warnings, action='ignore')
#   1108
#   1109                                                   # Reset values in case the forecaster has already been fitted.
#   1110         1      10390.0  10390.0      0.0          self.series_col_names    = None
#   1111         1       2900.0   2900.0      0.0          self.X_train_col_names   = None
#   1112         1       4750.0   4750.0      0.0          self.series_X_train      = None
#   1113         1        690.0    690.0      0.0          self.included_exog       = False
#   1114         1        420.0    420.0      0.0          self.exog_type           = None
#   1115         1       2440.0   2440.0      0.0          self.exog_dtypes         = None
#   1116         1        900.0    900.0      0.0          self.exog_col_names      = None
#   1117         1    3013497.0    3e+06      0.0          self.last_window         = None
#   1118         1     554186.0 554186.0      0.0          self.in_sample_residuals = None
#   1119         1    1277195.0    1e+06      0.0          self.training_range      = None
#   1120         1        890.0    890.0      0.0          self.index_type          = None
#   1121         1        860.0    860.0      0.0          self.index_freq          = None
#   1122         1       1570.0   1570.0      0.0          self.fitted              = False
#   1123
#   1124         1       2100.0   2100.0      0.0          (
#   1125         1        990.0    990.0      0.0              X_train,
#   1126         1        220.0    220.0      0.0              y_train,
#   1127         1        400.0    400.0      0.0              series_indexes,
#   1128         1        260.0    260.0      0.0              series_col_names,
#   1129         1        190.0    190.0      0.0              series_X_train,
#   1130         1        180.0    180.0      0.0              exog_col_names,
#   1131         1        270.0    270.0      0.0              exog_dtypes,
#   1132         1        380.0    380.0      0.0              last_window
#   1133         2 8116907411.0    4e+09     46.9          ) = self._create_train_X_y(
#   1134         1        470.0    470.0      0.0                  series=series, exog=exog, store_last_window=store_last_window
#   1135                                                   )
#   1136
#   1137         2     565167.0 282583.5      0.0          sample_weight = self.create_sample_weights(
#   1138         1        300.0    300.0      0.0                              series_col_names = series_col_names,
#   1139         1        230.0    230.0      0.0                              X_train          = X_train
#   1140                                                                   )
#   1141
#   1142         1        810.0    810.0      0.0          if sample_weight is not None:
#   1143                                                       self.regressor.fit(
#   1144                                                           X             = X_train,
#   1145                                                           y             = y_train,
#   1146                                                           sample_weight = sample_weight,
#   1147                                                           **self.fit_kwargs
#   1148                                                       )
#   1149                                                   else:
#   1150         1 6311062381.0    6e+09     36.4              self.regressor.fit(X=X_train, y=y_train, **self.fit_kwargs)
#   1151
#   1152         1       1170.0   1170.0      0.0          self.series_col_names = series_col_names
#   1153         1       1980.0   1980.0      0.0          self.series_X_train = series_X_train
#   1154         1      14970.0  14970.0      0.0          self.X_train_col_names = X_train.columns.to_list()
#   1155         1       1070.0   1070.0      0.0          self.fitted = True
#   1156         1      70901.0  70901.0      0.0          self.fit_date = pd.Timestamp.today().strftime('%Y-%m-%d %H:%M:%S')
#   1157         1  557590447.0    6e+08      3.2          self.training_range = {k: v[[0, -1]] for k, v in series_indexes.items()}
#   1158         1       2850.0   2850.0      0.0          self.index_type = type(series_indexes[series_col_names[0]])
#   1159         1       1830.0   1830.0      0.0          if isinstance(series_indexes[series_col_names[0]], pd.DatetimeIndex):
#   1160         1      25130.0  25130.0      0.0              self.index_freq = series_indexes[series_col_names[0]].freqstr
#   1161                                                   else:
#   1162                                                       self.index_freq = series_indexes[series_col_names[0]].step
#   1163
#   1164         1        380.0    380.0      0.0          if exog is not None:
#   1165         1        660.0    660.0      0.0              self.included_exog = True
#   1166         1        730.0    730.0      0.0              self.exog_type = type(exog)
#   1167         1        570.0    570.0      0.0              self.exog_col_names = exog_col_names
#   1168         1        510.0    510.0      0.0              self.exog_dtypes = exog_dtypes
#   1169
#   1170         1        290.0    290.0      0.0          in_sample_residuals = {}
#   1171         1        230.0    230.0      0.0          if store_in_sample_residuals:
#   1172
#   1173         1 1042759506.0    1e+09      6.0              residuals = (y_train - self.regressor.predict(X_train)).to_numpy()
#   1174         1     139871.0 139871.0      0.0              rng = np.random.default_rng(seed=123)
#   1175
#   1176      1579    1866440.0   1182.0      0.0              for col in series_X_train:
#   1177      1578    2581967.0   1636.2      0.0                  if self.encoding == 'onehot':
#   1178                                                               mask = X_train[col].to_numpy() == 1.
#   1179                                                           else:
#   1180      1578    1978930.0   1254.1      0.0                      encoded_value = self.encoding_mapping[col]
#   1181      1578  988152980.0 626205.9      5.7                      mask = X_train['_level_skforecast'].to_numpy() == encoded_value
#   1182
#   1183      1578  289961653.0 183752.6      1.7                  residuals_col = residuals[mask]
#   1184      1578    3832994.0   2429.0      0.0                  if len(residuals_col) > 1000:
#   1185                                                               residuals_col = rng.choice(
#   1186                                                                                       a       = residuals_col,
#   1187                                                                                       size    = 1000,
#   1188                                                                                       replace = False
#   1189                                                                                 )
#   1190      1578    2858268.0   1811.3      0.0                  in_sample_residuals[col] = residuals_col
#   1191                                                   else:
#   1192                                                       for col in series_X_train:
#   1193                                                           in_sample_residuals[col] = None
#   1194
#   1195         1       3600.0   3600.0      0.0          self.in_sample_residuals = in_sample_residuals
#   1196
#   1197         1        460.0    460.0      0.0          if store_last_window:
#   1198         1        870.0    870.0      0.0              self.last_window = last_window
#   1199
#   1200         1       4210.0   4210.0      0.0          set_skforecast_warnings(suppress_warnings, action='default')

# %%
# Profiling _create_train_X_y()
# ==============================================================================
def funt_to_profile(forecaster, series, exog):
    forecaster._create_train_X_y(series=series, exog=exog)

# %lprun -f forecaster._create_train_X_y funt_to_profile(forecaster, series_dict_train, exog_dict_train)
# Out:
# /home/ubuntu/varios/skforecast/skforecast/ForecasterAutoregMultiSeries/ForecasterAutoregMultiSeries.py:821: MissingValuesWarning: NaNs detected in `X_train`. Some regressors do not allow NaN values during training. If you want to drop them, set `forecaster.dropna_from_series = True`.
#  You can suppress this warning using: warnings.simplefilter('ignore', category=MissingValuesWarning)
#   warnings.warn(
# Timer unit: 1e-09 s
#
# Total time: 8.20557 s
# File: /home/ubuntu/varios/skforecast/skforecast/ForecasterAutoregMultiSeries/ForecasterAutoregMultiSeries.py
# Function: _create_train_X_y at line 595
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    595                                               def _create_train_X_y(
#    596                                                   self,
#    597                                                   series: Union[pd.DataFrame, dict],
#    598                                                   exog: Optional[Union[pd.Series, pd.DataFrame, dict]]=None,
#    599                                                   store_last_window: Union[bool, list]=True,
#    600                                               ) -> Tuple[pd.DataFrame, pd.Series, dict, list, list, list, dict, dict]:
#    601                                                   """
#    602                                                   Create training matrices from multiple time series and exogenous
#    603                                                   variables. See Notes section for more details depending on the type of
#    604                                                   `series` and `exog`.
#    605
#    606                                                   Parameters
#    607                                                   ----------
#    608                                                   series : pandas DataFrame, dict
#    609                                                       Training time series.
#    610                                                   exog : pandas Series, pandas DataFrame, dict, default `None`
#    611                                                       Exogenous variable/s included as predictor/s.
#    612                                                   store_last_window : bool, list, default `True`
#    613                                                       Whether or not to store the last window of training data.
#    614
#    615                                                       - If `True`, last_window is stored for all series.
#    616                                                       - If `list`, last_window is stored for the series present in the list.
#    617                                                       - If `False`, last_window is not stored.
#    618
#    619                                                   Returns
#    620                                                   -------
#    621                                                   X_train : pandas DataFrame
#    622                                                       Training values (predictors).
#    623                                                   y_train : pandas Series
#    624                                                       Values (target) of the time series related to each row of `X_train`.
#    625                                                   series_indexes : dict
#    626                                                       Dictionary with the index of each series.
#    627                                                   series_col_names : list
#    628                                                       Names of the series (levels) provided by the user during training.
#    629                                                   series_X_train : list
#    630                                                       Names of the series (levels) included in the matrix `X_train` created
#    631                                                       internally for training. It can be different from `series_col_names` if
#    632                                                       some series are dropped during the training process because of NaNs or
#    633                                                       because they are not present in the training period.
#    634                                                   exog_col_names : list
#    635                                                       Names of the exogenous variables used during training.
#    636                                                   exog_dtypes : dict
#    637                                                       Type of each exogenous variable/s used in training. If `transformer_exog`
#    638                                                       is used, the dtypes are calculated before the transformation.
#    639                                                   last_window : dict
#    640                                                       Last window of training data for each series. It stores the values
#    641                                                       needed to predict the next `step` immediately after the training data.
#    642
#    643                                                   Notes
#    644                                                   -----
#    645                                                   - If `series` is a pandas DataFrame and `exog` is a pandas Series or
#    646                                                   DataFrame, each exog is duplicated for each series. Exog must have the
#    647                                                   same index as `series` (type, length and frequency).
#    648                                                   - If `series` is a pandas DataFrame and `exog` is a dict of pandas Series
#    649                                                   or DataFrames. Each key in `exog` must be a column in `series` and the
#    650                                                   values are the exog for each series. Exog must have the same index as
#    651                                                   `series` (type, length and frequency).
#    652                                                   - If `series` is a dict of pandas Series, `exog` must be a dict of pandas
#    653                                                   Series or DataFrames. The keys in `series` and `exog` must be the same.
#    654                                                   All series and exog must have a pandas DatetimeIndex with the same
#    655                                                   frequency.
#    656
#    657                                                   """
#    658
#    659         1  662082240.0    7e+08      8.1          series_dict, series_indexes = check_preprocess_series(series=series)
#    660         1       1510.0   1510.0      0.0          input_series_is_dict = isinstance(series, dict)
#    661         1      14360.0  14360.0      0.0          series_col_names = list(series_dict.keys())
#    662
#    663         1       6550.0   6550.0      0.0          if self.fitted and not (series_col_names == self.series_col_names):
#    664                                                       raise ValueError(
#    665                                                           (f"Once the Forecaster has been trained, `series` must have the "
#    666                                                            f"same columns as the series used during training:\n"
#    667                                                            f" Got      : {series_col_names}\n"
#    668                                                            f" Expected : {self.series_col_names}")
#    669                                                       )
#    670
#    671         1     309294.0 309294.0      0.0          exog_dict = {serie: None for serie in series_col_names}
#    672         1        290.0    290.0      0.0          exog_col_names = None
#    673         1        430.0    430.0      0.0          if exog is not None:
#    674         2  688600248.0    3e+08      8.4              exog_dict, exog_col_names = check_preprocess_exog_multiseries(
#    675         1        400.0    400.0      0.0                                              input_series_is_dict = input_series_is_dict,
#    676         1        230.0    230.0      0.0                                              series_indexes       = series_indexes,
#    677         1        190.0    190.0      0.0                                              series_col_names     = series_col_names,
#    678         1        280.0    280.0      0.0                                              exog                 = exog,
#    679         1        230.0    230.0      0.0                                              exog_dict            = exog_dict
#    680                                                                                   )
#    681
#    682         1       1630.0   1630.0      0.0              if self.fitted:
#    683         1        830.0    830.0      0.0                  if self.exog_col_names is None:
#    684                                                               raise ValueError(
#    685                                                                   ("Once the Forecaster has been trained, `exog` must be `None` "
#    686                                                                    "because no exogenous variables were added during training.")
#    687                                                               )
#    688                                                           else:
#    689         1       4340.0   4340.0      0.0                      if not set(exog_col_names) == set(self.exog_col_names):
#    690                                                                   raise ValueError(
#    691                                                                       (f"Once the Forecaster has been trained, `exog` must have the "
#    692                                                                        f"same columns as the series used during training:\n"
#    693                                                                        f" Got      : {exog_col_names}\n"
#    694                                                                        f" Expected : {self.exog_col_names}")
#    695                                                                   )
#    696
#    697         1        510.0    510.0      0.0          if not self.fitted:
#    698                                                       self.transformer_series_ = initialize_transformer_series(
#    699                                                                                      series_col_names = series_col_names,
#    700                                                                                      transformer_series = self.transformer_series
#    701                                                                                  )
#    702
#    703         1       1510.0   1510.0      0.0          if self.differentiation is None:
#    704         1     347544.0 347544.0      0.0              self.differentiator_ = {serie: None for serie in series_col_names}
#    705                                                   else:
#    706                                                       if not self.fitted:
#    707                                                           self.differentiator_ = {serie: clone(self.differentiator)
#    708                                                                                   for serie in series_col_names}
#    709
#    710         2 2190056785.0    1e+09     26.7          series_dict, exog_dict = align_series_and_exog_multiseries(
#    711         1        520.0    520.0      0.0                                       series_dict          = series_dict,
#    712         1        230.0    230.0      0.0                                       input_series_is_dict = input_series_is_dict,
#    713         1        240.0    240.0      0.0                                       exog_dict            = exog_dict
#    714                                                                            )
#    715
#    716                                                   # TODO: parallelize
#    717                                                   # ======================================================================
#    718         1        890.0    890.0      0.0          ignore_exog = True if exog is None else False
#    719         2    1659010.0 829505.0      0.0          input_matrices = [
#    720                                                       [series_dict[k], exog_dict[k], ignore_exog]
#    721         1        960.0    960.0      0.0               for k in series_dict.keys()
#    722                                                   ]
#    723
#    724         1        500.0    500.0      0.0          X_train_lags_buffer = []
#    725         1        310.0    310.0      0.0          X_train_exog_buffer = []
#    726         1        340.0    340.0      0.0          y_train_buffer = []
#    727      1579     864440.0    547.5      0.0          for matrices in input_matrices:
#    728
#    729      1578    1297102.0    822.0      0.0              X_train_lags, X_train_exog, y_train = (
#    730      3156 1974420722.0 625608.6     24.1                  self._create_train_X_y_single_series(
#    731      1578     832909.0    527.8      0.0                      y           = matrices[0],
#    732      1578     563805.0    357.3      0.0                      exog        = matrices[1],
#    733      1578     451212.0    285.9      0.0                      ignore_exog = matrices[2],
#    734                                                           )
#    735                                                       )
#    736
#    737      1578    1382110.0    875.9      0.0              X_train_lags_buffer.append(X_train_lags)
#    738      1578     832765.0    527.7      0.0              X_train_exog_buffer.append(X_train_exog)
#    739      1578     956684.0    606.3      0.0              y_train_buffer.append(y_train)
#    740                                                   # ======================================================================
#    741
#    742         1  212012882.0    2e+08      2.6          X_train = pd.concat(X_train_lags_buffer, axis=0)
#    743         1   36107703.0    4e+07      0.4          y_train = pd.concat(y_train_buffer, axis=0)
#    744
#    745         1       1690.0   1690.0      0.0          if self.fitted:
#    746         1  343260857.0    3e+08      4.2              encoded_values = self.encoder.transform(X_train[['_level_skforecast']])
#    747                                                   else:
#    748                                                       encoded_values = self.encoder.fit_transform(X_train[['_level_skforecast']])
#    749                                                       for i, code in enumerate(self.encoder.categories_[0]):
#    750                                                           self.encoding_mapping[code] = i
#    751
#    752         3  109219140.0    4e+07      1.3          X_train = pd.concat([
#    753         1   33461041.0    3e+07      0.4                        X_train.drop(columns='_level_skforecast'),
#    754         1        780.0    780.0      0.0                        encoded_values
#    755         1        400.0    400.0      0.0                    ], axis=1)
#    756
#    757         1       3360.0   3360.0      0.0          if self.encoding == 'onehot':
#    758                                                       X_train.columns = X_train.columns.str.replace('_level_skforecast_', '')
#    759         1        830.0    830.0      0.0          elif self.encoding == 'ordinal_category':
#    760                                                       X_train['_level_skforecast'] = (
#    761                                                           X_train['_level_skforecast'].astype('category')
#    762                                                       )
#    763
#    764         1       6371.0   6371.0      0.0          del encoded_values
#    765
#    766         1        340.0    340.0      0.0          exog_dtypes = None
#    767         1        750.0    750.0      0.0          if exog is not None:
#    768
#    769         1  405603954.0    4e+08      4.9              X_train_exog = pd.concat(X_train_exog_buffer, axis=0)
#    770         1      26210.0  26210.0      0.0              if '_dummy_exog_col_to_keep_shape' in X_train_exog.columns:
#    771                                                           X_train_exog = (
#    772                                                               X_train_exog.drop(columns=['_dummy_exog_col_to_keep_shape'])
#    773                                                           )
#    774
#    775         1       9330.0   9330.0      0.0              exog_col_names = X_train_exog.columns.to_list()
#    776         1     426805.0 426805.0      0.0              exog_dtypes = get_exog_dtypes(exog=X_train_exog)
#    777
#    778         1       1850.0   1850.0      0.0              fit_transformer = False if self.fitted else True
#    779         2 1091563191.0    5e+08     13.3              X_train_exog = transform_dataframe(
#    780         1        210.0    210.0      0.0                                 df                = X_train_exog,
#    781         1       1531.0   1531.0      0.0                                 transformer       = self.transformer_exog,
#    782         1        220.0    220.0      0.0                                 fit               = fit_transformer,
#    783         1        200.0    200.0      0.0                                 inverse_transform = False
#    784                                                                      )
#    785
#    786         1     422855.0 422855.0      0.0              check_exog_dtypes(X_train_exog, call_check_exog=False)
#    787         1    2918535.0    3e+06      0.0              if not (X_train_exog.index == X_train.index).all():
#    788                                                           raise ValueError(
#    789                                                               ("Different index for `series` and `exog` after transformation. "
#    790                                                                "They must be equal to ensure the correct alignment of values.")
#    791                                                           )
#    792
#    793         1  116937123.0    1e+08      1.4              X_train = pd.concat([X_train, X_train_exog], axis=1)
#    794
#    795         1    1138864.0    1e+06      0.0          if y_train.isnull().any():
#    796                                                       mask = y_train.notna().to_numpy()
#    797                                                       y_train = y_train.iloc[mask]
#    798                                                       X_train = X_train.iloc[mask,]
#    799                                                       warnings.warn(
#    800                                                           ("NaNs detected in `y_train`. They have been dropped because the "
#    801                                                            "target variable cannot have NaN values. Same rows have been "
#    802                                                            "dropped from `X_train` to maintain alignment. This is caused by "
#    803                                                            "series with interspersed NaNs."),
#    804                                                            MissingValuesWarning
#    805                                                       )
#    806
#    807         1       3150.0   3150.0      0.0          if self.dropna_from_series:
#    808                                                       if np.any(X_train.isnull().to_numpy()):
#    809                                                           mask = X_train.notna().all(axis=1).to_numpy()
#    810                                                           X_train = X_train.iloc[mask, ]
#    811                                                           y_train = y_train.iloc[mask]
#    812                                                           warnings.warn(
#    813                                                               ("NaNs detected in `X_train`. They have been dropped. If "
#    814                                                                "you want to keep them, set `forecaster.dropna_from_series = False`. "
#    815                                                                "Same rows have been removed from `y_train` to maintain alignment. "
#    816                                                                "This caused by series with interspersed NaNs."),
#    817                                                                MissingValuesWarning
#    818                                                           )
#    819                                                   else:
#    820         1   24445313.0    2e+07      0.3              if np.any(X_train.isnull().to_numpy()):
#    821         2     262853.0 131426.5      0.0                  warnings.warn(
#    822         1        750.0    750.0      0.0                      ("NaNs detected in `X_train`. Some regressors do not allow "
#    823                                                                "NaN values during training. If you want to drop them, "
#    824                                                                "set `forecaster.dropna_from_series = True`."),
#    825         1        780.0    780.0      0.0                       MissingValuesWarning
#    826                                                           )
#    827
#    828         1      32170.0  32170.0      0.0          if X_train.empty:
#    829                                                       raise ValueError(
#    830                                                           ("All samples have been removed due to NaNs. Set "
#    831                                                            "`forecaster.dropna_from_series = False` or review `exog` values.")
#    832                                                       )
#    833
#    834         1       2250.0   2250.0      0.0          if self.encoding == 'onehot':
#    835                                                       series_X_train = [
#    836                                                           col for col in series_col_names if X_train[col].sum() > 0
#    837                                                       ]
#    838                                                   else:
#    839         1    6679151.0    7e+06      0.1              unique_levels = X_train['_level_skforecast'].unique()
#    840         2   11343166.0    6e+06      0.1              series_X_train = [
#    841         1       2080.0   2080.0      0.0                  k for k, v in self.encoding_mapping.items()
#    842                                                           if v in unique_levels
#    843                                                       ]
#    844
#    845                                                   # The last time window of training data is stored so that lags needed as
#    846                                                   # predictors in the first iteration of `predict()` can be calculated.
#    847         1        700.0    700.0      0.0          last_window = None
#    848         1        300.0    300.0      0.0          if store_last_window:
#    849
#    850         1        290.0    290.0      0.0              series_to_store = (
#    851         1        700.0    700.0      0.0                  series_X_train if store_last_window is True else store_last_window
#    852                                                       )
#    853
#    854         1     213802.0 213802.0      0.0              series_not_in_series_dict = set(series_to_store) - set(series_X_train)
#    855         1        760.0    760.0      0.0              if series_not_in_series_dict:
#    856                                                           warnings.warn(
#    857                                                               (f"Series {series_not_in_series_dict} are not present in "
#    858                                                                f"`series`. No last window is stored for them."),
#    859                                                               IgnoredArgumentWarning
#    860                                                           )
#    861                                                           series_to_store = [s for s in series_to_store
#    862                                                                              if s not in series_not_in_series_dict]
#    863
#    864         1        340.0    340.0      0.0              if series_to_store:
#    865         2  284760686.0    1e+08      3.5                  last_window = {
#    866                                                               k: v.iloc[-self.window_size_diff:].copy()
#    867         1       1020.0   1020.0      0.0                      for k, v in series_dict.items()
#    868                                                               if k in series_to_store
#    869                                                           }
#    870
#    871         1        350.0    350.0      0.0          return (
#    872         1        660.0    660.0      0.0              X_train,
#    873         1        280.0    280.0      0.0              y_train,
#    874         1        200.0    200.0      0.0              series_indexes,
#    875         1        400.0    400.0      0.0              series_col_names,
#    876         1        200.0    200.0      0.0              series_X_train,
#    877         1        300.0    300.0      0.0              exog_col_names,
#    878         1        380.0    380.0      0.0              exog_dtypes,
#    879         1        190.0    190.0      0.0              last_window,
#    880                                                   )

# %%
# Profiling predict()
# ==============================================================================
def funt_to_profile(forecaster, steps, exog):
    forecaster.predict(steps=steps, exog=exog, suppress_warnings=True)

# %lprun -f forecaster.predict funt_to_profile(forecaster, 7, exog_dict_valid)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 36.6131 s
# File: /home/ubuntu/varios/skforecast/skforecast/ForecasterAutoregMultiSeries/ForecasterAutoregMultiSeries.py
# Function: predict at line 1537
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#   1537                                               def predict(
#   1538                                                   self,
#   1539                                                   steps: int,
#   1540                                                   levels: Optional[Union[str, list]]=None,
#   1541                                                   last_window: Optional[pd.DataFrame]=None,
#   1542                                                   exog: Optional[Union[pd.Series, pd.DataFrame, dict]]=None,
#   1543                                                   suppress_warnings: bool=False
#   1544                                               ) -> pd.DataFrame:
#   1545                                                   """
#   1546                                                   Predict n steps ahead. It is an recursive process in which, each prediction,
#   1547                                                   is used as a predictor for the next step. Only levels whose last window
#   1548                                                   ends at the same datetime index can be predicted together.
#   1549
#   1550                                                   Parameters
#   1551                                                   ----------
#   1552                                                   steps : int
#   1553                                                       Number of future steps predicted.
#   1554                                                   levels : str, list, default `None`
#   1555                                                       Time series to be predicted. If `None` all levels whose last window
#   1556                                                       ends at the same datetime index will be predicted together.
#   1557                                                   last_window : pandas DataFrame, default `None`
#   1558                                                       Series values used to create the predictors (lags) needed in the
#   1559                                                       first iteration of the prediction (t + 1).
#   1560                                                       If `last_window = None`, the values stored in `self.last_window` are
#   1561                                                       used to calculate the initial predictors, and the predictions start
#   1562                                                       right after training data.
#   1563                                                   exog : pandas Series, pandas DataFrame, dict, default `None`
#   1564                                                       Exogenous variable/s included as predictor/s.
#   1565                                                   suppress_warnings : bool, default `False`
#   1566                                                       If `True`, skforecast warnings will be suppressed during the prediction
#   1567                                                       process. See skforecast.exceptions.warn_skforecast_categories for more
#   1568                                                       information.
#   1569
#   1570                                                   Returns
#   1571                                                   -------
#   1572                                                   predictions : pandas DataFrame
#   1573                                                       Predicted values, one column for each level.
#   1574
#   1575                                                   """
#   1576
#   1577         1      60301.0  60301.0      0.0          set_skforecast_warnings(suppress_warnings, action='ignore')
#   1578
#   1579         1       1960.0   1960.0      0.0          (
#   1580         1        710.0    710.0      0.0              last_window_values_dict,
#   1581         1        360.0    360.0      0.0              exog_values_dict,
#   1582         1        300.0    300.0      0.0              levels,
#   1583         1        400.0    400.0      0.0              prediction_index,
#   1584         1        520.0    520.0      0.0              _
#   1585         2        2e+10    1e+10     52.8          ) = self._create_predict_inputs(
#   1586         1        220.0    220.0      0.0              steps       = steps,
#   1587         1        200.0    200.0      0.0              levels      = levels,
#   1588         1        210.0    210.0      0.0              last_window = last_window,
#   1589         1        190.0    190.0      0.0              exog        = exog
#   1590                                                   )
#   1591
#   1592         1        440.0    440.0      0.0          predictions = []
#   1593      1579     777563.0    492.4      0.0          for level in levels:
#   1594
#   1595      3156        2e+10    5e+06     46.0              preds_level = self._recursive_predict(
#   1596      1578     389436.0    246.8      0.0                                steps       = steps,
#   1597      1578     382309.0    242.3      0.0                                level       = level,
#   1598      1578    1154419.0    731.6      0.0                                last_window = last_window_values_dict[level],
#   1599      1578     973106.0    616.7      0.0                                exog        = exog_values_dict[level]
#   1600                                                                     )
#   1601
#   1602      1578    1244621.0    788.7      0.0              if self.differentiation is not None:
#   1603                                                           preds_level = self.differentiator_[level].inverse_transform_next_window(preds_level)
#   1604
#   1605      3156  194722123.0  61699.0      0.5              preds_level = pd.Series(
#   1606      1578     440570.0    279.2      0.0                                data  = preds_level,
#   1607      1578     483597.0    306.5      0.0                                index = prediction_index,
#   1608      1578     387574.0    245.6      0.0                                name  = level
#   1609                                                                     )
#   1610
#   1611      3156    4344345.0   1376.5      0.0              preds_level = transform_series(
#   1612      1578     472086.0    299.2      0.0                                series            = preds_level,
#   1613      1578    1646270.0   1043.3      0.0                                transformer       = self.transformer_series_[level],
#   1614      1578     440865.0    279.4      0.0                                fit               = False,
#   1615      1578     386664.0    245.0      0.0                                inverse_transform = True
#   1616                                                                     )
#   1617
#   1618      1578    1421995.0    901.1      0.0              predictions.append(preds_level)
#   1619
#   1620         1  228002906.0    2e+08      0.6          predictions = pd.concat(predictions, axis=1)
#   1621
#   1622         1      68061.0  68061.0      0.0          set_skforecast_warnings(suppress_warnings, action='default')
#   1623
#   1624         1        240.0    240.0      0.0          return predictions

# %%
# Functions to profile:
# ==============================================================================
# check_preprocess_exog_multiseries
# align_series_and_exog_multiseries
# _create_train_X_y_single_series
# _create_predict_inputs
# _recursive_predict

# %%
# Profiling align_series_and_exog_multiseries()
# ==============================================================================
def funt_to_profile(series_dict, input_series_is_dict, exog_dict):
    align_series_and_exog_multiseries(
        series_dict=series_dict,
        input_series_is_dict=input_series_is_dict,
        exog_dict = exog_dict,
    )

# %lprun -f align_series_and_exog_multiseries funt_to_profile(series_dict_train, True, exog_dict_train)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 2.26484 s
# File: /home/ubuntu/varios/skforecast/skforecast/utils/utils.py
# Function: align_series_and_exog_multiseries at line 2532
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#   2532                                           def align_series_and_exog_multiseries(
#   2533                                               series_dict: dict,
#   2534                                               input_series_is_dict: bool,
#   2535                                               exog_dict: dict=None
#   2536                                           ) -> Tuple[Union[pd.Series, pd.DataFrame], Union[pd.Series, pd.DataFrame]]:
#   2537                                               """
#   2538                                               Align series and exog according to their index. If needed, reindexing is
#   2539                                               applied. Heading and trailing NaNs are removed from all series in
#   2540                                               `series_dict`.
#   2541
#   2542                                               - If input series is a pandas DataFrame (input_series_is_dict = False),
#   2543                                               input exog (pandas Series, DataFrame or dict) must have the same index
#   2544                                               (type, length and frequency). Reindexing is not applied.
#   2545                                               - If input series is a dict (input_series_is_dict = True), then input
#   2546                                               exog must be a dict. Both must have a pandas DatetimeIndex, but can have
#   2547                                               different lengths. Reindexing is applied.
#   2548
#   2549                                               Parameters
#   2550                                               ----------
#   2551                                               series_dict : dict
#   2552                                                   Dictionary with the series used during training.
#   2553                                               input_series_is_dict : bool
#   2554                                                   Indicates if input series argument is a dict.
#   2555                                               exog_dict : dict, default `None`
#   2556                                                   Dictionary with the exogenous variable/s used during training.
#   2557
#   2558                                               Returns
#   2559                                               -------
#   2560                                               series_dict : dict
#   2561                                                   Dictionary with the series used during training.
#   2562                                               exog_dict : dict
#   2563                                                   Dictionary with the exogenous variable/s used during training.
#   2564
#   2565                                               """
#   2566
#   2567      1579     732892.0    464.1      0.0      for k in series_dict.keys():
#   2568
#   2569      1578  388052133.0 245913.9     17.1          first_valid_index = series_dict[k].first_valid_index()
#   2570      1578  364960579.0 231280.5     16.1          last_valid_index = series_dict[k].last_valid_index()
#   2571
#   2572      1578  325770458.0 206445.2     14.4          series_dict[k] = series_dict[k].loc[first_valid_index : last_valid_index]
#   2573
#   2574      1578    1315327.0    833.5      0.1          if exog_dict[k] is not None:
#   2575      1578     547214.0    346.8      0.0              if input_series_is_dict:
#   2576      1578     500544.0    317.2      0.0                  index_intersection = (
#   2577      1578  114025138.0  72259.3      5.0                      series_dict[k].index.intersection(exog_dict[k].index)
#   2578                                                           )
#   2579      1578    3226856.0   2044.9      0.1                  if len(index_intersection) == 0:
#   2580                                                               warnings.warn(
#   2581                                                                   (f"Series '{k}' and its `exog` do not have the same index. "
#   2582                                                                    f"All exog values will be NaN for the period of the series."),
#   2583                                                                    MissingValuesWarning
#   2584                                                               )
#   2585      1578    8681427.0   5501.5      0.4                  elif len(index_intersection) != len(series_dict[k]):
#   2586                                                               warnings.warn(
#   2587                                                                   (f"Series '{k}' and its `exog` do not have the same length. "
#   2588                                                                    f"Exog values will be NaN for the not matched period of the series."),
#   2589                                                                    MissingValuesWarning
#   2590                                                               )
#   2591      1578 1046347242.0 663084.4     46.2                  exog_dict[k] = exog_dict[k].loc[index_intersection]
#   2592      1578   10683145.0   6770.1      0.5                  if len(index_intersection) != len(series_dict[k]):
#   2593                                                               exog_dict[k] = exog_dict[k].reindex(
#   2594                                                                                  series_dict[k].index,
#   2595                                                                                  fill_value = np.nan
#   2596                                                                              )
#   2597                                                       else:
#   2598                                                           exog_dict[k] = exog_dict[k].loc[first_valid_index : last_valid_index]
#   2599
#   2600         1        410.0    410.0      0.0      return series_dict, exog_dict

# %%
# Profiling check_preprocess_exog_multiseries()
# ==============================================================================
series_indexes = {k: v.index for k, v  in series_dict_train.items()}
series_col_names = list(series_dict_train.keys())

def funt_to_profile(input_series_is_dict, series_indexes, series_col_names, exog, exog_dict):
    check_preprocess_exog_multiseries(
        input_series_is_dict = input_series_is_dict,
        series_indexes = series_indexes,
        series_col_names = series_col_names,
        exog = exog_dict_train,
        exog_dict = exog_dict_train,
    )

# %lprun -f check_preprocess_exog_multiseries funt_to_profile(True, series_indexes, series_col_names, exog, exog_dict)
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.911268 s
# File: /home/ubuntu/varios/skforecast/skforecast/utils/utils.py
# Function: check_preprocess_exog_multiseries at line 2361
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#   2361                                           def check_preprocess_exog_multiseries(
#   2362                                               input_series_is_dict: bool,
#   2363                                               series_indexes: dict,
#   2364                                               series_col_names: list,
#   2365                                               exog: Union[pd.Series, pd.DataFrame, dict],
#   2366                                               exog_dict: dict,
#   2367                                           ) -> Tuple[dict, list]:
#   2368                                               """
#   2369                                               Check and preprocess `exog` argument in `ForecasterAutoregMultiSeries` and
#   2370                                               `ForecasterAutoregMultiSeriesCustom` classes.
#   2371
#   2372                                               - If input series is a pandas DataFrame (input_series_is_dict = False),
#   2373                                               checks that input exog (pandas Series, DataFrame or dict) has the same index
#   2374                                               (type, length and frequency). Index is overwritten according to the rules
#   2375                                               of preprocess_exog. Create a dict of exog with the same keys as series.
#   2376                                               - If input series is a dict (input_series_is_dict = True), then input
#   2377                                               exog must be a dict. Check exog has a pandas DatetimeIndex and convert all
#   2378                                               values to pandas DataFrames.
#   2379
#   2380                                               Parameters
#   2381                                               ----------
#   2382                                               input_series_is_dict : bool
#   2383                                                   Indicates if input series argument is a dict.
#   2384                                               series_indexes : dict
#   2385                                                   Dictionary with the index of each series.
#   2386                                               series_col_names : list
#   2387                                                   Names of the series (levels) used during training.
#   2388                                               exog : pandas Series, pandas DataFrame, dict
#   2389                                                   Exogenous variable/s used during training.
#   2390                                               exog_dict : dict
#   2391                                                   Dictionary with the exogenous variable/s used during training.
#   2392
#   2393                                               Returns
#   2394                                               -------
#   2395                                               exog_dict : dict
#   2396                                                   Dictionary with the exogenous variable/s used during training.
#   2397                                               exog_col_names : list
#   2398                                                   Names of the exogenous variables used during training.
#   2399
#   2400                                               """
#   2401
#   2402         1       3220.0   3220.0      0.0      if not isinstance(exog, (pd.Series, pd.DataFrame, dict)):
#   2403                                                   raise TypeError(
#   2404                                                       (f"`exog` must be a pandas Series, DataFrame, dictionary of pandas "
#   2405                                                        f"Series/DataFrames or None. Got {type(exog)}.")
#   2406                                                   )
#   2407
#   2408         1        390.0    390.0      0.0      if not input_series_is_dict:
#   2409                                                   # If input series is a pandas DataFrame, all index are the same.
#   2410                                                   # Select the first index to check exog
#   2411                                                   series_index = series_indexes[series_col_names[0]]
#   2412
#   2413         1       1350.0   1350.0      0.0      if isinstance(exog, (pd.Series, pd.DataFrame)):
#   2414
#   2415                                                   if input_series_is_dict:
#   2416                                                       raise TypeError(
#   2417                                                           (f"`exog` must be a dict of DataFrames or Series if "
#   2418                                                            f"`series` is a dict. Got {type(exog)}.")
#   2419                                                       )
#   2420
#   2421                                                   _, exog_index = preprocess_exog(exog=exog, return_values=False)
#   2422                                                   exog = exog.copy().to_frame() if isinstance(exog, pd.Series) else exog.copy()
#   2423                                                   exog.index = exog_index
#   2424
#   2425                                                   if len(exog) != len(series_index):
#   2426                                                       raise ValueError(
#   2427                                                           (f"`exog` must have same number of samples as `series`. "
#   2428                                                            f"length `exog`: ({len(exog)}), length `series`: ({len(series_index)})")
#   2429                                                       )
#   2430
#   2431                                                   if not (exog_index == series_index).all():
#   2432                                                       raise ValueError(
#   2433                                                           ("Different index for `series` and `exog`. They must be equal "
#   2434                                                            "to ensure the correct alignment of values.")
#   2435                                                       )
#   2436
#   2437                                                   exog_dict = {serie: exog for serie in series_col_names}
#   2438
#   2439                                               else:
#   2440
#   2441         2    1746021.0 873010.5      0.2          not_valid_exog = [
#   2442                                                       k
#   2443         1        930.0    930.0      0.0              for k, v in exog.items()
#   2444                                                       if not isinstance(v, (pd.Series, pd.DataFrame, type(None)))
#   2445                                                   ]
#   2446         1        560.0    560.0      0.0          if not_valid_exog:
#   2447                                                       raise TypeError(
#   2448                                                           (f"If `exog` is a dictionary, all exog must be a named pandas "
#   2449                                                            f"Series, a pandas DataFrame or None. Review exog: {not_valid_exog}")
#   2450                                                       )
#   2451
#   2452                                                   # Only elements already present in exog_dict are updated
#   2453         2  414822673.0    2e+08     45.5          exog_dict.update(
#   2454                                                       (k, v.copy())
#   2455         1        560.0    560.0      0.0              for k, v in exog.items()
#   2456                                                       if k in exog_dict and v is not None
#   2457                                                   )
#   2458
#   2459         1     240513.0 240513.0      0.0          series_not_in_exog = set(series_col_names) - set(exog.keys())
#   2460         1        480.0    480.0      0.0          if series_not_in_exog:
#   2461                                                       warnings.warn(
#   2462                                                           (f"{series_not_in_exog} not present in `exog`. All values "
#   2463                                                            f"of the exogenous variables for these series will be NaN."),
#   2464                                                            MissingExogWarning
#   2465                                                       )
#   2466
#   2467      1579     754801.0    478.0      0.1          for k, v in exog_dict.items():
#   2468      1578     459121.0    291.0      0.1              if v is not None:
#   2469      1578    3151626.0   1997.2      0.3                  check_exog(exog=v, allow_nan=True)
#   2470      1578     992314.0    628.8      0.1                  if isinstance(v, pd.Series):
#   2471                                                               v = v.to_frame()
#   2472      1578     629069.0    398.6      0.1                  exog_dict[k] = v
#   2473
#   2474         1        310.0    310.0      0.0          if not input_series_is_dict:
#   2475                                                       for k, v in exog_dict.items():
#   2476                                                           if v is not None:
#   2477                                                               if len(v) != len(series_index):
#   2478                                                                   raise ValueError(
#   2479                                                                       (f"`exog` for series '{k}' must have same number of "
#   2480                                                                        f"samples as `series`. length `exog`: ({len(v)}), "
#   2481                                                                        f"length `series`: ({len(series_index)})")
#   2482                                                                   )
#   2483
#   2484                                                               _, v_index = preprocess_exog(exog=v, return_values=False)
#   2485                                                               exog_dict[k].index = v_index
#   2486                                                               if not (exog_dict[k].index == series_index).all():
#   2487                                                                   raise ValueError(
#   2488                                                                       (f"Different index for series '{k}' and its exog. "
#   2489                                                                        f"When `series` is a pandas DataFrame, they must be "
#   2490                                                                        f"equal to ensure the correct alignment of values.")
#   2491                                                                   )
#   2492                                                   else:
#   2493         2    1722800.0 861400.0      0.2              not_valid_index = [
#   2494                                                           k
#   2495         1        670.0    670.0      0.0                  for k, v in exog_dict.items()
#   2496                                                           if v is not None and not isinstance(v.index, pd.DatetimeIndex)
#   2497                                                       ]
#   2498         1        490.0    490.0      0.0              if not_valid_index:
#   2499                                                           raise TypeError(
#   2500                                                               (f"All exog must have a Pandas DatetimeIndex as index with the "
#   2501                                                                f"same frequency. Check exog for series: {not_valid_index}")
#   2502                                                           )
#   2503
#   2504                                                   # Check that all exog have the same dtypes for common columns
#   2505         1  222578774.0    2e+08     24.4          exog_dtypes_buffer = [df.dtypes for df in exog_dict.values() if df is not None]
#   2506         1  236992527.0    2e+08     26.0          exog_dtypes_buffer = pd.concat(exog_dtypes_buffer, axis=1)
#   2507         1    7366058.0    7e+06      0.8          exog_dtypes_nunique = exog_dtypes_buffer.nunique(axis=1).eq(1)
#   2508         1      43191.0  43191.0      0.0          if not exog_dtypes_nunique.all():
#   2509                                                       non_unique_dtyeps_exogs = exog_dtypes_nunique[exog_dtypes_nunique != 1].index.to_list()
#   2510                                                       raise TypeError(f"Exog/s: {non_unique_dtyeps_exogs} have different dtypes in different series.")
#   2511
#   2512         2       2840.0   1420.0      0.0      exog_col_names = list(
#   2513         2   19644976.0    1e+07      2.2          set(
#   2514                                                       column
#   2515         1       1010.0   1010.0      0.0              for df in exog_dict.values()
#   2516                                                       if df is not None
#   2517                                                       for column in df.columns.to_list()
#   2518                                                   )
#   2519                                               )
#   2520
#   2521         1     109951.0 109951.0      0.0      if len(set(exog_col_names) - set(series_col_names)) != len(exog_col_names):
#   2522                                                   raise ValueError(
#   2523                                                       (f"`exog` cannot contain a column named the same as one of the "
#   2524                                                        f"series (column names of series).\n"
#   2525                                                        f"    `series` columns : {series_col_names}.\n"
#   2526                                                        f"    `exog`   columns : {exog_col_names}.")
#   2527                                                   )
#   2528
#   2529         1        550.0    550.0      0.0      return exog_dict, exog_col_names

# %%
import pandas as pd
import numpy as np
import time

def fun_original():
    pass

def fun_optimized_1():
    pass

start_time = time.time()
try:
    fun_original()
except TypeError as e:
    end_time = time.time()
    print(e)
finally:
    end_time = time.time()
print(f"Original code execution time: {end_time - start_time} seconds")

start_time = time.time()
try:
    fun_optimized_1()
except TypeError as e:
    end_time = time.time()
    print(e)
finally:
    end_time = time.time()
print(f"Optimized code 1 execution time: {end_time - start_time} seconds")
# Out:
# Original code execution time: 9.608268737792969e-05 seconds
# Optimized code 1 execution time: 7.390975952148438e-05 seconds
